# %%
# part 1 : 构造节点类（定义FP树数据结构）
"""
定义FP树数据结构
构造节点类,包括节点类的属性、用来统计节点出现次数的方法和显示FP-tree的方法,
节点类的属性有节点名、节点出现的次数、
用与链接所有相同节点的node_link、节点的父节点和子节点。
"""
class treeNode:

    def __init__(self, nameValue, numOccur, parentNode):
        self.name = nameValue # 节点元素名称
        self.count = numOccur # 节点出现的次数
        self.nodeLink = None # 指向下一个相似节点
        self.parent = parentNode # 指向父节点
        self.children = {} # 指向子节点，子节点元素名称为键，指向子节点指针为值

    def inc(self, numOccur):
        """
        增加节点的出现次数
        :param numOccur:
        :return:
        """
        self.count += numOccur

    def disp(self, ind=1):
        """
        输出节点和子节点的FP树结构
        :param ind:
        :return:
        """
        print('  ' * ind, self.name, ' ', self.count) # 展示节点名称和出现的次数
        for child in self.children.values():
            child.disp(ind + 1) #打印时，子节点的缩进比父节点更深一级

# %%
# part 1 : 测试 class treeNode
rootNode = treeNode('pyramid', 9, None)  # 创建节点
rootNode.children['eye'] = treeNode('eye', 13, None) # 增加子节点
rootNode.children['phoenix'] = treeNode('phoenix', 3, None) # 增加另一个子节点
rootNode.disp() # 将树以文本形式显示
# Out:
#    pyramid   9
#      eye   13
#      phoenix   3

# %%
# part 2 : 原始数据创建和处理
from collections import OrderedDict
def loadSimpDat():
    '''
    # 生成原始数据集
    '''
    simpData = [
        ['A', 'B', 'C', 'E', 'F','O'],
        ['A', 'C', 'G'],
        ['E','I'],
        ['A', 'C', 'D', 'E', 'G'],
        ['A', 'C', 'E', 'G', 'L'],
        ['E', 'J'],
        ['A', 'B', 'C', 'E', 'F', 'P'],
        ['A', 'C', 'D'],
        ['A', 'C', 'E', 'G', 'M'],
        ['A', 'C', 'E', 'G', 'N'],
        ['A', 'C', 'B'],
        ['A', 'B', 'D']]
    return simpData

'''
把原始事务数据集处理成字典的形式，方面后面的函数调用
frozenset() 返回一个冻结的集合，冻结后集合不能再添加或删除任何元素。
'''
def createInitSet(dataSet):
    retDict=OrderedDict() # retDict = {}
    for trans in dataSet:
        # 把每条数据记录冻结（frozenset函数）后作为字典的键，而每个键对应的值都是1
        retDict[frozenset(trans)] = 1
    return retDict

# %%
# part 2 : 原始数据创建和处理
simpData = loadSimpDat() # load样本数据
# print(simpDat, '\n')
# frozen set 格式化 并 重新装载 样本数据，对所有的行进行统计求和，格式: {行: 出现次数}
initSet = createInitSet(simpData)
initSet
# Out:
# OrderedDict([(frozenset({'A', 'B', 'C', 'E', 'F', 'O'}), 1),
#              (frozenset({'A', 'C', 'G'}), 1),
#              (frozenset({'E', 'I'}), 1),
#              (frozenset({'A', 'C', 'D', 'E', 'G'}), 1),
#              (frozenset({'A', 'C', 'E', 'G', 'L'}), 1),
#              (frozenset({'E', 'J'}), 1),
#              (frozenset({'A', 'B', 'C', 'E', 'F', 'P'}), 1),
#              (frozenset({'A', 'C', 'D'}), 1),
#              (frozenset({'A', 'C', 'E', 'G', 'M'}), 1),
#              (frozenset({'A', 'C', 'E', 'G', 'N'}), 1),
#              (frozenset({'A', 'B', 'C'}), 1),
#              (frozenset({'A', 'B', 'D'}), 1)])

# %%
print(len(initSet))
# Out:
# 12

# %%
# part 3 : 创建FP树
'''
createTree(生成FP-tree)
建造树，首先要扫描整个数据库，根据最小支持度，获得频繁1-项集。
然后根据频繁1-项集为每一件事物数据按照降序排序，
并调用update_tree来建造树。
:param dataSet: dist{行: 出现次数}的样本数据
:param minSup: 最小的支持度
:return: retTree  FP-tree
            headerTable 满足minSup {所有的元素+(value, treeNode)}
'''
def createTree(dataSet, minSup=0.1):
    headerTable = {}  # 支持度>=minSup的dist{所有元素: 出现的次数}
    for trans in dataSet:  # 循环 dist{行: 出现次数}的样本数据
        # 对所有的行进行循环，得到行里面的所有元素
        # 统计每一行中，每个元素出现的总次数
        for item in trans:
            # 例如:  {'ababa': 3}  count(a)=3+3+3=9   count(b)=3+3=6
            # 计算每项元素的出现次数
            headerTable[item] = headerTable.get(item, 0) + dataSet[trans]
    # 删除 headerTable中，<最小支持度的元素
    for k in list(headerTable.keys()):  # python3中.keys()返回的是迭代器不是list,不能在遍历时对其改变。
        if (headerTable[k]/(len(dataSet))) < minSup:
            del (headerTable[k]) # 删除不满足最小支持度的元素

    # 开始构建 FP树
    freqItemSet = set(headerTable.keys())  # 满足最小支持度的频繁项集 # 满足minSup: set(各元素集合)

    if len(freqItemSet) == 0: # 如果不存在，直接返回None
        return None, None

    for k in headerTable: # 我们在每个键对应的值中增加一个“None”，为后面的存储相似元素做准备
        headerTable[k] = [headerTable[k], None] # 格式化:  dist{元素key: [元素次数, None]}
    retTree = treeNode('Null Set', 1, None) # create tree

    '''
    读入每个项集也就是每条记录，并将其添加到一条已经存在的路径中。
    如果该路径不存在，则创建一条新路径。
    假设有集合{z,x,y}和{y,z,r}，
    为了保证相同项只出现一次，需要对每条记录里的元素项进行排序。
    在每条记录中，这种排序是根据每个元素出现的次数进行的，也就是说出现次数越多，排位越前。
    '''
    for tranSet, count in dataSet.items(): # 循环 dist{行: 出现次数}的样本数据
        localD = {} # localD = dist{元素key: 元素总出现次数}
        for item in tranSet:
            if item in freqItemSet:# 过滤，只取该样本中满足最小支持度的频繁项
                # 把headerTable中记录的该元素的出现次数赋值给localD中的对应键
                localD[item] = headerTable[item][0]
        # 对每一行的key 进行排序，然后开始往树添加枝丫，直到丰满
        # 第二次，如果在同一个排名下出现，那么就对该枝丫的值进行追加，继续递归调用！
        if len(localD) > 0: #如果该条记录有符合条件的元素
            # 根据全局频数从大到小对单样本排序
            # p=key,value; 所以是通过value值的大小，进行从大到小进行排序
            # orderedItems 表示取出元组的key值，也就是字母本身，但是字母本身是大到小的顺序
            # 元素按照支持度排序，支持度越大，排位越靠前
            orderedItems = [v[0] for v in sorted(localD.items(), key=lambda p: p[1], reverse=True)]
            # 用过滤且排序后的样本更新树
            # 填充树，通过有序的orderedItems的第一位，进行顺序填充 第一层的子节点。
            updateTree(orderedItems, retTree, headerTable, count)
            
    return retTree, headerTable



'''
使用频繁项集使FP树生长 (更新FP-tree，第二次遍历)
更新树是一种递归的思想，首先判断节点是否存在，
如果存在，则节点合并，并且记录节点的个数加一，
否则创建新的节点，并更新项头表。
# 针对每一行的数据
# 最大的key,  添加
:param items: 满足minSup 排序后的元素key的数组（大到小的排序）
:param inTree: 空的Tree对象
:param headerTable: 满足minSup {所有的元素+(value, treeNode)}
:param count: 原数据集中每一组Kay出现的次数
:return: 
'''
def updateTree(items, inTree, headerTable, count):
    # 取出 元素 出现次数最高的
    # 如果该元素在 inTree.children 这个字典中，就进行累加
    # 如果该元素不存在 就 inTree.children 字典中新增key，value为初始化的 treeNode 对象
    if items[0] in inTree.children: #如果inTree的子节点中已经存在该元素
        # 更新 最大元素，对应的 treeNode 对象的count进行叠加，增加的值为该元素所在记录的出现次数
        inTree.children[items[0]].inc(count)
    else:
        # 如果不存在子节点，我们为该inTree添加子节点
        inTree.children[items[0]] = treeNode(items[0], count, inTree)
        # 如果满足minSup的dist字典的value值第二位为null， 我们就设置该元素为 本节点对应的tree节点
        # 如果元素第二位不为null，我们就更新header节点
        if headerTable[items[0]][1] is None: #如果在相似元素的字典headerTable中，该元素键对应的列表值中，起始元素为None
            # headerTable只记录第一次节点出现的位置
            headerTable[items[0]][1] = inTree.children[items[0]] #把新创建的这个节点赋值给起始元素
        else:
            # 本质上是修改headerTable的key对应的Tree，的nodeLink值
            # 如果在相似元素字典headerTable中，该元素键对应的值列表中已经有了起始元素，那么把这个新建的节点放到值列表的最后
            updateHeader(headerTable[items[0]][1], inTree.children[items[0]])
    if len(items) > 1:
        # 递归的调用，在items[0]的基础上，添加item0[1]做子节点， count只要循环的进行累计加和而已，统计出节点的最后的统计值。
        updateTree(items[1::], inTree.children[items[0]], headerTable, count)



"""
更新项头表：
项头表可以使遍历树更加快速，它是一个横向迭代向前并判断的思想。
更新头指针表，确保节点链接指向树中该元素项的每一个实例
(更新头指针，建立相同元素之间的关系，
例如:  左边的r指向右边的r值，就是后出现的相同元素 指向 已经出现的元素)
从头指针的nodeLink开始，一直沿着nodeLink直到到达链表末尾。这就是链表。
性能: 如果链表很长可能会遇到迭代调用的次数限制。
:param nodeToTest: 满足minSup {所有的元素+(value, treeNode)}
:param targetNode: Tree对象的子节点
:return:
"""
def updateHeader(nodeToTest, targetNode):
    while nodeToTest.nodeLink is not None:
        nodeToTest = nodeToTest.nodeLink
    nodeToTest.nodeLink = targetNode

# %%
# part 3 : 创建FP树
# 输入: dist{行: 出现次数}的样本数据  和  最小的支持度
# 输出: 最终的PF-tree，通过循环获取第一层的节点，然后每一层的节点进行递归的获取每一行的字节点，也就是分支。然后所谓的指针，就是后来的指向已存在的
minSup = 0.1
myFPtree, myHeaderTab = createTree(initSet, minSup)
myFPtree.disp()
# Out:
#    Null Set   1
#      A   10
#        C   9
#          E   6
#            B   2
#              F   2
#            G   4
#              D   1
#          G   1
#          D   1
#          B   1
#        B   1
#          D   1
#      E   2

# %%
# part 4 ：挖掘频繁项集
'''
# 挖掘频繁项集
# 递归回溯
(如果存在父节点，就记录当前节点的name值)
#该函数找出元素节点leafNode的所有前缀路径，
并把包括该leafNode及其前缀路径的各个节点的名称保存在prefixPath中
:param leafNode: 查询的节点对于的nodeTree
:param prefixPath: 要查询的节点值
:return:
'''
def ascendTree(leafNode, prefixPath):
    if leafNode.parent is not None:
        prefixPath.append(leafNode.name)
        ascendTree(leafNode.parent, prefixPath)


'''
# 条件模式基
:param basePat: 要查询的节点值
:param treeNode: 查询的节点所在的当前nodeTree
:return:  condPats 对非basePat的倒叙值作为key,赋值为count数
'''
def findPrefixPath(basePat, treeNode):
    condPats = {}
    while treeNode is not None: # 对 treeNode的link进行循环
        prefixPath = []
        ascendTree(treeNode, prefixPath) # 寻找改节点的父节点，相当于找到了该节点的频繁项集
        if len(prefixPath) > 1: # 排除自身这个元素，判断是否存在父元素（所以要>1, 说明存在父元素）
            # 对非basePat的倒叙值作为key,赋值为count数
            # prefixPath[1:] 变frozenset后，字母就变无序了
            # condPats[frozenset(prefixPath)] = treeNode.count
            # 某个元素的前缀路径不包括该元素本身
            condPats[frozenset(prefixPath[1:])] = treeNode.count
        # 递归，寻找改节点的下一个 相同值的链接节点 #下一个相似元素
        treeNode = treeNode.nodeLink
    # condPats存储的是元素节点treeNode及其所有相似元素节点的前缀路径和它的计数
    return condPats

# %%
# part 4 : 挖掘频繁项集
# 抽取条件模式基
# 查询树节点的，频繁子项
print('A --->', findPrefixPath('A', myHeaderTab['A'][1]))
print('B --->', findPrefixPath('B', myHeaderTab['B'][1]))
print('C --->', findPrefixPath('C', myHeaderTab['C'][1]))
# Out:
# A ---> {}
# B ---> {frozenset({'C', 'A', 'E'}): 2, frozenset({'C', 'A'}): 1, frozenset({'A'}): 1}
# C ---> {frozenset({'A'}): 9}

# %%
# part 5 : 递归查找频繁项集
'''
递归查找频繁项集
(创建条件FP树)
:param inTree: myFPtree
:param headerTable: 满足minSup {所有的元素+(value, treeNode)}
:param minSup: 最小支持项集
:param preFix: preFix为newFreqSet上一次的存储记录，一旦没有myHead，就不会更新
:param freqItemList: 用来存储频繁子项的列表
:return:
'''
def mineTree(inTree, headerTable, minSup, preFix, freqItemList):
    # 通过value进行从小到大的排序， 得到频繁项集的key
    # 最小支持项集的key的list集合
    bigL = [v[0] for v in sorted(headerTable.items(), key=lambda p:p[1][0])]

    # 循环遍历 最频繁项集的key，从小到大的递归寻找对应的频繁项集
    for basePat in bigL:
        newFreqSet = preFix.copy() # preFix为newFreqSet上一次的存储记录，一旦没有myHead，就不会更新
        newFreqSet.add(basePat)
        freqItemList.append(newFreqSet)
        condPattBases = findPrefixPath(basePat, headerTable[basePat][1])

        myCondTree, myHead = createTree(condPattBases, minSup)

        # 挖掘条件 FP-tree, 如果myHead不为空，表示满足minSup {所有的元素+(value, treeNode)}
        if myHead != None:
            # print('conditional tree for:', newFreqSet)
            # myCondTree.disp(1)
            # 递归 myHead 找出频繁项集
            mineTree(myCondTree, myHead, minSup, newFreqSet, freqItemList)

# %%
# part 5 : 创建条件模式基
freqItemList = []
mineTree(myFPtree, myHeaderTab, minSup, set([]), freqItemList)
print("freqItemList: \n", freqItemList)
# Out:
# freqItemList:
#  [{'F'}, {'C', 'F'}, {'F', 'A'}, {'C', 'F', 'A'}, {'F', 'B'}, {'C', 'F', 'B'}, {'F', 'B', 'A'}, {'C', 'F', 'B', 'A'}, {'F', 'E'}, {'C', 'F', 'E'}, {'F', 'B', 'E'}, {'C', 'F', 'B', 'E'}, {'F', 'A', 'E'}, {'C', 'F', 'A', 'E'}, {'B', 'F', 'A', 'E'}, {'B', 'A', 'F', 'E', 'C'}, {'D'}, {'G', 'D'}, {'C', 'G', 'D'}, {'G', 'A', 'D'}, {'C', 'G', 'A', 'D'}, {'E', 'D'}, {'C', 'E', 'D'}, {'G', 'E', 'D'}, {'C', 'G', 'E', 'D'}, {'A', 'E', 'D'}, {'C', 'A', 'E', 'D'}, {'G', 'A', 'E', 'D'}, {'G', 'A', 'E', 'D', 'C'}, {'B', 'D'}, {'B', 'A', 'D'}, {'C', 'D'}, {'C', 'A', 'D'}, {'A', 'D'}, {'B'}, {'B', 'E'}, {'C', 'B', 'E'}, {'A', 'B', 'E'}, {'A', 'C', 'B', 'E'}, {'C', 'B'}, {'C', 'B', 'A'}, {'B', 'A'}, {'G'}, {'G', 'E'}, {'C', 'G', 'E'}, {'G', 'A', 'E'}, {'C', 'G', 'A', 'E'}, {'C', 'G'}, {'G', 'A'}, {'C', 'G', 'A'}, {'E'}, {'C', 'E'}, {'A', 'E'}, {'C', 'A', 'E'}, {'C'}, {'C', 'A'}, {'A'}]

# %%
import pandas as pd

supermarket_data_set = pd.read_csv('supermarket.csv')
supermarket_data_set.dropna(inplace = True) 
supermarket_data_set.drop(columns = 'total',inplace=True)

# %%
columns_list = list(supermarket_data_set)
for i in range(len(supermarket_data_set)):
    for j in range(len(supermarket_data_set.columns)):
        if supermarket_data_set.iloc[i,j] == 't':
            supermarket_data_set.iloc[i,j] = columns_list[j]
supermarket_data_set
# Out:
#      'grocery misc'  'baby needs'  'bread and cake'  'baking needs' coupons  \
# 0                 ?  'baby needs'  'bread and cake'  'baking needs'       ?
# 1                 ?             ?                 ?               ?       ?
# 2                 ?             ?  'bread and cake'  'baking needs'       ?
# 3                 ?             ?  'bread and cake'  'baking needs'       ?
# 4                 ?             ?  'bread and cake'  'baking needs'       ?
# ...             ...           ...               ...             ...     ...
# 4622              ?             ?  'bread and cake'  'baking needs'       ?
# 4623              ?             ?  'bread and cake'  'baking needs'       ?
# 4624              ?             ?                 ?               ?       ?
# 4625              ?  'baby needs'                 ?  'baking needs'       ?
# 4626              ?             ?  'bread and cake'               ?       ?
#
#       juice-sat-cord-ms  tea  biscuits  'canned fish-meat'  'canned fruit'  \
# 0     juice-sat-cord-ms    ?  biscuits                   ?               ?
# 1                     ?    ?         ?  'canned fish-meat'  'canned fruit'
# 2     juice-sat-cord-ms    ?  biscuits                   ?  'canned fruit'
# 3     juice-sat-cord-ms    ?  biscuits                   ?               ?
# 4     juice-sat-cord-ms  tea         ?                   ?               ?
# ...                 ...  ...       ...                 ...             ...
# 4622  juice-sat-cord-ms    ?  biscuits                   ?  'canned fruit'
# 4623  juice-sat-cord-ms    ?  biscuits                   ?  'canned fruit'
# 4624                  ?    ?         ?                   ?               ?
# 4625                  ?    ?         ?                   ?               ?
# 4626  juice-sat-cord-ms    ?  biscuits                   ?               ?
#
#       ...  '750ml white nz' '750ml red nz' '750ml white imp' '750ml red imp'  \
# 0     ...  '750ml white nz'              ?                 ?               ?
# 1     ...                 ?              ?                 ?               ?
# 2     ...                 ?              ?                 ?               ?
# 3     ...                 ?              ?                 ?               ?
# 4     ...                 ?              ?                 ?               ?
# ...   ...               ...            ...               ...             ...
# 4622  ...                 ?              ?                 ?               ?
# 4623  ...                 ?              ?                 ?               ?
# 4624  ...                 ?              ?                 ?               ?
# 4625  ...                 ?              ?                 ?               ?
# 4626  ...                 ?              ?                 ?               ?
#
#      'sparkling nz' 'sparkling imp' 'brew kits/accesry' 'port and sherry'  \
# 0                 ?               ?                   ?                 ?
# 1                 ?               ?                   ?                 ?
# 2                 ?               ?                   ?                 ?
# 3                 ?               ?                   ?                 ?
# 4                 ?               ?                   ?                 ?
# ...             ...             ...                 ...               ...
# 4622              ?               ?                   ?                 ?
# 4623              ?               ?                   ?                 ?
# 4624              ?               ?                   ?                 ?
# 4625              ?               ?                   ?                 ?
# 4626              ?               ?                   ?                 ?
#
#      ctrled label wine' 'non host support'
# 0                     ?                  ?
# 1                     ?                  ?
# 2                     ?                  ?
# 3                     ?                  ?
# 4                     ?                  ?
# ...                 ...                ...
# 4622                  ?                  ?
# 4623                  ?                  ?
# 4624                  ?                  ?
# 4625                  ?                  ?
# 4626                  ?                  ?
#
# [4626 rows x 105 columns]

# %%
supermarket_data_set_list = supermarket_data_set.values.tolist()
for i in range(len(supermarket_data_set_list)):
    supermarket_data_set_list[i] = list(filter(lambda x : x != '?', supermarket_data_set_list[i]))
supermarket_data_set_list
# Out:
# [["'baby needs'",
#   "'bread and cake'",
#   "'baking needs'",
#   'juice-sat-cord-ms',
#   'biscuits',
#   "'canned vegetables'",
#   'cleaners-polishers',
#   'coffee',
#   'sauces-gravy-pkle',
#   'confectionary',
#   'dishcloths-scour',
#   "'frozen foods'",
#   "'razor blades'",
#   "'party snack foods'",
#   "'tissues-paper prd'",
#   'wrapping',
#   "'mens toiletries'",
#   'cheese',
#   'milk-cream',
#   'margarine',
#   "'small goods'",
#   'fruit',
#   'vegetables',
#   "'750ml white nz'"],
#  ["'canned fish-meat'",
#   "'canned fruit'",
#   "'canned vegetables'",
#   'sauces-gravy-pkle',
#   'deod-disinfectant',
#   "'frozen foods'",
#   "'pet foods'",
#   "'laundry needs'",
#   "'tissues-paper prd'",
#   'deodorants-soap',
#   'haircare',
#   'milk-cream',
#   'fruit',
#   'vegetables'],
#  ["'bread and cake'",
#   "'baking needs'",
#   'juice-sat-cord-ms',
#   'biscuits',
#   "'canned fruit'",
#   'sauces-gravy-pkle',
#   'puddings-deserts',
#   'wrapping',
#   "'health food other'",
#   "'small goods'",
#   "'dairy foods'",
#   'beef',
#   'lamb',
#   'fruit',
#   'vegetables',
#   'stationary'],
#  ["'bread and cake'",
#   "'baking needs'",
#   'juice-sat-cord-ms',
#   'biscuits',
#   "'canned vegetables'",
#   "'breakfast food'",
#   'cleaners-polishers',
#   "'frozen foods'",
#   'jams-spreads',
#   "'pet foods'",
#   "'party snack foods'",
#   "'tissues-paper prd'",
#   'deodorants-soap',
#   "'mens toiletries'",
#   'cheese',
#   'margarine',
#   "'dairy foods'",
#   'beef',
#   'stationary',
#   "'prepared meals'"],
#  ["'bread and cake'",
#   "'baking needs'",
#   'juice-sat-cord-ms',
#   'tea',
#   'cleaners-polishers',
#   'coffee',
#   'sauces-gravy-pkle',
#   "'frozen foods'",
#   'jams-spreads',
#   "'laundry needs'",
#   'wrapping',
#   'deodorants-soap',
#   'haircare',
#   "'dental needs'",
#   "'meat misc'",
#   'milk-cream',
#   'margarine',
#   'beef',
#   'poultry',
#   'potatoes',
#   'vegetables',
#   'condiments',
#   "'small goods2'"],
#  ["'bread and cake'",
#   "'baking needs'",
#   'juice-sat-cord-ms',
#   'tea',
#   'biscuits',
#   "'canned fruit'",
#   "'canned vegetables'",
#   "'breakfast food'",
#   'cleaners-polishers',
#   'sauces-gravy-pkle',
#   "'tissues-paper prd'",
#   "'soft drinks'",
#   "'sanitary pads'",
#   'cheese',
#   'milk-cream',
#   'margarine',
#   'fruit',
#   'electrical'],
#  ["'baby needs'",
#   "'bread and cake'",
#   "'baking needs'",
#   'juice-sat-cord-ms',
#   'biscuits',
#   "'canned vegetables'",
#   'coffee',
#   'sauces-gravy-pkle',
#   "'frozen foods'",
#   "'pet foods'",
#   "'party snack foods'",
#   "'sanitary pads'",
#   'milk-cream',
#   'fruit',
#   'vegetables'],
#  ['fruit', 'stationary', "'bake off products'", "'750ml red imp'"],
#  ["'bread and cake'",
#   "'baking needs'",
#   'juice-sat-cord-ms',
#   'biscuits',
#   "'canned fruit'",
#   "'canned vegetables'",
#   'sauces-gravy-pkle',
#   'puddings-deserts',
#   'jams-spreads',
#   "'pet foods'",
#   "'party snack foods'",
#   'wrapping',
#   "'dental needs'",
#   'milk-cream',
#   'beef',
#   'fruit',
#   'vegetables',
#   'electrical',
#   "'sparkling nz'"],
#  ["'bread and cake'",
#   "'baking needs'",
#   'juice-sat-cord-ms',
#   'biscuits',
#   "'canned fruit'",
#   "'canned vegetables'",
#   "'breakfast food'",
#   'coffee',
#   'dishcloths-scour',
#   "'frozen foods'",
#   "'pet foods'",
#   "'laundry needs'",
#   'haircare',
#   "'dental needs'",
#   'cheese',
#   'milk-cream',
#   'margarine',
#   'beef',
#   'pork',
#   'poultry',
#   'fruit',
#   'vegetables',
#   "'small goods2'"],
#  ["'bread and cake'",
#   "'baking needs'",
#   'juice-sat-cord-ms',
#   "'canned fish-meat'",
#   "'canned fruit'",
#   "'canned vegetables'",
#   'puddings-deserts',
#   'jams-spreads',
#   "'laundry needs'",
#   "'beverages hot'",
#   'deodorants-soap',
#   'lotions-creams',
#   'cough-cold-pain',
#   'cheese',
#   'margarine',
#   'beef',
#   "'pet food'",
#   'fruit',
#   'vegetables'],
#  ["'grocery misc'",
#   "'baby needs'",
#   "'bread and cake'",
#   "'baking needs'",
#   'juice-sat-cord-ms',
#   'biscuits',
#   "'breakfast food'",
#   "'cigs-tobacco pkts'",
#   'coffee',
#   'sauces-gravy-pkle',
#   "'frozen foods'",
#   'jams-spreads',
#   "'laundry needs'",
#   "'party snack foods'",
#   "'pkt-canned soup'",
#   'margarine',
#   "'dairy foods'"],
#  ["'baking needs'",
#   'puddings-deserts',
#   'jams-spreads',
#   "'party snack foods'",
#   'haircare',
#   'lotions-creams',
#   "'produce misc'",
#   'fruit',
#   'vegetables',
#   "'prepared meals'"],
#  ["'bread and cake'",
#   'juice-sat-cord-ms',
#   'biscuits',
#   "'breakfast food'",
#   'sauces-gravy-pkle',
#   "'pet foods'",
#   "'party snack foods'",
#   'cheese',
#   'milk-cream',
#   "'deli gourmet'",
#   "'dairy foods'",
#   'fruit',
#   'vegetables',
#   "'variety misc'",
#   'kitchen',
#   'stationary',
#   "'imported cheese'"],
#  ["'bread and cake'",
#   "'baking needs'",
#   'juice-sat-cord-ms',
#   'tea',
#   'biscuits',
#   "'canned fruit'",
#   "'canned vegetables'",
#   "'breakfast food'",
#   'sauces-gravy-pkle',
#   'dishcloths-scour',
#   "'frozen foods'",
#   "'fuels-garden aids'",
#   "'pet foods'",
#   "'laundry needs'",
#   "'party snack foods'",
#   "'tissues-paper prd'",
#   'wrapping',
#   "'pkt-canned soup'",
#   "'soft drinks'",
#   'haircare',
#   "'dental needs'",
#   'margarine',
#   "'small goods'",
#   'poultry',
#   'fruit',
#   'vegetables',
#   'stationary',
#   "'prepared meals'",
#   "'bake off products'",
#   "'small goods2'"],
#  ['juice-sat-cord-ms',
#   'tea',
#   'biscuits',
#   "'canned fruit'",
#   'deod-disinfectant',
#   "'frozen foods'",
#   "'party snack foods'",
#   'cheese',
#   'cold-meats',
#   'margarine',
#   'beef',
#   "'variety misc'",
#   'stationary'],
#  ["'bread and cake'",
#   'biscuits',
#   'fruit',
#   'vegetables',
#   "'casks white wine'",
#   "'sparkling nz'"],
#  ["'grocery misc'",
#   "'baby needs'",
#   "'baking needs'",
#   "'breakfast food'",
#   "'cigs-tobacco pkts'",
#   'cleaners-polishers',
#   'coffee',
#   'sauces-gravy-pkle',
#   "'laundry needs'",
#   "'party snack foods'",
#   'wrapping',
#   "'beverages hot'",
#   'milk-cream',
#   'margarine',
#   'fruit',
#   'potatoes',
#   'vegetables',
#   'condiments',
#   "'bake off products'"],
#  ['biscuits',
#   "'canned fish-meat'",
#   'sauces-gravy-pkle',
#   'confectionary',
#   "'frozen foods'",
#   "'party snack foods'",
#   'fruit',
#   "'prepared meals'",
#   "'cooking oils'"],
#  ["'grocery misc'",
#   "'bread and cake'",
#   'biscuits',
#   "'cigs-tobacco pkts'",
#   'sauces-gravy-pkle',
#   "'frozen foods'",
#   "'pet foods'",
#   'cheese',
#   'milk-cream',
#   "'deli gourmet'",
#   'margarine',
#   "'small goods'",
#   "'dairy foods'",
#   'beef',
#   'pork',
#   "'produce misc'",
#   'fruit',
#   'vegetables',
#   'stationary',
#   'offal'],
#  ["'bread and cake'",
#   "'baking needs'",
#   'juice-sat-cord-ms',
#   'tea',
#   'biscuits',
#   "'canned vegetables'",
#   "'breakfast food'",
#   'sauces-gravy-pkle',
#   'confectionary',
#   'puddings-deserts',
#   'dishcloths-scour',
#   "'frozen foods'",
#   'jams-spreads',
#   "'pet foods'",
#   "'laundry needs'",
#   "'party snack foods'",
#   "'tissues-paper prd'",
#   'wrapping',
#   'deodorants-soap',
#   "'dental needs'",
#   'cheese',
#   'milk-cream',
#   'cold-meats',
#   'margarine',
#   "'small goods'",
#   "'dairy foods'",
#   'beef',
#   'lamb',
#   "'pet food'",
#   'fruit',
#   'potatoes',
#   'vegetables',
#   'electrical',
#   'manchester',
#   'plasticware',
#   'stationary',
#   "'prepared meals'",
#   "'cooking oils'",
#   "'bake off products'",
#   "'small goods2'"],
#  ["'baking needs'",
#   'biscuits',
#   'cleaners-polishers',
#   'sauces-gravy-pkle',
#   'confectionary',
#   "'frozen foods'",
#   "'party snack foods'",
#   "'tissues-paper prd'",
#   'cheese',
#   'milk-cream',
#   'margarine',
#   'pork',
#   'poultry',
#   'fruit',
#   'vegetables',
#   "'small goods2'"],
#  ["'bread and cake'",
#   'juice-sat-cord-ms',
#   'biscuits',
#   "'canned fish-meat'",
#   'sauces-gravy-pkle',
#   "'frozen foods'",
#   "'laundry needs'",
#   "'party snack foods'",
#   "'soft drinks'",
#   "'mens toiletries'",
#   'lotions-creams',
#   'margarine',
#   "'dairy foods'",
#   'fruit',
#   'vegetables'],
#  ["'bread and cake'",
#   "'baking needs'",
#   'tea',
#   'sauces-gravy-pkle',
#   "'laundry needs'",
#   "'tissues-paper prd'",
#   "'beverages hot'",
#   'milk-cream',
#   'beef',
#   'lamb',
#   'fruit',
#   "'small goods2'"],
#  ["'bread and cake'",
#   "'baking needs'",
#   'juice-sat-cord-ms',
#   'biscuits',
#   "'canned fruit'",
#   "'canned vegetables'",
#   "'breakfast food'",
#   'cleaners-polishers',
#   'puddings-deserts',
#   'dishcloths-scour',
#   "'frozen foods'",
#   'insecticides',
#   "'pet foods'",
#   "'laundry needs'",
#   "'tissues-paper prd'",
#   'milk-cream',
#   'cold-meats',
#   "'dairy foods'",
#   'fruit',
#   'vegetables',
#   'brushware',
#   'electrical'],
#  ["'bread and cake'",
#   "'baking needs'",
#   'juice-sat-cord-ms',
#   "'canned vegetables'",
#   "'breakfast food'",
#   "'cigs-tobacco pkts'",
#   "'frozen foods'",
#   "'tissues-paper prd'",
#   'deodorants-soap',
#   'cheese',
#   'milk-cream',
#   'margarine',
#   'fruit',
#   'potatoes',
#   'vegetables',
#   "'prepared meals'",
#   "'small goods2'"],
#  ["'bread and cake'",
#   "'baking needs'",
#   'juice-sat-cord-ms',
#   'biscuits',
#   "'canned vegetables'",
#   "'breakfast food'",
#   'sauces-gravy-pkle',
#   'confectionary',
#   'puddings-deserts',
#   'dishcloths-scour',
#   'deod-disinfectant',
#   "'frozen foods'",
#   "'laundry needs'",
#   "'party snack foods'",
#   "'tissues-paper prd'",
#   'wrapping',
#   "'soft drinks'",
#   "'beverages hot'",
#   'deodorants-soap',
#   "'mens toiletries'",
#   'haircare',
#   "'dental needs'",
#   'cheese',
#   "'small goods'",
#   "'dairy foods'",
#   "'pet food'",
#   'fruit',
#   'stationary',
#   "'small goods2'"],
#  ["'baking needs'",
#   'tea',
#   'confectionary',
#   'deod-disinfectant',
#   "'frozen foods'",
#   "'fuels-garden aids'",
#   "'party snack foods'",
#   'cheese',
#   "'dairy foods'",
#   "'variety misc'"],
#  ["'bread and cake'",
#   "'baking needs'",
#   'juice-sat-cord-ms',
#   'biscuits',
#   "'canned vegetables'",
#   'coffee',
#   'confectionary',
#   "'pet foods'",
#   "'party snack foods'",
#   "'tissues-paper prd'",
#   'deodorants-soap',
#   "'dental needs'",
#   'milk-cream'],
#  ['juice-sat-cord-ms',
#   'tea',
#   "'canned fish-meat'",
#   'coffee',
#   'jams-spreads',
#   'insecticides',
#   "'pet foods'",
#   "'laundry needs'",
#   "'tissues-paper prd'",
#   "'pkt-canned soup'",
#   'deodorants-soap',
#   'haircare',
#   "'dental needs'",
#   'fruit',
#   "'cooking oils'",
#   "'non host support'"],
#  ["'bread and cake'",
#   'biscuits',
#   "'canned fruit'",
#   "'canned vegetables'",
#   "'breakfast food'",
#   "'frozen foods'",
#   "'party snack foods'",
#   'wrapping',
#   'lotions-creams',
#   'cheese',
#   'fruit',
#   'kitchen',
#   "'bake off products'"],
#  ["'bread and cake'",
#   'biscuits',
#   "'canned fruit'",
#   "'canned vegetables'",
#   'cleaners-polishers',
#   "'frozen foods'",
#   "'party snack foods'",
#   "'soft drinks'",
#   'margarine',
#   'beef',
#   'fruit',
#   'vegetables',
#   'haberdashery',
#   'kitchen',
#   "'prepared meals'",
#   "'port and sherry'"],
#  ["'baby needs'",
#   "'bread and cake'",
#   "'baking needs'",
#   'juice-sat-cord-ms',
#   'tea',
#   'biscuits',
#   "'breakfast food'",
#   'cleaners-polishers',
#   'coffee',
#   'confectionary',
#   "'frozen foods'",
#   'jams-spreads',
#   "'pet foods'",
#   "'party snack foods'",
#   "'tissues-paper prd'",
#   "'soft drinks'",
#   'haircare',
#   'cheese',
#   'margarine',
#   'beef',
#   'lamb',
#   'pork',
#   'fruit',
#   'vegetables',
#   'plasticware',
#   "'small goods2'"],
#  ["'bread and cake'",
#   'biscuits',
#   'jams-spreads',
#   "'party snack foods'",
#   'haircare',
#   'milk-cream',
#   "'delicatessen misc'",
#   'fruit',
#   'vegetables',
#   "'small goods2'"],
#  ["'baby needs'",
#   "'bread and cake'",
#   "'baking needs'",
#   "'canned fruit'",
#   "'breakfast food'",
#   'cleaners-polishers',
#   'spices',
#   'jams-spreads',
#   'haircare',
#   'cheese',
#   'milk-cream',
#   'margarine',
#   'fruit',
#   'stationary'],
#  ["'bread and cake'",
#   "'baking needs'",
#   'tea',
#   'biscuits',
#   "'canned fish-meat'",
#   "'canned vegetables'",
#   'cleaners-polishers',
#   'coffee',
#   'sauces-gravy-pkle',
#   'confectionary',
#   "'frozen foods'",
#   'spices',
#   'jams-spreads',
#   'insecticides',
#   "'pet foods'",
#   "'laundry needs'",
#   "'party snack foods'",
#   "'soft drinks'",
#   "'beverages hot'",
#   'deodorants-soap',
#   'haircare',
#   "'sanitary pads'",
#   'cheese',
#   'milk-cream',
#   "'deli gourmet'",
#   'margarine',
#   "'dairy foods'",
#   'beef',
#   'poultry',
#   'fruit',
#   'vegetables',
#   'brushware',
#   'stationary',
#   "'prepared meals'"],
#  ["'bread and cake'",
#   "'canned fish-meat'",
#   "'canned vegetables'",
#   "'cigs-tobacco pkts'",
#   'coffee',
#   'sauces-gravy-pkle',
#   'deod-disinfectant',
#   "'frozen foods'",
#   'spices',
#   "'laundry needs'",
#   "'tissues-paper prd'",
#   'deodorants-soap',
#   'cheese',
#   'margarine',
#   'fruit',
#   'vegetables',
#   "'prepared meals'",
#   'condiments'],
#  ['juice-sat-cord-ms',
#   'biscuits',
#   "'breakfast food'",
#   'coffee',
#   'sauces-gravy-pkle',
#   'confectionary',
#   'puddings-deserts',
#   "'frozen foods'",
#   "'pet foods'",
#   "'party snack foods'",
#   'wrapping',
#   "'soft drinks'",
#   "'health&beauty misc'",
#   'deodorants-soap',
#   "'mens toiletries'",
#   'haircare',
#   "'dental needs'",
#   'cough-cold-pain',
#   'milk-cream',
#   'margarine',
#   "'dairy foods'",
#   'fruit',
#   'vegetables',
#   'stationary'],
#  ["'baby needs'",
#   "'bread and cake'",
#   "'baking needs'",
#   'juice-sat-cord-ms',
#   'tea',
#   'biscuits',
#   "'canned fish-meat'",
#   "'canned fruit'",
#   "'breakfast food'",
#   'cleaners-polishers',
#   'coffee',
#   'sauces-gravy-pkle',
#   'confectionary',
#   'jams-spreads',
#   "'pet foods'",
#   "'laundry needs'",
#   "'tissues-paper prd'",
#   'wrapping',
#   "'soft drinks'",
#   'deodorants-soap',
#   'haircare',
#   "'dental needs'",
#   'cheese',
#   'milk-cream',
#   'margarine',
#   "'dairy foods'",
#   "'pet food'",
#   'fruit',
#   'vegetables',
#   'kitchen',
#   'stationary',
#   "'cooking oils'",
#   "'bake off products'"],
#  ["'bread and cake'",
#   "'cigs-tobacco pkts'",
#   "'frozen foods'",
#   'wrapping',
#   "'dental needs'",
#   'milk-cream',
#   "'variety misc'",
#   "'prepared meals'"],
#  ["'baby needs'",
#   "'bread and cake'",
#   "'baking needs'",
#   'juice-sat-cord-ms',
#   'tea',
#   'biscuits',
#   "'canned fruit'",
#   "'canned vegetables'",
#   "'breakfast food'",
#   'sauces-gravy-pkle',
#   'confectionary',
#   'deod-disinfectant',
#   "'frozen foods'",
#   "'fuels-garden aids'",
#   'jams-spreads',
#   "'pet foods'",
#   "'laundry needs'",
#   "'party snack foods'",
#   "'tissues-paper prd'",
#   'deodorants-soap',
#   'haircare',
#   "'dental needs'",
#   "'sanitary pads'",
#   'cheese',
#   'margarine',
#   "'dairy foods'",
#   'beef',
#   'fruit',
#   'vegetables',
#   'electrical',
#   'plasticware',
#   'stationary',
#   "'prepared meals'"],
#  ["'baking needs'",
#   'biscuits',
#   "'canned vegetables'",
#   'coffee',
#   'confectionary',
#   'deod-disinfectant',
#   'jams-spreads',
#   "'pet foods'",
#   "'laundry needs'",
#   "'tissues-paper prd'",
#   'wrapping',
#   'deodorants-soap',
#   'haircare',
#   "'dental needs'",
#   'lotions-creams',
#   'milk-cream',
#   'margarine',
#   "'small goods'",
#   'beef',
#   'lamb',
#   "'pet food'",
#   'fruit',
#   'vegetables',
#   'electrical'],
#  ["'bread and cake'",
#   "'baking needs'",
#   'juice-sat-cord-ms',
#   'sauces-gravy-pkle',
#   'spices',
#   'jams-spreads',
#   "'soft drinks'",
#   'haircare',
#   'cheese',
#   'margarine',
#   "'small goods'",
#   "'produce misc'",
#   'vegetables',
#   'electrical',
#   "'prepared meals'",
#   'condiments',
#   "'small goods2'"],
#  ["'baking needs'",
#   'biscuits',
#   'confectionary',
#   "'party snack foods'",
#   "'tissues-paper prd'",
#   "'soft drinks'",
#   'potatoes',
#   'kitchen',
#   'stationary'],
#  ["'bread and cake'", 'milk-cream', "'variety misc'", 'kitchen'],
#  ["'bread and cake'",
#   "'baking needs'",
#   'juice-sat-cord-ms',
#   'biscuits',
#   "'breakfast food'",
#   'confectionary',
#   "'frozen foods'",
#   "'fuels-garden aids'",
#   'spices',
#   "'party snack foods'",
#   'wrapping',
#   "'dried vegetables'",
#   'medicines',
#   'lotions-creams',
#   'cough-cold-pain',
#   'cheese',
#   'milk-cream',
#   'fruit'],
#  ["'baking needs'",
#   'biscuits',
#   'sauces-gravy-pkle',
#   "'tissues-paper prd'",
#   'cheese',
#   'milk-cream',
#   'margarine',
#   "'dairy foods'",
#   'poultry',
#   'fruit',
#   'electrical',
#   'stationary',
#   'condiments',
#   "'port and sherry'"],
#  ["'baking needs'",
#   'juice-sat-cord-ms',
#   "'breakfast food'",
#   'spices',
#   'wrapping',
#   "'sanitary pads'",
#   'cheese',
#   'fruit',
#   "'variety misc'",
#   'kitchen',
#   "'cooking oils'"],
#  ["'baby needs'",
#   'juice-sat-cord-ms',
#   'tea',
#   'biscuits',
#   "'canned fish-meat'",
#   "'canned fruit'",
#   "'canned vegetables'",
#   "'breakfast food'",
#   'sauces-gravy-pkle',
#   'confectionary',
#   "'frozen foods'",
#   "'razor blades'",
#   'jams-spreads',
#   "'pet foods'",
#   "'laundry needs'",
#   "'party snack foods'",
#   "'tissues-paper prd'",
#   "'mens toiletries'",
#   'cheese',
#   'margarine',
#   "'dairy foods'",
#   'beef',
#   'pork',
#   'potatoes'],
#  ["'grocery misc'",
#   "'cigs-tobacco pkts'",
#   "'party snack foods'",
#   'pork',
#   'poultry',
#   'stationary'],
#  ["'baking needs'",
#   'tea',
#   'biscuits',
#   "'canned fruit'",
#   "'canned vegetables'",
#   "'breakfast food'",
#   'cleaners-polishers',
#   'sauces-gravy-pkle',
#   'confectionary',
#   'dishcloths-scour',
#   "'frozen foods'",
#   'jams-spreads',
#   "'laundry needs'",
#   "'tissues-paper prd'",
#   "'health food other'",
#   'deodorants-soap',
#   "'dental needs'",
#   'cough-cold-pain',
#   'cheese',
#   "'pet food'",
#   'potatoes',
#   'vegetables'],
#  ["'bread and cake'",
#   "'baking needs'",
#   'juice-sat-cord-ms',
#   'tea',
#   'biscuits',
#   "'canned fish-meat'",
#   'coffee',
#   'sauces-gravy-pkle',
#   'puddings-deserts',
#   "'frozen foods'",
#   "'laundry needs'",
#   "'party snack foods'",
#   "'tissues-paper prd'",
#   'cheese',
#   'milk-cream',
#   "'dairy foods'",
#   'fruit',
#   'haberdashery',
#   'stationary'],
#  ["'bread and cake'",
#   'biscuits',
#   "'cigs-tobacco pkts'",
#   'insecticides',
#   "'laundry needs'",
#   "'party snack foods'",
#   "'tissues-paper prd'",
#   "'pet food'",
#   'fruit',
#   'vegetables',
#   "'bake off products'"],
#  ["'baby needs'",
#   "'bread and cake'",
#   "'baking needs'",
#   'juice-sat-cord-ms',
#   "'canned fish-meat'",
#   "'canned vegetables'",
#   'coffee',
#   "'pet foods'",
#   "'laundry needs'",
#   "'party snack foods'",
#   'milk-cream',
#   'margarine',
#   "'small goods'",
#   'lamb',
#   'poultry',
#   'fruit',
#   'vegetables',
#   'plasticware',
#   'stationary',
#   "'cooking oils'"],
#  ["'bread and cake'",
#   "'baking needs'",
#   'juice-sat-cord-ms',
#   'biscuits',
#   "'canned fish-meat'",
#   "'canned vegetables'",
#   'puddings-deserts',
#   'wrapping',
#   'haircare',
#   'cheese',
#   'milk-cream',
#   'beef',
#   'potatoes',
#   'vegetables',
#   "'cooking oils'"],
#  ["'baby needs'",
#   "'bread and cake'",
#   "'baking needs'",
#   'juice-sat-cord-ms',
#   "'canned fruit'",
#   "'breakfast food'",
#   'cleaners-polishers',
#   'puddings-deserts',
#   "'frozen foods'",
#   'jams-spreads',
#   "'laundry needs'",
#   "'party snack foods'",
#   "'tissues-paper prd'",
#   'wrapping',
#   'deodorants-soap',
#   "'dental needs'",
#   "'sanitary pads'",
#   'cheese',
#   'milk-cream',
#   'cold-meats',
#   'margarine',
#   "'dairy foods'",
#   'beef',
#   'lamb',
#   'fruit',
#   'potatoes',
#   'vegetables',
#   "'small goods2'",
#   "'trim pork'"],
#  ["'bread and cake'",
#   'cleaners-polishers',
#   'sauces-gravy-pkle',
#   "'frozen foods'",
#   'spices',
#   "'tissues-paper prd'",
#   "'pkt-canned soup'",
#   "'health food other'",
#   "'beverages hot'",
#   'milk-cream',
#   'margarine',
#   "'dairy foods'"],
#  ["'bread and cake'",
#   "'baking needs'",
#   'tea',
#   'biscuits',
#   "'canned fruit'",
#   "'cigarette cartons'",
#   'cleaners-polishers',
#   "'frozen foods'",
#   "'fuels-garden aids'",
#   'jams-spreads',
#   "'tissues-paper prd'",
#   'fruit',
#   'vegetables'],
#  ["'grocery misc'",
#   "'baby needs'",
#   "'bread and cake'",
#   "'baking needs'",
#   'biscuits',
#   "'canned vegetables'",
#   "'cigs-tobacco pkts'",
#   "'party snack foods'",
#   "'soft drinks'",
#   'deodorants-soap',
#   'cheese',
#   'beef',
#   'fruit',
#   "'prepared meals'"],
#  ["'bread and cake'",
#   'biscuits',
#   "'breakfast food'",
#   'cleaners-polishers',
#   'deod-disinfectant',
#   "'pet foods'",
#   "'tissues-paper prd'",
#   'deodorants-soap',
#   'haircare',
#   'milk-cream',
#   'poultry',
#   'vegetables'],
#  ["'baking needs'",
#   'biscuits',
#   "'canned fish-meat'",
#   "'canned vegetables'",
#   "'frozen foods'",
#   'spices',
#   'jams-spreads',
#   "'tissues-paper prd'",
#   "'pkt-canned soup'",
#   'cheese',
#   'margarine',
#   "'small goods'",
#   'beef',
#   'fruit',
#   'vegetables',
#   "'variety misc'",
#   "'imported cheese'"],
#  ['juice-sat-cord-ms',
#   "'breakfast food'",
#   'cleaners-polishers',
#   'confectionary',
#   "'frozen foods'",
#   "'laundry needs'",
#   "'party snack foods'",
#   "'tissues-paper prd'",
#   'medicines',
#   "'dental needs'",
#   'cheese',
#   "'dairy foods'",
#   'beef',
#   'lamb',
#   "'produce misc'",
#   'fruit',
#   'vegetables'],
#  ["'bread and cake'",
#   "'baking needs'",
#   "'canned fish-meat'",
#   "'canned fruit'",
#   "'breakfast food'",
#   'sauces-gravy-pkle',
#   'deod-disinfectant',
#   "'frozen foods'",
#   "'pet foods'",
#   "'laundry needs'",
#   "'tissues-paper prd'",
#   'wrapping',
#   "'beverages hot'",
#   "'meat misc'",
#   'cheese',
#   'margarine',
#   'fruit',
#   'vegetables',
#   'stationary',
#   "'bake off products'"],
#  ["'grocery misc'",
#   "'bread and cake'",
#   "'baking needs'",
#   'tea',
#   'biscuits',
#   "'cigs-tobacco pkts'",
#   'coffee',
#   'confectionary',
#   "'frozen foods'",
#   'jams-spreads',
#   "'pet foods'",
#   'wrapping',
#   "'soft drinks'",
#   "'beverages hot'",
#   'milk-cream',
#   'margarine',
#   "'small goods'",
#   'fruit',
#   'plants',
#   'stationary',
#   "'bake off products'"],
#  ["'bread and cake'",
#   "'baking needs'",
#   'juice-sat-cord-ms',
#   "'canned fruit'",
#   "'canned vegetables'",
#   "'breakfast food'",
#   'coffee',
#   'sauces-gravy-pkle',
#   'dishcloths-scour',
#   "'frozen foods'",
#   'spices',
#   "'laundry needs'",
#   "'health food other'",
#   "'beverages hot'",
#   'haircare',
#   'cheese',
#   'milk-cream',
#   'margarine',
#   'fruit',
#   'vegetables',
#   "'prepared meals'",
#   "'bake off products'"],
#  ["'baby needs'",
#   "'bread and cake'",
#   "'baking needs'",
#   'juice-sat-cord-ms',
#   'biscuits',
#   "'breakfast food'",
#   'coffee',
#   'sauces-gravy-pkle',
#   'confectionary',
#   'puddings-deserts',
#   "'frozen foods'",
#   'jams-spreads',
#   "'laundry needs'",
#   "'party snack foods'",
#   'deodorants-soap',
#   'lotions-creams',
#   'cheese',
#   'milk-cream',
#   'margarine',
#   "'small goods'",
#   "'dairy foods'",
#   'poultry',
#   'fruit',
#   'vegetables',
#   "'variety misc'",
#   'kitchen',
#   'stationary',
#   "'prepared meals'",
#   "'cooking oils'",
#   "'bake off products'",
#   "'small goods2'",
#   "'casks white wine'"],
#  ["'baby needs'",
#   "'bread and cake'",
#   "'baking needs'",
#   'juice-sat-cord-ms',
#   'biscuits',
#   "'canned fish-meat'",
#   "'canned vegetables'",
#   "'frozen foods'",
#   "'party snack foods'",
#   'deodorants-soap',
#   'cheese',
#   'margarine',
#   "'dairy foods'",
#   'fruit',
#   'vegetables',
#   'brushware',
#   'haberdashery',
#   'kitchen',
#   "'prepared meals'",
#   'condiments',
#   "'cooking oils'"],
#  ["'bread and cake'",
#   "'baking needs'",
#   'juice-sat-cord-ms',
#   'tea',
#   'biscuits',
#   "'canned fish-meat'",
#   "'canned fruit'",
#   "'breakfast food'",
#   'cleaners-polishers',
#   'coffee',
#   'sauces-gravy-pkle',
#   'confectionary',
#   "'pet foods'",
#   "'laundry needs'",
#   "'party snack foods'",
#   "'tissues-paper prd'",
#   'wrapping',
#   "'soft drinks'",
#   "'beverages hot'",
#   'deodorants-soap',
#   'haircare',
#   "'sanitary pads'",
#   'milk-cream',
#   'beef',
#   'stationary',
#   "'small goods2'"],
#  ["'bread and cake'",
#   "'baking needs'",
#   'juice-sat-cord-ms',
#   'biscuits',
#   "'breakfast food'",
#   'sauces-gravy-pkle',
#   "'frozen foods'",
#   "'fuels-garden aids'",
#   "'pet foods'",
#   "'laundry needs'",
#   "'party snack foods'",
#   "'tissues-paper prd'",
#   'wrapping',
#   "'soft drinks'",
#   'cheese',
#   'milk-cream',
#   "'small goods'",
#   'fruit',
#   'vegetables',
#   "'variety misc'"],
#  ["'bread and cake'",
#   "'baking needs'",
#   'tea',
#   'biscuits',
#   "'pet foods'",
#   "'tissues-paper prd'",
#   "'pkt-canned soup'",
#   'deodorants-soap',
#   "'dental needs'",
#   'cheese',
#   'milk-cream',
#   'margarine',
#   "'small goods'",
#   "'dairy foods'",
#   'beef',
#   'lamb',
#   "'pet food'",
#   'pork',
#   'fruit',
#   'potatoes',
#   'vegetables',
#   'stationary'],
#  ["'bread and cake'",
#   "'baking needs'",
#   'biscuits',
#   'cleaners-polishers',
#   'coffee',
#   "'laundry needs'",
#   "'party snack foods'",
#   "'soft drinks'",
#   "'sanitary pads'",
#   'milk-cream',
#   'margarine',
#   "'dairy foods'",
#   'fruit',
#   'potatoes',
#   'vegetables',
#   'stationary',
#   "'small goods2'"],
#  ["'bread and cake'",
#   'juice-sat-cord-ms',
#   'biscuits',
#   "'canned vegetables'",
#   "'breakfast food'",
#   'sauces-gravy-pkle',
#   'confectionary',
#   "'frozen foods'",
#   'jams-spreads',
#   "'party snack foods'",
#   'wrapping',
#   'cheese',
#   'milk-cream',
#   "'dairy foods'",
#   'beef',
#   'lamb',
#   'poultry',
#   'fruit',
#   'potatoes',
#   'vegetables',
#   "'prepared meals'",
#   'condiments',
#   "'imported cheese'"],
#  ["'bread and cake'",
#   "'baking needs'",
#   'biscuits',
#   "'canned fish-meat'",
#   "'canned fruit'",
#   "'canned vegetables'",
#   'coffee',
#   'sauces-gravy-pkle',
#   'confectionary',
#   "'frozen foods'",
#   "'pet foods'",
#   "'laundry needs'",
#   "'party snack foods'",
#   'wrapping',
#   "'soft drinks'",
#   'cheese',
#   'milk-cream',
#   'margarine',
#   'fruit',
#   'vegetables',
#   'brushware',
#   'stationary'],
#  ["'bread and cake'",
#   "'baking needs'",
#   'juice-sat-cord-ms',
#   'biscuits',
#   "'canned vegetables'",
#   "'breakfast food'",
#   'cleaners-polishers',
#   'sauces-gravy-pkle',
#   'confectionary',
#   'puddings-deserts',
#   'dishcloths-scour',
#   "'frozen foods'",
#   "'fuels-garden aids'",
#   'spices',
#   'jams-spreads',
#   "'laundry needs'",
#   "'party snack foods'",
#   "'tissues-paper prd'",
#   "'pkt-canned soup'",
#   "'soft drinks'",
#   'deodorants-soap',
#   "'mens toiletries'",
#   'haircare',
#   'lotions-creams',
#   'cheese',
#   'milk-cream',
#   'margarine',
#   "'small goods'",
#   'pork',
#   "'prepared meals'",
#   "'preserving needs'",
#   "'cooking oils'",
#   "'trim pork'"],
#  ["'bread and cake'",
#   'biscuits',
#   "'canned fish-meat'",
#   "'canned vegetables'",
#   'cleaners-polishers',
#   'sauces-gravy-pkle',
#   'deod-disinfectant',
#   "'fuels-garden aids'",
#   "'party snack foods'",
#   "'tissues-paper prd'",
#   "'beverages hot'",
#   'haircare',
#   'lotions-creams',
#   'lamb',
#   'brushware',
#   "'small goods2'"],
#  ['juice-sat-cord-ms',
#   "'cigs-tobacco pkts'",
#   "'soft drinks'",
#   'fruit',
#   'vegetables',
#   "'750ml white imp'"],
#  ['juice-sat-cord-ms',
#   "'canned fish-meat'",
#   "'canned vegetables'",
#   'cleaners-polishers',
#   'coffee',
#   'sauces-gravy-pkle',
#   "'laundry needs'",
#   "'party snack foods'",
#   "'tissues-paper prd'",
#   "'pkt-canned soup'",
#   "'soft drinks'",
#   'deodorants-soap',
#   "'dental needs'",
#   'cheese',
#   'margarine',
#   "'pet food'",
#   'potatoes',
#   'vegetables',
#   'condiments',
#   "'cooking oils'",
#   "'small goods2'",
#   "'casks white wine'",
#   "'750ml white nz'"],
#  ["'bread and cake'",
#   "'baking needs'",
#   'juice-sat-cord-ms',
#   'biscuits',
#   "'canned vegetables'",
#   "'breakfast food'",
#   'cleaners-polishers',
#   'coffee',
#   'sauces-gravy-pkle',
#   'confectionary',
#   "'frozen foods'",
#   "'laundry needs'",
#   "'tissues-paper prd'",
#   "'soft drinks'",
#   'deodorants-soap',
#   "'dental needs'",
#   "'sanitary pads'",
#   'cough-cold-pain',
#   "'dairy foods'",
#   'fruit',
#   'vegetables',
#   'stationary',
#   "'prepared meals'",
#   "'bake off products'"],
#  ["'bread and cake'",
#   'biscuits',
#   "'canned vegetables'",
#   "'breakfast food'",
#   'jams-spreads',
#   'insecticides',
#   'deodorants-soap',
#   'milk-cream',
#   'beef',
#   'poultry',
#   'fruit',
#   'vegetables',
#   'stationary'],
#  ["'baking needs'",
#   "'breakfast food'",
#   "'frozen foods'",
#   "'pet foods'",
#   "'party snack foods'",
#   "'tissues-paper prd'",
#   'wrapping',
#   'deodorants-soap',
#   "'mens toiletries'",
#   'milk-cream',
#   "'pet food'",
#   'fruit',
#   'potatoes',
#   'vegetables',
#   'stationary'],
#  ["'grocery misc'", "'cigs-tobacco pkts'"],
#  ["'bread and cake'",
#   "'baking needs'",
#   'biscuits',
#   "'canned fruit'",
#   'coffee',
#   'sauces-gravy-pkle',
#   'confectionary',
#   'puddings-deserts',
#   'deod-disinfectant',
#   "'frozen foods'",
#   "'pet foods'",
#   "'tissues-paper prd'",
#   'wrapping',
#   'haircare',
#   'milk-cream',
#   'fruit',
#   'vegetables',
#   'kitchen',
#   'condiments'],
#  [],
#  ["'baby needs'",
#   "'bread and cake'",
#   "'baking needs'",
#   'juice-sat-cord-ms',
#   'biscuits',
#   "'canned vegetables'",
#   "'cigs-tobacco pkts'",
#   'coffee',
#   'sauces-gravy-pkle',
#   'confectionary',
#   'puddings-deserts',
#   "'frozen foods'",
#   'jams-spreads',
#   "'laundry needs'",
#   "'party snack foods'",
#   "'tissues-paper prd'",
#   "'soft drinks'",
#   'medicines',
#   "'sanitary pads'",
#   'cough-cold-pain',
#   'cheese',
#   'margarine',
#   'fruit',
#   'kitchen',
#   "'prepared meals'",
#   "'preserving needs'",
#   "'cooking oils'"],
#  ["'bread and cake'",
#   'juice-sat-cord-ms',
#   'confectionary',
#   'puddings-deserts',
#   "'frozen foods'",
#   'jams-spreads',
#   "'party snack foods'",
#   "'tissues-paper prd'",
#   "'soft drinks'",
#   'milk-cream',
#   'fruit',
#   'vegetables',
#   'stationary'],
#  ["'bread and cake'",
#   'juice-sat-cord-ms',
#   'biscuits',
#   "'canned fish-meat'",
#   "'canned fruit'",
#   "'canned vegetables'",
#   "'breakfast food'",
#   'sauces-gravy-pkle',
#   'puddings-deserts',
#   "'frozen foods'",
#   "'pet foods'",
#   "'dairy foods'",
#   'beef',
#   'fruit',
#   'vegetables',
#   'kitchen',
#   "'prepared meals'",
#   "'small goods2'"],
#  ["'baby needs'",
#   "'baking needs'",
#   'juice-sat-cord-ms',
#   'biscuits',
#   "'canned fish-meat'",
#   "'canned fruit'",
#   "'canned vegetables'",
#   "'breakfast food'",
#   'cleaners-polishers',
#   'sauces-gravy-pkle',
#   'confectionary',
#   'puddings-deserts',
#   "'frozen foods'",
#   'jams-spreads',
#   'insecticides',
#   "'laundry needs'",
#   "'party snack foods'",
#   "'tissues-paper prd'",
#   'wrapping',
#   "'soft drinks'",
#   "'beverages hot'",
#   'deodorants-soap',
#   'haircare',
#   'cheese',
#   'margarine',
#   'vegetables',
#   'brushware',
#   "'prepared meals'"],
#  ["'bread and cake'",
#   "'baking needs'",
#   'tea',
#   'biscuits',
#   "'canned fish-meat'",
#   "'canned fruit'",
#   'sauces-gravy-pkle',
#   "'frozen foods'",
#   'milk-cream',
#   'manchester',
#   "'prepared meals'"],
#  ['juice-sat-cord-ms',
#   'tea',
#   'biscuits',
#   "'canned fruit'",
#   "'canned vegetables'",
#   "'frozen foods'",
#   "'party snack foods'",
#   'fruit',
#   "'bake off products'"],
#  ["'bread and cake'",
#   "'baking needs'",
#   'juice-sat-cord-ms',
#   'biscuits',
#   "'canned fruit'",
#   "'canned vegetables'",
#   "'breakfast food'",
#   'cleaners-polishers',
#   'coffee',
#   'sauces-gravy-pkle',
#   'puddings-deserts',
#   'dishcloths-scour',
#   "'frozen foods'",
#   "'pet foods'",
#   "'laundry needs'",
#   "'tissues-paper prd'",
#   'wrapping',
#   'deodorants-soap',
#   'haircare',
#   'milk-cream',
#   'cold-meats',
#   'margarine',
#   "'small goods'",
#   'beef',
#   "'pet food'",
#   'poultry',
#   'fruit',
#   'vegetables',
#   "'prepared meals'",
#   "'small goods2'"],
#  ["'bread and cake'",
#   "'baking needs'",
#   "'canned fish-meat'",
#   "'cigs-tobacco pkts'",
#   'cleaners-polishers',
#   'coffee',
#   'deod-disinfectant',
#   "'frozen foods'",
#   'insecticides',
#   "'soft drinks'",
#   'margarine',
#   'poultry',
#   'potatoes',
#   'vegetables',
#   "'variety misc'",
#   'stationary',
#   "'cooking oils'"],
#  ["'grocery misc'",
#   "'bread and cake'",
#   "'baking needs'",
#   'juice-sat-cord-ms',
#   'biscuits',
#   "'canned fish-meat'",
#   "'breakfast food'",
#   "'cigs-tobacco pkts'",
#   'coffee',
#   'sauces-gravy-pkle',
#   'confectionary',
#   "'frozen foods'",
#   "'razor blades'",
#   'jams-spreads',
#   'insecticides',
#   "'pet foods'",
#   "'laundry needs'",
#   "'party snack foods'",
#   "'tissues-paper prd'",
#   'wrapping',
#   "'soft drinks'",
#   "'beverages hot'",
#   'deodorants-soap',
#   'haircare',
#   "'sanitary pads'",
#   'cheese',
#   'milk-cream',
#   'margarine',
#   "'dairy foods'",
#   'beef',
#   'lamb',
#   'pork',
#   'poultry',
#   'fruit',
#   'vegetables',
#   'electrical',
#   'stationary',
#   "'cooking oils'"],
#  ["'baby needs'",
#   "'bread and cake'",
#   "'baking needs'",
#   'juice-sat-cord-ms',
#   'biscuits',
#   "'breakfast food'",
#   'coffee',
#   'sauces-gravy-pkle',
#   'spices',
#   'insecticides',
#   "'pet foods'",
#   "'beverages hot'",
#   'haircare',
#   "'meat misc'",
#   'milk-cream',
#   'margarine',
#   'fruit',
#   'potatoes',
#   'vegetables',
#   "'prepared meals'",
#   "'bake off products'"],
#  ["'bread and cake'",
#   "'canned fish-meat'",
#   "'breakfast food'",
#   'confectionary',
#   'spices',
#   "'pet foods'",
#   'wrapping',
#   'cheese',
#   'milk-cream',
#   'margarine',
#   "'dairy foods'",
#   'poultry',
#   'potatoes',
#   'vegetables',
#   "'prepared meals'"],
#  ["'bread and cake'",
#   "'baking needs'",
#   'juice-sat-cord-ms',
#   'biscuits',
#   "'canned fruit'",
#   "'canned vegetables'",
#   "'breakfast food'",
#   'cleaners-polishers',
#   'sauces-gravy-pkle',
#   'deod-disinfectant',
#   "'frozen foods'",
#   'jams-spreads',
#   "'pet foods'",
#   "'party snack foods'",
#   "'tissues-paper prd'",
#   'wrapping',
#   'deodorants-soap',
#   'cheese',
#   'margarine',
#   'beef',
#   'hogget',
#   'fruit',
#   'vegetables',
#   'stationary',
#   "'prepared meals'",
#   "'small goods2'"],
#  ["'bread and cake'",
#   'tea',
#   'biscuits',
#   "'canned fruit'",
#   "'canned vegetables'",
#   'cleaners-polishers',
#   'coffee',
#   'confectionary',
#   "'frozen foods'",
#   'jams-spreads',
#   "'party snack foods'",
#   "'soft drinks'",
#   "'sanitary pads'",
#   'milk-cream',
#   'electrical'],
#  ["'bread and cake'",
#   "'baking needs'",
#   'juice-sat-cord-ms',
#   'biscuits',
#   "'canned vegetables'",
#   "'breakfast food'",
#   "'frozen foods'",
#   "'pet foods'",
#   "'party snack foods'",
#   "'tissues-paper prd'",
#   'lotions-creams',
#   'cheese',
#   'milk-cream',
#   'margarine',
#   'lamb',
#   "'pet food'",
#   'fruit',
#   'vegetables'],
#  ["'baking needs'",
#   'biscuits',
#   "'canned fish-meat'",
#   "'canned fruit'",
#   "'canned vegetables'",
#   "'cigs-tobacco pkts'",
#   'sauces-gravy-pkle',
#   "'frozen foods'",
#   'jams-spreads',
#   "'pet foods'",
#   "'health food other'",
#   'margarine',
#   "'small goods'",
#   "'dairy foods'",
#   'beef',
#   'fruit',
#   'vegetables',
#   "'bake off products'"],
#  ["'bread and cake'",
#   'juice-sat-cord-ms',
#   'biscuits',
#   "'canned vegetables'",
#   'deod-disinfectant',
#   "'frozen foods'",
#   "'pet foods'",
#   "'soft drinks'",
#   'margarine',
#   'fruit',
#   'stationary'],
#  ['juice-sat-cord-ms',
#   'cleaners-polishers',
#   "'pet foods'",
#   "'soft drinks'",
#   'beef',
#   "'pet food'",
#   'pork',
#   'fruit',
#   'potatoes',
#   'vegetables',
#   'kitchen',
#   "'small goods2'"],
#  ["'baking needs'",
#   "'frozen foods'",
#   "'fuels-garden aids'",
#   'jams-spreads',
#   'insecticides',
#   "'soft drinks'",
#   'margarine',
#   "'dairy foods'",
#   'fruit',
#   'kitchen',
#   "'prepared meals'",
#   "'cooking oils'",
#   "'750ml white nz'"],
#  ["'bread and cake'",
#   "'baking needs'",
#   'biscuits',
#   "'canned fish-meat'",
#   "'breakfast food'",
#   'sauces-gravy-pkle',
#   "'frozen foods'",
#   'spices',
#   "'laundry needs'",
#   "'tissues-paper prd'",
#   "'pkt-canned soup'",
#   'cheese',
#   'fruit',
#   'potatoes',
#   'vegetables',
#   "'prepared meals'"],
#  ["'bread and cake'",
#   "'baking needs'",
#   'juice-sat-cord-ms',
#   'biscuits',
#   "'breakfast food'",
#   'cleaners-polishers',
#   'coffee',
#   "'frozen foods'",
#   'jams-spreads',
#   "'pet foods'",
#   "'soft drinks'",
#   'cheese',
#   'milk-cream',
#   'margarine',
#   'beef',
#   'fruit',
#   'vegetables',
#   'stationary',
#   "'small goods2'"],
#  ["'bread and cake'",
#   "'baking needs'",
#   'juice-sat-cord-ms',
#   'cleaners-polishers',
#   'sauces-gravy-pkle',
#   'puddings-deserts',
#   "'frozen foods'",
#   "'laundry needs'",
#   "'tissues-paper prd'",
#   'deodorants-soap',
#   'cheese',
#   'milk-cream',
#   'margarine',
#   "'small goods'",
#   "'dairy foods'",
#   "'produce misc'",
#   'fruit',
#   'vegetables'],
#  ["'bread and cake'",
#   "'baking needs'",
#   'juice-sat-cord-ms',
#   'biscuits',
#   'coffee',
#   'confectionary',
#   "'tissues-paper prd'",
#   'haircare',
#   'cheese',
#   'milk-cream',
#   'margarine',
#   'beef',
#   'poultry',
#   'fruit',
#   'vegetables',
#   "'variety misc'",
#   'stationary'],
#  ["'bread and cake'",
#   "'baking needs'",
#   'juice-sat-cord-ms',
#   'biscuits',
#   "'canned fruit'",
#   "'canned vegetables'",
#   "'breakfast food'",
#   "'cigs-tobacco pkts'",
#   'coffee',
#   'sauces-gravy-pkle',
#   "'frozen foods'",
#   'spices',
#   "'laundry needs'",
#   "'party snack foods'",
#   "'tissues-paper prd'",
#   'wrapping',
#   "'health food other'",
#   'deodorants-soap',
#   'haircare',
#   "'dental needs'",
#   'cheese',
#   'milk-cream',
#   'margarine',
#   "'dairy foods'",
#   'beef',
#   'poultry',
#   'fruit',
#   'vegetables',
#   "'prepared meals'",
#   "'small goods2'"],
#  ["'bread and cake'",
#   "'baking needs'",
#   'juice-sat-cord-ms',
#   'biscuits',
#   "'frozen foods'",
#   "'pet foods'",
#   "'soft drinks'",
#   'milk-cream',
#   'cold-meats',
#   "'dairy foods'",
#   'fruit',
#   'vegetables',
#   "'prepared meals'",
#   'condiments'],
#  ["'baby needs'",
#   "'bread and cake'",
#   "'baking needs'",
#   'juice-sat-cord-ms',
#   'cleaners-polishers',
#   'puddings-deserts',
#   'jams-spreads',
#   'insecticides',
#   "'pet foods'",
#   "'laundry needs'",
#   "'party snack foods'",
#   "'soft drinks'",
#   'haircare',
#   'cough-cold-pain',
#   'cheese',
#   'fruit',
#   'condiments'],
#  ["'bread and cake'",
#   "'baking needs'",
#   'juice-sat-cord-ms',
#   'biscuits',
#   "'canned fish-meat'",
#   "'canned fruit'",
#   "'canned vegetables'",
#   "'breakfast food'",
#   "'cigs-tobacco pkts'",
#   'cleaners-polishers',
#   'coffee',
#   'sauces-gravy-pkle',
#   'puddings-deserts',
#   "'frozen foods'",
#   "'laundry needs'",
#   "'party snack foods'",
#   "'tissues-paper prd'",
#   'wrapping',
#   "'soft drinks'",
#   'deodorants-soap',
#   "'dental needs'",
#   'cough-cold-pain',
#   'cheese',
#   'milk-cream',
#   'margarine',
#   "'small goods'",
#   'beef',
#   'pork',
#   'fruit',
#   'stationary',
#   "'prepared meals'",
#   "'cooking oils'",
#   "'bake off products'",
#   'offal',
#   "'sparkling nz'"],
#  ["'bread and cake'",
#   'tea',
#   'biscuits',
#   'cleaners-polishers',
#   'confectionary',
#   'deod-disinfectant',
#   "'frozen foods'",
#   'spices',
#   "'pet foods'",
#   "'laundry needs'",
#   "'soft drinks'",
#   "'health food other'",
#   "'dental needs'",
#   'cheese',
#   'milk-cream',
#   'margarine',
#   "'dairy foods'",
#   'beef',
#   'lamb',
#   'fruit',
#   "'750ml white nz'"],
#  ["'bread and cake'",
#   'juice-sat-cord-ms',
#   'tea',
#   'biscuits',
#   "'canned fish-meat'",
#   'cleaners-polishers',
#   "'fuels-garden aids'",
#   "'tissues-paper prd'",
#   'milk-cream',
#   'beef',
#   'kitchen'],
#  ["'bread and cake'",
#   'juice-sat-cord-ms',
#   'biscuits',
#   'spices',
#   'jams-spreads',
#   "'party snack foods'",
#   "'soft drinks'",
#   'cheese',
#   'milk-cream',
#   'margarine',
#   "'small goods'",
#   'fruit',
#   'vegetables',
#   'stationary',
#   "'small goods2'"],
#  ["'bread and cake'",
#   "'baking needs'",
#   "'canned vegetables'",
#   "'breakfast food'",
#   'cleaners-polishers',
#   'sauces-gravy-pkle',
#   'jams-spreads',
#   "'pet foods'",
#   "'laundry needs'",
#   'cheese',
#   'milk-cream',
#   'margarine',
#   'fruit',
#   'vegetables',
#   "'small goods2'"],
#  ["'bread and cake'",
#   "'baking needs'",
#   'biscuits',
#   "'breakfast food'",
#   'sauces-gravy-pkle',
#   "'frozen foods'",
#   'deodorants-soap',
#   'haircare',
#   "'dental needs'",
#   'milk-cream',
#   "'dairy foods'",
#   'fruit',
#   'stationary',
#   "'imported cheese'"],
#  ["'bread and cake'",
#   "'baking needs'",
#   'juice-sat-cord-ms',
#   'biscuits',
#   "'canned fish-meat'",
#   "'canned vegetables'",
#   "'breakfast food'",
#   'sauces-gravy-pkle',
#   'confectionary',
#   'puddings-deserts',
#   "'frozen foods'",
#   'jams-spreads',
#   "'party snack foods'",
#   "'tissues-paper prd'",
#   'wrapping',
#   "'soft drinks'",
#   'deodorants-soap',
#   "'sanitary pads'",
#   'cheese',
#   'milk-cream',
#   'margarine',
#   'beef',
#   'poultry',
#   'fruit',
#   'brushware',
#   'kitchen',
#   'condiments'],
#  ['juice-sat-cord-ms',
#   'biscuits',
#   'coffee',
#   'sauces-gravy-pkle',
#   "'frozen foods'",
#   "'beverages hot'",
#   'lotions-creams',
#   'cheese',
#   'milk-cream',
#   'margarine',
#   'beef',
#   'fruit',
#   'vegetables',
#   "'small goods2'",
#   "'750ml white nz'"],
#  ["'baby needs'",
#   "'bread and cake'",
#   "'baking needs'",
#   'biscuits',
#   "'breakfast food'",
#   'puddings-deserts',
#   "'frozen foods'",
#   "'pet foods'",
#   "'party snack foods'",
#   "'soft drinks'",
#   'cheese',
#   'milk-cream',
#   'margarine',
#   "'small goods'",
#   "'dairy foods'",
#   "'pet food'",
#   'poultry',
#   'fruit',
#   'vegetables',
#   'brushware',
#   'kitchen',
#   "'prepared meals'",
#   "'bake off products'"],
#  ["'baby needs'",
#   "'bread and cake'",
#   'biscuits',
#   'coffee',
#   'dishcloths-scour',
#   'lotions-creams',
#   'cheese',
#   'cold-meats',
#   'margarine',
#   'fruit',
#   'vegetables',
#   "'variety misc'",
#   'kitchen'],
#  ['juice-sat-cord-ms',
#   'biscuits',
#   "'canned vegetables'",
#   'sauces-gravy-pkle',
#   "'fuels-garden aids'",
#   "'pet foods'",
#   "'laundry needs'",
#   "'party snack foods'",
#   "'tissues-paper prd'",
#   "'soft drinks'",
#   'cheese',
#   "'small goods'",
#   'fruit',
#   'vegetables'],
#  ['tea',
#   "'canned fish-meat'",
#   "'canned vegetables'",
#   "'breakfast food'",
#   "'frozen foods'",
#   "'razor blades'",
#   "'party snack foods'",
#   "'tissues-paper prd'",
#   'wrapping',
#   "'soft drinks'",
#   'milk-cream',
#   'margarine',
#   "'dairy foods'",
#   'beef'],
#  ["'bread and cake'",
#   "'baking needs'",
#   'biscuits',
#   "'canned vegetables'",
#   "'breakfast food'",
#   'cleaners-polishers',
#   'sauces-gravy-pkle',
#   'dishcloths-scour',
#   "'frozen foods'",
#   'spices',
#   "'laundry needs'",
#   "'tissues-paper prd'",
#   'wrapping',
#   'deodorants-soap',
#   'haircare',
#   'cough-cold-pain',
#   'cheese',
#   'milk-cream',
#   'cold-meats',
#   'margarine',
#   "'small goods'",
#   'potatoes',
#   'kitchen',
#   "'small goods2'"],
#  ["'bread and cake'",
#   "'baking needs'",
#   'juice-sat-cord-ms',
#   'biscuits',
#   'sauces-gravy-pkle',
#   'confectionary',
#   "'frozen foods'",
#   'insecticides',
#   "'pet foods'",
#   "'party snack foods'",
#   'wrapping',
#   "'soft drinks'",
#   'milk-cream',
#   'margarine',
#   "'small goods'",
#   "'dairy foods'",
#   'fruit',
#   'vegetables',
#   "'cooking oils'",
#   "'small goods2'"],
#  ['cleaners-polishers',
#   'deod-disinfectant',
#   "'razor blades'",
#   'insecticides',
#   "'pet foods'",
#   "'laundry needs'",
#   "'tissues-paper prd'",
#   'wrapping',
#   'deodorants-soap',
#   'haircare',
#   "'dental needs'",
#   'stationary'],
#  ["'bread and cake'",
#   'juice-sat-cord-ms',
#   'tea',
#   "'canned vegetables'",
#   "'breakfast food'",
#   'cleaners-polishers',
#   'sauces-gravy-pkle',
#   'confectionary',
#   'dishcloths-scour',
#   "'frozen foods'",
#   'jams-spreads',
#   "'laundry needs'",
#   "'tissues-paper prd'",
#   "'soft drinks'",
#   'deodorants-soap',
#   "'sanitary pads'",
#   'milk-cream',
#   'margarine',
#   "'small goods'",
#   "'dairy foods'",
#   'beef',
#   'vegetables',
#   "'bake off products'"],
#  ["'baking needs'",
#   'juice-sat-cord-ms',
#   'biscuits',
#   "'canned vegetables'",
#   'sauces-gravy-pkle',
#   "'frozen foods'",
#   "'pet foods'",
#   "'laundry needs'",
#   "'party snack foods'",
#   "'tissues-paper prd'",
#   "'soft drinks'",
#   'margarine',
#   "'dairy foods'",
#   'fruit',
#   'vegetables',
#   "'cooking oils'"],
#  ["'baby needs'",
#   "'bread and cake'",
#   "'baking needs'",
#   'tea',
#   'biscuits',
#   "'canned fruit'",
#   "'breakfast food'",
#   'cleaners-polishers',
#   'sauces-gravy-pkle',
#   'confectionary',
#   'puddings-deserts',
#   "'frozen foods'",
#   "'razor blades'",
#   "'fuels-garden aids'",
#   "'laundry needs'",
#   "'tissues-paper prd'",
#   'wrapping',
#   "'soft drinks'",
#   'lotions-creams',
#   'cheese',
#   'margarine',
#   "'small goods'",
#   'beef',
#   'lamb',
#   'fruit',
#   'vegetables',
#   'stationary',
#   "'small goods2'"],
#  ["'bread and cake'",
#   'biscuits',
#   'cleaners-polishers',
#   'coffee',
#   'puddings-deserts',
#   "'frozen foods'",
#   'insecticides',
#   "'pet foods'",
#   "'tissues-paper prd'",
#   "'soft drinks'",
#   'deodorants-soap',
#   'haircare',
#   'cheese',
#   'milk-cream',
#   'margarine',
#   "'small goods'",
#   "'dairy foods'",
#   "'fruit drinks'",
#   'vegetables',
#   'stationary'],
#  ["'grocery misc'", "'cigs-tobacco pkts'", 'coffee', 'stationary'],
#  ["'bread and cake'",
#   "'baking needs'",
#   'juice-sat-cord-ms',
#   'biscuits',
#   "'breakfast food'",
#   'jams-spreads',
#   'insecticides',
#   "'party snack foods'",
#   "'tissues-paper prd'",
#   'cheese',
#   'cold-meats',
#   'margarine',
#   "'dairy foods'",
#   'fruit',
#   'potatoes',
#   "'variety misc'",
#   'stationary'],
#  ["'bread and cake'",
#   "'baking needs'",
#   'juice-sat-cord-ms',
#   'biscuits',
#   "'canned vegetables'",
#   'sauces-gravy-pkle',
#   "'frozen foods'",
#   "'laundry needs'",
#   "'party snack foods'",
#   'deodorants-soap',
#   'cheese',
#   'milk-cream',
#   'margarine',
#   "'pet food'",
#   'fruit',
#   'vegetables',
#   "'small goods2'"],
#  ["'bread and cake'",
#   "'baking needs'",
#   'juice-sat-cord-ms',
#   'tea',
#   'biscuits',
#   "'canned fish-meat'",
#   "'canned fruit'",
#   'cleaners-polishers',
#   'sauces-gravy-pkle',
#   "'frozen foods'",
#   'jams-spreads',
#   "'pet foods'",
#   "'laundry needs'",
#   "'party snack foods'",
#   "'tissues-paper prd'",
#   'wrapping',
#   "'health food other'",
#   'cheese',
#   'milk-cream',
#   'cold-meats',
#   'margarine',
#   "'small goods'",
#   "'dairy foods'",
#   'beef',
#   "'pet food'",
#   'pork',
#   'fruit',
#   'vegetables',
#   "'bake off products'",
#   "'small goods2'"],
#  ["'bread and cake'",
#   'juice-sat-cord-ms',
#   'tea',
#   'biscuits',
#   "'canned fruit'",
#   "'canned vegetables'",
#   "'breakfast food'",
#   'cleaners-polishers',
#   'sauces-gravy-pkle',
#   'insecticides',
#   "'laundry needs'",
#   "'party snack foods'",
#   "'tissues-paper prd'",
#   'wrapping',
#   'milk-cream',
#   'cold-meats',
#   'margarine',
#   "'small goods'",
#   "'dairy foods'",
#   "'pet food'",
#   'fruit',
#   'vegetables',
#   'stationary',
#   "'prepared meals'",
#   "'preserving needs'"],
#  ["'bread and cake'",
#   'biscuits',
#   "'canned fish-meat'",
#   "'canned vegetables'",
#   "'frozen foods'",
#   "'razor blades'",
#   'jams-spreads',
#   "'pet foods'",
#   "'laundry needs'",
#   "'party snack foods'",
#   "'tissues-paper prd'",
#   'wrapping',
#   "'soft drinks'",
#   'deodorants-soap',
#   "'dental needs'",
#   'cough-cold-pain',
#   'cheese',
#   'milk-cream',
#   'cold-meats',
#   'margarine',
#   "'dairy foods'",
#   "'pet food'",
#   'poultry',
#   'fruit',
#   'stationary'],
#  ["'baking needs'",
#   'juice-sat-cord-ms',
#   "'canned fish-meat'",
#   "'canned fruit'",
#   'cleaners-polishers',
#   "'frozen foods'",
#   'jams-spreads',
#   "'pet foods'",
#   "'party snack foods'",
#   "'pkt-canned soup'",
#   "'soft drinks'",
#   'haircare',
#   "'dental needs'",
#   'cheese',
#   'milk-cream',
#   "'dairy foods'",
#   "'pet food'"],
#  ["'bread and cake'",
#   "'baking needs'",
#   'juice-sat-cord-ms',
#   'biscuits',
#   "'canned fish-meat'",
#   "'canned fruit'",
#   "'canned vegetables'",
#   "'breakfast food'",
#   'coffee',
#   'sauces-gravy-pkle',
#   "'frozen foods'",
#   'jams-spreads',
#   "'party snack foods'",
#   'wrapping',
#   'cheese',
#   "'deli gourmet'",
#   'margarine',
#   "'small goods'",
#   'beef',
#   'fruit',
#   'vegetables'],
#  ["'bread and cake'",
#   "'baking needs'",
#   'juice-sat-cord-ms',
#   'biscuits',
#   "'canned fish-meat'",
#   "'canned fruit'",
#   "'canned vegetables'",
#   "'breakfast food'",
#   "'cigs-tobacco pkts'",
#   'sauces-gravy-pkle',
#   'deod-disinfectant',
#   "'frozen foods'",
#   'spices',
#   'jams-spreads',
#   'insecticides',
#   "'pet foods'",
#   "'laundry needs'",
#   "'party snack foods'",
#   "'tissues-paper prd'",
#   'wrapping',
#   'haircare',
#   'lotions-creams',
#   'cheese',
#   'margarine',
#   "'dairy foods'",
#   'beef',
#   'pork',
#   "'produce misc'",
#   'fruit',
#   'potatoes',
#   'vegetables',
#   "'prepared meals'",
#   "'cooking oils'",
#   "'750ml white imp'"],
#  ["'grocery misc'",
#   "'bread and cake'",
#   "'baking needs'",
#   'juice-sat-cord-ms',
#   'biscuits',
#   "'cigs-tobacco pkts'",
#   'sauces-gravy-pkle',
#   'pork'],
#  ["'bread and cake'",
#   "'baking needs'",
#   'biscuits',
#   "'canned fish-meat'",
#   "'canned fruit'",
#   "'canned vegetables'",
#   "'breakfast food'",
#   'coffee',
#   'sauces-gravy-pkle',
#   'confectionary',
#   'puddings-deserts',
#   'spices',
#   'insecticides',
#   "'pet foods'",
#   "'laundry needs'",
#   "'party snack foods'",
#   'haircare',
#   "'sanitary pads'",
#   'cheese',
#   'milk-cream',
#   'margarine',
#   "'small goods'",
#   "'dairy foods'",
#   "'prepared meals'",
#   "'750ml white nz'",
#   "'750ml red nz'"],
#  ["'bread and cake'",
#   "'baking needs'",
#   'tea',
#   "'breakfast food'",
#   'cleaners-polishers',
#   'sauces-gravy-pkle',
#   'puddings-deserts',
#   "'frozen foods'",
#   'insecticides',
#   "'laundry needs'",
#   'wrapping',
#   'cheese',
#   'cold-meats',
#   'margarine',
#   "'small goods'",
#   "'dairy foods'",
#   'beef',
#   'kitchen',
#   'offal'],
#  ["'bread and cake'",
#   'juice-sat-cord-ms',
#   "'cigs-tobacco pkts'",
#   'confectionary',
#   "'frozen foods'",
#   "'pet foods'",
#   "'soft drinks'",
#   "'dental needs'",
#   'milk-cream',
#   'beef',
#   'lamb',
#   'potatoes',
#   'vegetables',
#   'stationary'],
#  ["'bread and cake'",
#   "'baking needs'",
#   'juice-sat-cord-ms',
#   'biscuits',
#   "'canned fruit'",
#   'confectionary',
#   'jams-spreads',
#   'wrapping',
#   'cough-cold-pain',
#   "'small goods'",
#   'plants',
#   'electrical',
#   "'small goods2'"],
#  ["'bread and cake'",
#   'juice-sat-cord-ms',
#   'tea',
#   'biscuits',
# ...
#   'deodorants-soap',
#   "'dental needs'",
#   'cheese',
#   'milk-cream',
#   'margarine',
#   "'small goods'",
#   "'dairy foods'",
#   'beef',
#   "'pet food'",
#   'fruit',
#   'electrical',
#   "'prepared meals'",
#   "'small goods2'"],
#  ["'bread and cake'",
#   "'baking needs'",
#   'juice-sat-cord-ms',
#   "'canned vegetables'",
#   "'breakfast food'",
#   'sauces-gravy-pkle',
#   "'pet foods'",
#   "'laundry needs'",
#   "'tissues-paper prd'",
#   'wrapping',
#   'deodorants-soap',
#   "'mens toiletries'",
#   'haircare',
#   "'dental needs'",
#   'cough-cold-pain',
#   'cheese',
#   'milk-cream',
#   'margarine',
#   'beef',
#   'poultry',
#   'vegetables',
#   "'prepared meals'",
#   "'cooking oils'",
#   "'small goods2'"],
#  ["'bread and cake'",
#   'juice-sat-cord-ms',
#   'biscuits',
#   "'canned fish-meat'",
#   "'canned vegetables'",
#   'coffee',
#   'sauces-gravy-pkle',
#   'deod-disinfectant',
#   "'frozen foods'",
#   "'pet foods'",
#   "'laundry needs'",
#   "'party snack foods'",
#   "'tissues-paper prd'",
#   "'soft drinks'",
#   'cheese',
#   'milk-cream',
#   'margarine',
#   "'small goods'",
#   "'dairy foods'",
#   'beef',
#   'lamb',
#   'poultry',
#   'fruit',
#   'vegetables',
#   'stationary',
#   'offal'],
#  ["'baking needs'",
#   'juice-sat-cord-ms',
#   'biscuits',
#   'sauces-gravy-pkle',
#   'jams-spreads',
#   "'party snack foods'",
#   'cheese',
#   'milk-cream',
#   'margarine',
#   "'small goods'",
#   "'dairy foods'",
#   'poultry',
#   'fruit',
#   'potatoes'],
#  ["'baby needs'",
#   "'bread and cake'",
#   "'baking needs'",
#   'juice-sat-cord-ms',
#   'tea',
#   'biscuits',
#   "'canned fish-meat'",
#   "'canned fruit'",
#   "'canned vegetables'",
#   "'breakfast food'",
#   'cleaners-polishers',
#   'coffee',
#   'sauces-gravy-pkle',
#   'confectionary',
#   'puddings-deserts',
#   "'frozen foods'",
#   'jams-spreads',
#   "'pet foods'",
#   "'party snack foods'",
#   "'tissues-paper prd'",
#   'wrapping',
#   "'soft drinks'",
#   'deodorants-soap',
#   "'mens toiletries'",
#   'medicines',
#   "'dental needs'",
#   'lotions-creams',
#   'cough-cold-pain',
#   'cheese',
#   'milk-cream',
#   'margarine',
#   'beef',
#   'fruit',
#   'vegetables',
#   "'prepared meals'",
#   'condiments',
#   "'small goods2'"],
#  ["'bread and cake'",
#   "'baking needs'",
#   'biscuits',
#   "'canned fish-meat'",
#   "'canned fruit'",
#   "'canned vegetables'",
#   "'breakfast food'",
#   'coffee',
#   'sauces-gravy-pkle',
#   'puddings-deserts',
#   "'pet foods'",
#   "'laundry needs'",
#   "'tissues-paper prd'",
#   'wrapping',
#   "'dried vegetables'",
#   'milk-cream',
#   "'dairy foods'",
#   'beef',
#   'lamb',
#   "'pet food'",
#   'poultry',
#   'stationary',
#   "'prepared meals'"],
#  ["'bread and cake'",
#   "'baking needs'",
#   'juice-sat-cord-ms',
#   'biscuits',
#   "'canned fish-meat'",
#   "'canned fruit'",
#   "'canned vegetables'",
#   "'breakfast food'",
#   'sauces-gravy-pkle',
#   'confectionary',
#   "'frozen foods'",
#   "'pet foods'",
#   "'laundry needs'",
#   "'party snack foods'",
#   "'tissues-paper prd'",
#   "'pkt-canned soup'",
#   'deodorants-soap',
#   'haircare',
#   'lotions-creams',
#   'margarine',
#   "'small goods'",
#   'beef',
#   'poultry',
#   'vegetables',
#   "'prepared meals'",
#   "'750ml white nz'",
#   "'750ml red nz'"],
#  ["'cigs-tobacco pkts'",
#   'confectionary',
#   "'laundry needs'",
#   "'party snack foods'",
#   'deodorants-soap',
#   'lamb',
#   'vegetables'],
#  ["'bread and cake'",
#   "'baking needs'",
#   'biscuits',
#   "'canned fish-meat'",
#   "'canned vegetables'",
#   "'cigs-tobacco pkts'",
#   'cleaners-polishers',
#   'sauces-gravy-pkle',
#   'confectionary',
#   "'frozen foods'",
#   'insecticides',
#   "'tissues-paper prd'",
#   'wrapping',
#   "'soft drinks'",
#   'deodorants-soap',
#   'cheese',
#   'margarine',
#   "'produce misc'",
#   'fruit',
#   'potatoes',
#   'vegetables',
#   'electrical',
#   'stationary',
#   "'bake off products'",
#   "'small goods2'",
#   "'750ml red nz'"],
#  ["'bread and cake'",
#   "'cigs-tobacco pkts'",
#   'cleaners-polishers',
#   'confectionary',
#   "'pet foods'",
#   "'laundry needs'",
#   "'party snack foods'",
#   'wrapping',
#   "'soft drinks'",
#   'milk-cream',
#   'cold-meats',
#   'margarine',
#   'beef',
#   'potatoes',
#   'vegetables',
#   'stationary'],
#  ["'bread and cake'",
#   'juice-sat-cord-ms',
#   'tea',
#   'biscuits',
#   "'canned fruit'",
#   "'canned vegetables'",
#   'cleaners-polishers',
#   'sauces-gravy-pkle',
#   'confectionary',
#   'puddings-deserts',
#   "'frozen foods'",
#   "'razor blades'",
#   "'pet foods'",
#   "'laundry needs'",
#   "'party snack foods'",
#   'wrapping',
#   "'soft drinks'",
#   'deodorants-soap',
#   'cheese',
#   "'dairy foods'",
#   'beef',
#   'fruit',
#   'vegetables',
#   'stationary',
#   "'prepared meals'"],
#  ["'baby needs'",
#   "'bread and cake'",
#   "'baking needs'",
#   'juice-sat-cord-ms',
#   'biscuits',
#   "'canned vegetables'",
#   "'breakfast food'",
#   'cleaners-polishers',
#   'sauces-gravy-pkle',
#   'confectionary',
#   'dishcloths-scour',
#   "'frozen foods'",
#   "'laundry needs'",
#   "'party snack foods'",
#   "'tissues-paper prd'",
#   'wrapping',
#   "'pkt-canned soup'",
#   "'soft drinks'",
#   'deodorants-soap',
#   'haircare',
#   'chickens',
#   'milk-cream',
#   'cold-meats',
#   "'deli gourmet'",
#   'margarine',
#   "'small goods'",
#   "'dairy foods'",
#   'beef',
#   'fruit',
#   'vegetables',
#   'kitchen',
#   "'prepared meals'",
#   "'imported cheese'"],
#  ["'baking needs'",
#   'confectionary',
#   "'frozen foods'",
#   "'laundry needs'",
#   'milk-cream',
#   'beef',
#   'hogget',
#   'lamb',
#   'vegetables',
#   'stationary'],
#  ["'baking needs'",
#   'juice-sat-cord-ms',
#   'confectionary',
#   'spices',
#   "'health&beauty misc'",
#   'milk-cream',
#   'fruit',
#   'vegetables'],
#  ["'cigs-tobacco pkts'", 'haircare', "'750ml white imp'", "'750ml red imp'"],
#  ['biscuits',
#   "'cigs-tobacco pkts'",
#   'sauces-gravy-pkle',
#   "'frozen foods'",
#   "'tissues-paper prd'",
#   "'soft drinks'",
#   'cold-meats',
#   "'deli gourmet'",
#   "'dairy foods'",
#   "'delicatessen misc'",
#   'fruit',
#   'vegetables'],
#  ['juice-sat-cord-ms',
#   'biscuits',
#   "'breakfast food'",
#   'sauces-gravy-pkle',
#   'confectionary',
#   'deod-disinfectant',
#   "'frozen foods'",
#   "'pet foods'",
#   "'laundry needs'",
#   "'party snack foods'",
#   "'tissues-paper prd'",
#   "'beverages hot'",
#   'deodorants-soap',
#   "'dental needs'",
#   'lotions-creams',
#   'cheese',
#   'milk-cream',
#   'cold-meats',
#   'margarine',
#   "'dairy foods'",
#   'fruit',
#   'vegetables',
#   'stationary',
#   "'prepared meals'",
#   "'non host support'"],
#  ["'bread and cake'",
#   'juice-sat-cord-ms',
#   'biscuits',
#   'coffee',
#   'confectionary',
#   "'frozen foods'",
#   "'pet foods'",
#   "'tissues-paper prd'",
#   "'soft drinks'",
#   'deodorants-soap',
#   "'dental needs'",
#   "'sanitary pads'",
#   'cheese',
#   'milk-cream',
#   'beef',
#   'fruit',
#   'vegetables',
#   "'prepared meals'"],
#  ["'bread and cake'",
#   "'baking needs'",
#   'tea',
#   'biscuits',
#   "'canned fish-meat'",
#   'cleaners-polishers',
#   'coffee',
#   'sauces-gravy-pkle',
#   'confectionary',
#   'margarine',
#   "'small goods'",
#   'beef',
#   'pork',
#   'fruit',
#   'vegetables',
#   'stationary',
#   "'small goods2'"],
#  ["'baking needs'",
#   'juice-sat-cord-ms',
#   'biscuits',
#   'confectionary',
#   "'pet foods'",
#   'wrapping',
#   'milk-cream',
#   "'dairy foods'",
#   'fruit',
#   'stationary',
#   "'bake off products'"],
#  ['juice-sat-cord-ms',
#   "'canned fish-meat'",
#   "'canned vegetables'",
#   "'cigs-tobacco pkts'",
#   'milk-cream',
#   "'sparkling nz'"],
#  ["'canned vegetables'",
#   "'breakfast food'",
#   "'party snack foods'",
#   "'meat misc'",
#   'milk-cream',
#   "'dairy foods'",
#   'fruit',
#   'vegetables'],
#  ["'bread and cake'",
#   'biscuits',
#   'confectionary',
#   'jams-spreads',
#   "'laundry needs'",
#   "'tissues-paper prd'",
#   "'soft drinks'",
#   'cheese',
#   'milk-cream',
#   'cold-meats',
#   'margarine',
#   'fruit',
#   'potatoes',
#   'stationary'],
#  ["'bread and cake'",
#   "'baking needs'",
#   'biscuits',
#   'coffee',
#   'confectionary',
#   "'pet foods'",
#   "'party snack foods'",
#   "'tissues-paper prd'",
#   "'soft drinks'",
#   'milk-cream',
#   'lamb',
#   "'pet food'",
#   'fruit',
#   'potatoes',
#   'vegetables',
#   'stationary'],
#  ["'bread and cake'",
#   "'baking needs'",
#   'juice-sat-cord-ms',
#   'biscuits',
#   'sauces-gravy-pkle',
#   'confectionary',
#   "'frozen foods'",
#   'jams-spreads',
#   "'party snack foods'",
#   "'tissues-paper prd'",
#   "'soft drinks'",
#   'milk-cream',
#   'cold-meats',
#   'margarine',
#   "'small goods'",
#   "'dairy foods'",
#   'beef',
#   'poultry',
#   'fruit',
#   'potatoes',
#   'vegetables',
#   "'bake off products'"],
#  ["'bread and cake'",
#   'tea',
#   "'canned fruit'",
#   "'breakfast food'",
#   'cleaners-polishers',
#   'sauces-gravy-pkle',
#   'puddings-deserts',
#   "'frozen foods'",
#   'jams-spreads',
#   "'pet foods'",
#   "'laundry needs'",
#   "'party snack foods'",
#   "'tissues-paper prd'",
#   "'soft drinks'",
#   "'mens toiletries'",
#   "'dental needs'",
#   'lotions-creams',
#   'cheese',
#   'milk-cream',
#   "'deli gourmet'",
#   'margarine',
#   "'dairy foods'",
#   'beef',
#   'fruit',
#   'kitchen',
#   "'small goods2'",
#   "'750ml red imp'"],
#  ["'bread and cake'",
#   "'baking needs'",
#   'juice-sat-cord-ms',
#   'biscuits',
#   "'canned fruit'",
#   "'canned vegetables'",
#   "'breakfast food'",
#   "'cigs-tobacco pkts'",
#   'cleaners-polishers',
#   'coffee',
#   'sauces-gravy-pkle',
#   "'frozen foods'",
#   'jams-spreads',
#   "'pet foods'",
#   "'party snack foods'",
#   "'tissues-paper prd'",
#   "'soft drinks'",
#   'deodorants-soap',
#   'haircare',
#   "'dental needs'",
#   "'sanitary pads'",
#   'cheese',
#   'milk-cream',
#   'cold-meats',
#   'margarine',
#   "'small goods'",
#   "'dairy foods'",
#   "'pet food'",
#   'fruit'],
#  ["'bread and cake'",
#   "'breakfast food'",
#   "'cigs-tobacco pkts'",
#   'sauces-gravy-pkle',
#   'confectionary',
#   "'frozen foods'",
#   'haircare',
#   "'dairy foods'",
#   "'variety misc'",
#   'stationary'],
#  ['juice-sat-cord-ms',
#   'sauces-gravy-pkle',
#   "'fuels-garden aids'",
#   'insecticides',
#   "'tissues-paper prd'",
#   'milk-cream',
#   'vegetables',
#   "'variety misc'",
#   "'small goods2'",
#   "'casks white wine'"],
#  ["'baby needs'",
#   "'bread and cake'",
#   "'baking needs'",
#   'juice-sat-cord-ms',
#   'tea',
#   'biscuits',
#   "'canned vegetables'",
#   'cleaners-polishers',
#   'sauces-gravy-pkle',
#   'confectionary',
#   "'frozen foods'",
#   "'pet foods'",
#   "'laundry needs'",
#   "'party snack foods'",
#   "'tissues-paper prd'",
#   'wrapping',
#   "'soft drinks'",
#   'cheese',
#   'milk-cream',
#   'margarine',
#   "'small goods'",
#   'vegetables',
#   'stationary',
#   "'cooking oils'",
#   "'small goods2'"],
#  ['juice-sat-cord-ms',
#   'cleaners-polishers',
#   'coffee',
#   "'frozen foods'",
#   "'laundry needs'",
#   "'tissues-paper prd'",
#   'milk-cream',
#   "'small goods'",
#   "'dairy foods'",
#   'beef',
#   'fruit',
#   'vegetables',
#   'stationary'],
#  ["'baby needs'",
#   "'bread and cake'",
#   "'baking needs'",
#   'tea',
#   'biscuits',
#   "'breakfast food'",
#   'cleaners-polishers',
#   'sauces-gravy-pkle',
#   "'frozen foods'",
#   'spices',
#   "'pet foods'",
#   "'laundry needs'",
#   "'party snack foods'",
#   "'tissues-paper prd'",
#   'wrapping',
#   "'soft drinks'",
#   'deodorants-soap',
#   "'sanitary pads'",
#   'milk-cream',
#   'margarine',
#   "'small goods'",
#   'brushware',
#   'kitchen'],
#  ["'bread and cake'",
#   "'baking needs'",
#   'juice-sat-cord-ms',
#   'biscuits',
#   "'canned fruit'",
#   "'breakfast food'",
#   'cleaners-polishers',
#   'sauces-gravy-pkle',
#   "'frozen foods'",
#   'jams-spreads',
#   "'pet foods'",
#   "'laundry needs'",
#   "'party snack foods'",
#   "'tissues-paper prd'",
#   "'soft drinks'",
#   'deodorants-soap',
#   'haircare',
#   "'dental needs'",
#   'cheese',
#   'milk-cream',
#   "'deli gourmet'",
#   'margarine',
#   "'small goods'",
#   "'dairy foods'",
#   "'delicatessen misc'",
#   'beef',
#   'poultry',
#   'fruit',
#   'potatoes',
#   'vegetables',
#   'stationary',
#   "'bake off products'",
#   "'small goods2'",
#   "'imported cheese'"],
#  ["'bread and cake'",
#   "'baking needs'",
#   'juice-sat-cord-ms',
#   'biscuits',
#   "'canned vegetables'",
#   "'cigs-tobacco pkts'",
#   'coffee',
#   'confectionary',
#   'deod-disinfectant',
#   "'frozen foods'",
#   "'pet foods'",
#   "'party snack foods'",
#   "'tissues-paper prd'",
#   'wrapping',
#   "'soft drinks'",
#   'deodorants-soap',
#   "'dental needs'",
#   'cheese',
#   'milk-cream',
#   'margarine',
#   "'small goods'",
#   "'dairy foods'",
#   'fruit',
#   'vegetables',
#   "'prepared meals'",
#   "'cooking oils'",
#   "'bake off products'"],
#  ["'bread and cake'",
#   "'baking needs'",
#   "'breakfast food'",
#   'haircare',
#   'lotions-creams',
#   'margarine',
#   "'small goods'",
#   "'dairy foods'",
#   'fruit',
#   'vegetables',
#   'kitchen'],
#  ["'cigs-tobacco pkts'",
#   "'frozen foods'",
#   "'party snack foods'",
#   "'soft drinks'",
#   'milk-cream',
#   'beef',
#   'poultry',
#   'stationary',
#   "'small goods2'"],
#  ["'bread and cake'",
#   'biscuits',
#   "'breakfast food'",
#   'milk-cream',
#   'cold-meats',
#   'vegetables',
#   'stationary',
#   'condiments'],
#  ['biscuits',
#   'confectionary',
#   "'party snack foods'",
#   'deodorants-soap',
#   'haircare',
#   "'dental needs'",
#   "'sanitary pads'",
#   'fruit',
#   'electrical',
#   'kitchen',
#   "'prepared meals'",
#   "'bake off products'"],
#  ["'bread and cake'",
#   'biscuits',
#   "'breakfast food'",
#   'jams-spreads',
#   'insecticides',
#   'lotions-creams',
#   'milk-cream',
#   'beef',
#   'poultry',
#   'fruit',
#   'potatoes',
#   'vegetables',
#   'manchester',
#   "'small goods2'",
#   "'trim pork'"],
#  ["'bread and cake'",
#   "'baking needs'",
#   'biscuits',
#   'sauces-gravy-pkle',
#   'confectionary',
#   "'frozen foods'",
#   "'party snack foods'",
#   'wrapping',
#   "'small goods'",
#   'vegetables'],
#  ["'baking needs'",
#   "'canned fruit'",
#   "'breakfast food'",
#   'confectionary',
#   "'frozen foods'",
#   'milk-cream',
#   'margarine',
#   "'small goods'",
#   'beef',
#   'potatoes',
#   'vegetables',
#   'stationary'],
#  ["'bread and cake'",
#   "'baking needs'",
#   'juice-sat-cord-ms',
#   'biscuits',
#   "'canned fruit'",
#   "'canned vegetables'",
#   'sauces-gravy-pkle',
#   'confectionary',
#   'puddings-deserts',
#   'dishcloths-scour',
#   "'frozen foods'",
#   "'pet foods'",
#   "'laundry needs'",
#   "'party snack foods'",
#   "'soft drinks'",
#   'milk-cream',
#   "'dairy foods'",
#   'beef',
#   'fruit',
#   'vegetables'],
#  ["'bread and cake'",
#   'biscuits',
#   'sauces-gravy-pkle',
#   "'frozen foods'",
#   'jams-spreads',
#   "'pet foods'",
#   "'soft drinks'",
#   'cheese',
#   'milk-cream',
#   'cold-meats',
#   "'dairy foods'",
#   "'delicatessen misc'",
#   "'pet food'",
#   'vegetables',
#   'kitchen',
#   'stationary',
#   "'casks red wine'",
#   "'750ml red imp'"],
#  ["'bread and cake'",
#   "'baking needs'",
#   'juice-sat-cord-ms',
#   'biscuits',
#   "'canned fruit'",
#   "'canned vegetables'",
#   "'frozen foods'",
#   "'party snack foods'",
#   'cold-meats',
#   "'dairy foods'",
#   "'delicatessen misc'",
#   'fruit',
#   'potatoes',
#   'vegetables'],
#  ["'bread and cake'",
#   "'canned fruit'",
#   'puddings-deserts',
#   "'laundry needs'",
#   "'tissues-paper prd'",
#   "'dental needs'",
#   'lotions-creams',
#   'margarine',
#   "'dairy foods'",
#   'beef',
#   'vegetables'],
#  ["'grocery misc'",
#   "'baking needs'",
#   'biscuits',
#   "'cigs-tobacco pkts'",
#   'sauces-gravy-pkle',
#   'confectionary',
#   "'frozen foods'",
#   "'pet foods'",
#   "'party snack foods'",
#   "'soft drinks'",
#   "'sanitary pads'",
#   'milk-cream',
#   "'pet food'",
#   'stationary'],
#  ["'cigs-tobacco pkts'",
#   'confectionary',
#   "'frozen foods'",
#   "'soft drinks'",
#   'milk-cream',
#   'beef',
#   'vegetables',
#   'kitchen',
#   "'casks red wine'"],
#  ["'bread and cake'",
#   "'baking needs'",
#   'tea',
#   'jams-spreads',
#   'insecticides',
#   'haircare',
#   'cough-cold-pain',
#   'cheese',
#   "'deli gourmet'",
#   'margarine',
#   "'dairy foods'",
#   "'imported cheese'"],
#  ["'bread and cake'",
#   "'canned fish-meat'",
#   "'canned vegetables'",
#   "'cigs-tobacco pkts'",
#   'cleaners-polishers',
#   'insecticides',
#   "'pet foods'",
#   "'laundry needs'",
#   "'tissues-paper prd'",
#   "'soft drinks'",
#   'milk-cream',
#   "'small goods'",
#   "'dairy foods'",
#   'fruit',
#   'potatoes',
#   'manchester'],
#  ["'bread and cake'",
#   "'baking needs'",
#   'juice-sat-cord-ms',
#   "'canned vegetables'",
#   "'breakfast food'",
#   "'cigs-tobacco pkts'",
#   'coffee',
#   "'party snack foods'",
#   'wrapping',
#   "'soft drinks'",
#   "'dental needs'",
#   'milk-cream',
#   'margarine',
#   'vegetables',
#   "'prepared meals'"],
#  ["'bread and cake'",
#   'juice-sat-cord-ms',
#   'biscuits',
#   "'fuels-garden aids'",
#   "'party snack foods'",
#   'milk-cream',
#   "'deli gourmet'",
#   "'dairy foods'",
#   'fruit',
#   'plants',
#   'vegetables',
#   'kitchen',
#   "'small goods2'"],
#  ...]

# %%
supermarket_data_set_list = createInitSet(supermarket_data_set_list)
supermarket_data_set_list
# Out:
# OrderedDict([(frozenset({"'750ml white nz'",
#                          "'baby needs'",
#                          "'baking needs'",
#                          "'bread and cake'",
#                          "'canned vegetables'",
#                          "'frozen foods'",
#                          "'mens toiletries'",
#                          "'party snack foods'",
#                          "'razor blades'",
#                          "'small goods'",
#                          "'tissues-paper prd'",
#                          'biscuits',
#                          'cheese',
#                          'cleaners-polishers',
#                          'coffee',
#                          'confectionary',
#                          'dishcloths-scour',
#                          'fruit',
#                          'juice-sat-cord-ms',
#                          'margarine',
#                          'milk-cream',
#                          'sauces-gravy-pkle',
#                          'vegetables',
#                          'wrapping'}),
#               1),
#              (frozenset({"'canned fish-meat'",
#                          "'canned fruit'",
#                          "'canned vegetables'",
#                          "'frozen foods'",
#                          "'laundry needs'",
#                          "'pet foods'",
#                          "'tissues-paper prd'",
#                          'deod-disinfectant',
#                          'deodorants-soap',
#                          'fruit',
#                          'haircare',
#                          'milk-cream',
#                          'sauces-gravy-pkle',
#                          'vegetables'}),
#               1),
#              (frozenset({"'baking needs'",
#                          "'bread and cake'",
#                          "'canned fruit'",
#                          "'dairy foods'",
#                          "'health food other'",
#                          "'small goods'",
#                          'beef',
#                          'biscuits',
#                          'fruit',
#                          'juice-sat-cord-ms',
#                          'lamb',
#                          'puddings-deserts',
#                          'sauces-gravy-pkle',
#                          'stationary',
#                          'vegetables',
#                          'wrapping'}),
#               1),
#              (frozenset({"'baking needs'",
#                          "'bread and cake'",
#                          "'breakfast food'",
#                          "'canned vegetables'",
#                          "'dairy foods'",
#                          "'frozen foods'",
#                          "'mens toiletries'",
#                          "'party snack foods'",
#                          "'pet foods'",
#                          "'prepared meals'",
#                          "'tissues-paper prd'",
#                          'beef',
#                          'biscuits',
#                          'cheese',
#                          'cleaners-polishers',
#                          'deodorants-soap',
#                          'jams-spreads',
#                          'juice-sat-cord-ms',
#                          'margarine',
#                          'stationary'}),
#               1),
#              (frozenset({"'baking needs'",
#                          "'bread and cake'",
#                          "'dental needs'",
#                          "'frozen foods'",
#                          "'laundry needs'",
#                          "'meat misc'",
#                          "'small goods2'",
#                          'beef',
#                          'cleaners-polishers',
#                          'coffee',
#                          'condiments',
#                          'deodorants-soap',
#                          'haircare',
#                          'jams-spreads',
#                          'juice-sat-cord-ms',
#                          'margarine',
#                          'milk-cream',
#                          'potatoes',
#                          'poultry',
#                          'sauces-gravy-pkle',
#                          'tea',
#                          'vegetables',
#                          'wrapping'}),
#               1),
#              (frozenset({"'baking needs'",
#                          "'bread and cake'",
#                          "'breakfast food'",
#                          "'canned fruit'",
#                          "'canned vegetables'",
#                          "'sanitary pads'",
#                          "'soft drinks'",
#                          "'tissues-paper prd'",
#                          'biscuits',
#                          'cheese',
#                          'cleaners-polishers',
#                          'electrical',
#                          'fruit',
#                          'juice-sat-cord-ms',
#                          'margarine',
#                          'milk-cream',
#                          'sauces-gravy-pkle',
#                          'tea'}),
#               1),
#              (frozenset({"'baby needs'",
#                          "'baking needs'",
#                          "'bread and cake'",
#                          "'canned vegetables'",
#                          "'frozen foods'",
#                          "'party snack foods'",
#                          "'pet foods'",
#                          "'sanitary pads'",
#                          'biscuits',
#                          'coffee',
#                          'fruit',
#                          'juice-sat-cord-ms',
#                          'milk-cream',
#                          'sauces-gravy-pkle',
#                          'vegetables'}),
#               1),
#              (frozenset({"'750ml red imp'",
#                          "'bake off products'",
#                          'fruit',
#                          'stationary'}),
#               1),
#              (frozenset({"'baking needs'",
#                          "'bread and cake'",
#                          "'canned fruit'",
#                          "'canned vegetables'",
#                          "'dental needs'",
#                          "'party snack foods'",
#                          "'pet foods'",
#                          "'sparkling nz'",
#                          'beef',
#                          'biscuits',
#                          'electrical',
#                          'fruit',
#                          'jams-spreads',
#                          'juice-sat-cord-ms',
#                          'milk-cream',
#                          'puddings-deserts',
#                          'sauces-gravy-pkle',
#                          'vegetables',
#                          'wrapping'}),
#               1),
#              (frozenset({"'baking needs'",
#                          "'bread and cake'",
#                          "'breakfast food'",
#                          "'canned fruit'",
#                          "'canned vegetables'",
#                          "'dental needs'",
#                          "'frozen foods'",
#                          "'laundry needs'",
#                          "'pet foods'",
#                          "'small goods2'",
#                          'beef',
#                          'biscuits',
#                          'cheese',
#                          'coffee',
#                          'dishcloths-scour',
#                          'fruit',
#                          'haircare',
#                          'juice-sat-cord-ms',
#                          'margarine',
#                          'milk-cream',
#                          'pork',
#                          'poultry',
#                          'vegetables'}),
#               1),
#              (frozenset({"'baking needs'",
#                          "'beverages hot'",
#                          "'bread and cake'",
#                          "'canned fish-meat'",
#                          "'canned fruit'",
#                          "'canned vegetables'",
#                          "'laundry needs'",
#                          "'pet food'",
#                          'beef',
#                          'cheese',
#                          'cough-cold-pain',
#                          'deodorants-soap',
#                          'fruit',
#                          'jams-spreads',
#                          'juice-sat-cord-ms',
#                          'lotions-creams',
#                          'margarine',
#                          'puddings-deserts',
#                          'vegetables'}),
#               1),
#              (frozenset({"'baby needs'",
#                          "'baking needs'",
#                          "'bread and cake'",
#                          "'breakfast food'",
#                          "'cigs-tobacco pkts'",
#                          "'dairy foods'",
#                          "'frozen foods'",
#                          "'grocery misc'",
#                          "'laundry needs'",
#                          "'party snack foods'",
#                          "'pkt-canned soup'",
#                          'biscuits',
#                          'coffee',
#                          'jams-spreads',
#                          'juice-sat-cord-ms',
#                          'margarine',
#                          'sauces-gravy-pkle'}),
#               1),
#              (frozenset({"'baking needs'",
#                          "'party snack foods'",
#                          "'prepared meals'",
#                          "'produce misc'",
#                          'fruit',
#                          'haircare',
#                          'jams-spreads',
#                          'lotions-creams',
#                          'puddings-deserts',
#                          'vegetables'}),
#               1),
#              (frozenset({"'bread and cake'",
#                          "'breakfast food'",
#                          "'dairy foods'",
#                          "'deli gourmet'",
#                          "'imported cheese'",
#                          "'party snack foods'",
#                          "'pet foods'",
#                          "'variety misc'",
#                          'biscuits',
#                          'cheese',
#                          'fruit',
#                          'juice-sat-cord-ms',
#                          'kitchen',
#                          'milk-cream',
#                          'sauces-gravy-pkle',
#                          'stationary',
#                          'vegetables'}),
#               1),
#              (frozenset({"'bake off products'",
#                          "'baking needs'",
#                          "'bread and cake'",
#                          "'breakfast food'",
#                          "'canned fruit'",
#                          "'canned vegetables'",
#                          "'dental needs'",
#                          "'frozen foods'",
#                          "'fuels-garden aids'",
#                          "'laundry needs'",
#                          "'party snack foods'",
#                          "'pet foods'",
#                          "'pkt-canned soup'",
#                          "'prepared meals'",
#                          "'small goods'",
#                          "'small goods2'",
#                          "'soft drinks'",
#                          "'tissues-paper prd'",
#                          'biscuits',
#                          'dishcloths-scour',
#                          'fruit',
#                          'haircare',
#                          'juice-sat-cord-ms',
#                          'margarine',
#                          'poultry',
#                          'sauces-gravy-pkle',
#                          'stationary',
#                          'tea',
#                          'vegetables',
#                          'wrapping'}),
#               1),
#              (frozenset({"'canned fruit'",
#                          "'frozen foods'",
#                          "'party snack foods'",
#                          "'variety misc'",
#                          'beef',
#                          'biscuits',
#                          'cheese',
#                          'cold-meats',
#                          'deod-disinfectant',
#                          'juice-sat-cord-ms',
#                          'margarine',
#                          'stationary',
#                          'tea'}),
#               1),
#              (frozenset({"'bread and cake'",
#                          "'casks white wine'",
#                          "'sparkling nz'",
#                          'biscuits',
#                          'fruit',
#                          'vegetables'}),
#               1),
#              (frozenset({"'baby needs'",
#                          "'bake off products'",
#                          "'baking needs'",
#                          "'beverages hot'",
#                          "'breakfast food'",
#                          "'cigs-tobacco pkts'",
#                          "'grocery misc'",
#                          "'laundry needs'",
#                          "'party snack foods'",
#                          'cleaners-polishers',
#                          'coffee',
#                          'condiments',
#                          'fruit',
#                          'margarine',
#                          'milk-cream',
#                          'potatoes',
#                          'sauces-gravy-pkle',
#                          'vegetables',
#                          'wrapping'}),
#               1),
#              (frozenset({"'canned fish-meat'",
#                          "'cooking oils'",
#                          "'frozen foods'",
#                          "'party snack foods'",
#                          "'prepared meals'",
#                          'biscuits',
#                          'confectionary',
#                          'fruit',
#                          'sauces-gravy-pkle'}),
#               1),
#              (frozenset({"'bread and cake'",
#                          "'cigs-tobacco pkts'",
#                          "'dairy foods'",
#                          "'deli gourmet'",
#                          "'frozen foods'",
#                          "'grocery misc'",
#                          "'pet foods'",
#                          "'produce misc'",
#                          "'small goods'",
#                          'beef',
#                          'biscuits',
#                          'cheese',
#                          'fruit',
#                          'margarine',
#                          'milk-cream',
#                          'offal',
#                          'pork',
#                          'sauces-gravy-pkle',
#                          'stationary',
#                          'vegetables'}),
#               1),
#              (frozenset({"'bake off products'",
#                          "'baking needs'",
#                          "'bread and cake'",
#                          "'breakfast food'",
#                          "'canned vegetables'",
#                          "'cooking oils'",
#                          "'dairy foods'",
#                          "'dental needs'",
#                          "'frozen foods'",
#                          "'laundry needs'",
#                          "'party snack foods'",
#                          "'pet food'",
#                          "'pet foods'",
#                          "'prepared meals'",
#                          "'small goods'",
#                          "'small goods2'",
#                          "'tissues-paper prd'",
#                          'beef',
#                          'biscuits',
#                          'cheese',
#                          'cold-meats',
#                          'confectionary',
#                          'deodorants-soap',
#                          'dishcloths-scour',
#                          'electrical',
#                          'fruit',
#                          'jams-spreads',
#                          'juice-sat-cord-ms',
#                          'lamb',
#                          'manchester',
#                          'margarine',
#                          'milk-cream',
#                          'plasticware',
#                          'potatoes',
#                          'puddings-deserts',
#                          'sauces-gravy-pkle',
#                          'stationary',
#                          'tea',
#                          'vegetables',
#                          'wrapping'}),
#               1),
#              (frozenset({"'baking needs'",
#                          "'frozen foods'",
#                          "'party snack foods'",
#                          "'small goods2'",
#                          "'tissues-paper prd'",
#                          'biscuits',
#                          'cheese',
#                          'cleaners-polishers',
#                          'confectionary',
#                          'fruit',
#                          'margarine',
#                          'milk-cream',
#                          'pork',
#                          'poultry',
#                          'sauces-gravy-pkle',
#                          'vegetables'}),
#               1),
#              (frozenset({"'bread and cake'",
#                          "'canned fish-meat'",
#                          "'dairy foods'",
#                          "'frozen foods'",
#                          "'laundry needs'",
#                          "'mens toiletries'",
#                          "'party snack foods'",
#                          "'soft drinks'",
#                          'biscuits',
#                          'fruit',
#                          'juice-sat-cord-ms',
#                          'lotions-creams',
#                          'margarine',
#                          'sauces-gravy-pkle',
#                          'vegetables'}),
#               1),
#              (frozenset({"'baking needs'",
#                          "'beverages hot'",
#                          "'bread and cake'",
#                          "'laundry needs'",
#                          "'small goods2'",
#                          "'tissues-paper prd'",
#                          'beef',
#                          'fruit',
#                          'lamb',
#                          'milk-cream',
#                          'sauces-gravy-pkle',
#                          'tea'}),
#               1),
#              (frozenset({"'baking needs'",
#                          "'bread and cake'",
#                          "'breakfast food'",
#                          "'canned fruit'",
#                          "'canned vegetables'",
#                          "'dairy foods'",
#                          "'frozen foods'",
#                          "'laundry needs'",
#                          "'pet foods'",
#                          "'tissues-paper prd'",
#                          'biscuits',
#                          'brushware',
#                          'cleaners-polishers',
#                          'cold-meats',
#                          'dishcloths-scour',
#                          'electrical',
#                          'fruit',
#                          'insecticides',
#                          'juice-sat-cord-ms',
#                          'milk-cream',
#                          'puddings-deserts',
#                          'vegetables'}),
#               1),
#              (frozenset({"'baking needs'",
#                          "'bread and cake'",
#                          "'breakfast food'",
#                          "'canned vegetables'",
#                          "'cigs-tobacco pkts'",
#                          "'frozen foods'",
#                          "'prepared meals'",
#                          "'small goods2'",
#                          "'tissues-paper prd'",
#                          'cheese',
#                          'deodorants-soap',
#                          'fruit',
#                          'juice-sat-cord-ms',
#                          'margarine',
#                          'milk-cream',
#                          'potatoes',
#                          'vegetables'}),
#               1),
#              (frozenset({"'baking needs'",
#                          "'beverages hot'",
#                          "'bread and cake'",
#                          "'breakfast food'",
#                          "'canned vegetables'",
#                          "'dairy foods'",
#                          "'dental needs'",
#                          "'frozen foods'",
#                          "'laundry needs'",
#                          "'mens toiletries'",
#                          "'party snack foods'",
#                          "'pet food'",
#                          "'small goods'",
#                          "'small goods2'",
#                          "'soft drinks'",
#                          "'tissues-paper prd'",
#                          'biscuits',
#                          'cheese',
#                          'confectionary',
#                          'deod-disinfectant',
#                          'deodorants-soap',
#                          'dishcloths-scour',
#                          'fruit',
#                          'haircare',
#                          'juice-sat-cord-ms',
#                          'puddings-deserts',
#                          'sauces-gravy-pkle',
#                          'stationary',
#                          'wrapping'}),
#               1),
#              (frozenset({"'baking needs'",
#                          "'dairy foods'",
#                          "'frozen foods'",
#                          "'fuels-garden aids'",
#                          "'party snack foods'",
#                          "'variety misc'",
#                          'cheese',
#                          'confectionary',
#                          'deod-disinfectant',
#                          'tea'}),
#               1),
#              (frozenset({"'baking needs'",
#                          "'bread and cake'",
#                          "'canned vegetables'",
#                          "'dental needs'",
#                          "'party snack foods'",
#                          "'pet foods'",
#                          "'tissues-paper prd'",
#                          'biscuits',
#                          'coffee',
#                          'confectionary',
#                          'deodorants-soap',
#                          'juice-sat-cord-ms',
#                          'milk-cream'}),
#               1),
#              (frozenset({"'canned fish-meat'",
#                          "'cooking oils'",
#                          "'dental needs'",
#                          "'laundry needs'",
#                          "'non host support'",
#                          "'pet foods'",
#                          "'pkt-canned soup'",
#                          "'tissues-paper prd'",
#                          'coffee',
#                          'deodorants-soap',
#                          'fruit',
#                          'haircare',
#                          'insecticides',
#                          'jams-spreads',
#                          'juice-sat-cord-ms',
#                          'tea'}),
#               1),
#              (frozenset({"'bake off products'",
#                          "'bread and cake'",
#                          "'breakfast food'",
#                          "'canned fruit'",
#                          "'canned vegetables'",
#                          "'frozen foods'",
#                          "'party snack foods'",
#                          'biscuits',
#                          'cheese',
#                          'fruit',
#                          'kitchen',
#                          'lotions-creams',
#                          'wrapping'}),
#               1),
#              (frozenset({"'bread and cake'",
#                          "'canned fruit'",
#                          "'canned vegetables'",
#                          "'frozen foods'",
#                          "'party snack foods'",
#                          "'port and sherry'",
#                          "'prepared meals'",
#                          "'soft drinks'",
#                          'beef',
#                          'biscuits',
#                          'cleaners-polishers',
#                          'fruit',
#                          'haberdashery',
#                          'kitchen',
#                          'margarine',
#                          'vegetables'}),
#               1),
#              (frozenset({"'baby needs'",
#                          "'baking needs'",
#                          "'bread and cake'",
#                          "'breakfast food'",
#                          "'frozen foods'",
#                          "'party snack foods'",
#                          "'pet foods'",
#                          "'small goods2'",
#                          "'soft drinks'",
#                          "'tissues-paper prd'",
#                          'beef',
#                          'biscuits',
#                          'cheese',
#                          'cleaners-polishers',
#                          'coffee',
#                          'confectionary',
#                          'fruit',
#                          'haircare',
#                          'jams-spreads',
#                          'juice-sat-cord-ms',
#                          'lamb',
#                          'margarine',
#                          'plasticware',
#                          'pork',
#                          'tea',
#                          'vegetables'}),
#               1),
#              (frozenset({"'bread and cake'",
#                          "'delicatessen misc'",
#                          "'party snack foods'",
#                          "'small goods2'",
#                          'biscuits',
#                          'fruit',
#                          'haircare',
#                          'jams-spreads',
#                          'milk-cream',
#                          'vegetables'}),
#               1),
#              (frozenset({"'baby needs'",
#                          "'baking needs'",
#                          "'bread and cake'",
#                          "'breakfast food'",
#                          "'canned fruit'",
#                          'cheese',
#                          'cleaners-polishers',
#                          'fruit',
#                          'haircare',
#                          'jams-spreads',
#                          'margarine',
#                          'milk-cream',
#                          'spices',
#                          'stationary'}),
#               1),
#              (frozenset({"'baking needs'",
#                          "'beverages hot'",
#                          "'bread and cake'",
#                          "'canned fish-meat'",
#                          "'canned vegetables'",
#                          "'dairy foods'",
#                          "'deli gourmet'",
#                          "'frozen foods'",
#                          "'laundry needs'",
#                          "'party snack foods'",
#                          "'pet foods'",
#                          "'prepared meals'",
#                          "'sanitary pads'",
#                          "'soft drinks'",
#                          'beef',
#                          'biscuits',
#                          'brushware',
#                          'cheese',
#                          'cleaners-polishers',
#                          'coffee',
#                          'confectionary',
#                          'deodorants-soap',
#                          'fruit',
#                          'haircare',
#                          'insecticides',
#                          'jams-spreads',
#                          'margarine',
#                          'milk-cream',
#                          'poultry',
#                          'sauces-gravy-pkle',
#                          'spices',
#                          'stationary',
#                          'tea',
#                          'vegetables'}),
#               1),
#              (frozenset({"'bread and cake'",
#                          "'canned fish-meat'",
#                          "'canned vegetables'",
#                          "'cigs-tobacco pkts'",
#                          "'frozen foods'",
#                          "'laundry needs'",
#                          "'prepared meals'",
#                          "'tissues-paper prd'",
#                          'cheese',
#                          'coffee',
#                          'condiments',
#                          'deod-disinfectant',
#                          'deodorants-soap',
#                          'fruit',
#                          'margarine',
#                          'sauces-gravy-pkle',
#                          'spices',
#                          'vegetables'}),
#               1),
#              (frozenset({"'breakfast food'",
#                          "'dairy foods'",
#                          "'dental needs'",
#                          "'frozen foods'",
#                          "'health&beauty misc'",
#                          "'mens toiletries'",
#                          "'party snack foods'",
#                          "'pet foods'",
#                          "'soft drinks'",
#                          'biscuits',
#                          'coffee',
#                          'confectionary',
#                          'cough-cold-pain',
#                          'deodorants-soap',
#                          'fruit',
#                          'haircare',
#                          'juice-sat-cord-ms',
#                          'margarine',
#                          'milk-cream',
#                          'puddings-deserts',
#                          'sauces-gravy-pkle',
#                          'stationary',
#                          'vegetables',
#                          'wrapping'}),
#               1),
#              (frozenset({"'baby needs'",
#                          "'bake off products'",
#                          "'baking needs'",
#                          "'bread and cake'",
#                          "'breakfast food'",
#                          "'canned fish-meat'",
#                          "'canned fruit'",
#                          "'cooking oils'",
#                          "'dairy foods'",
#                          "'dental needs'",
#                          "'laundry needs'",
#                          "'pet food'",
#                          "'pet foods'",
#                          "'soft drinks'",
#                          "'tissues-paper prd'",
#                          'biscuits',
#                          'cheese',
#                          'cleaners-polishers',
#                          'coffee',
#                          'confectionary',
#                          'deodorants-soap',
#                          'fruit',
#                          'haircare',
#                          'jams-spreads',
#                          'juice-sat-cord-ms',
#                          'kitchen',
#                          'margarine',
#                          'milk-cream',
#                          'sauces-gravy-pkle',
#                          'stationary',
#                          'tea',
#                          'vegetables',
#                          'wrapping'}),
#               1),
#              (frozenset({"'bread and cake'",
#                          "'cigs-tobacco pkts'",
#                          "'dental needs'",
#                          "'frozen foods'",
#                          "'prepared meals'",
#                          "'variety misc'",
#                          'milk-cream',
#                          'wrapping'}),
#               1),
#              (frozenset({"'baby needs'",
#                          "'baking needs'",
#                          "'bread and cake'",
#                          "'breakfast food'",
#                          "'canned fruit'",
#                          "'canned vegetables'",
#                          "'dairy foods'",
#                          "'dental needs'",
#                          "'frozen foods'",
#                          "'fuels-garden aids'",
#                          "'laundry needs'",
#                          "'party snack foods'",
#                          "'pet foods'",
#                          "'prepared meals'",
#                          "'sanitary pads'",
#                          "'tissues-paper prd'",
#                          'beef',
#                          'biscuits',
#                          'cheese',
#                          'confectionary',
#                          'deod-disinfectant',
#                          'deodorants-soap',
#                          'electrical',
#                          'fruit',
#                          'haircare',
#                          'jams-spreads',
#                          'juice-sat-cord-ms',
#                          'margarine',
#                          'plasticware',
#                          'sauces-gravy-pkle',
#                          'stationary',
#                          'tea',
#                          'vegetables'}),
#               1),
#              (frozenset({"'baking needs'",
#                          "'canned vegetables'",
#                          "'dental needs'",
#                          "'laundry needs'",
#                          "'pet food'",
#                          "'pet foods'",
#                          "'small goods'",
#                          "'tissues-paper prd'",
#                          'beef',
#                          'biscuits',
#                          'coffee',
#                          'confectionary',
#                          'deod-disinfectant',
#                          'deodorants-soap',
#                          'electrical',
#                          'fruit',
#                          'haircare',
#                          'jams-spreads',
#                          'lamb',
#                          'lotions-creams',
#                          'margarine',
#                          'milk-cream',
#                          'vegetables',
#                          'wrapping'}),
#               1),
#              (frozenset({"'baking needs'",
#                          "'bread and cake'",
#                          "'prepared meals'",
#                          "'produce misc'",
#                          "'small goods'",
#                          "'small goods2'",
#                          "'soft drinks'",
#                          'cheese',
#                          'condiments',
#                          'electrical',
#                          'haircare',
#                          'jams-spreads',
#                          'juice-sat-cord-ms',
#                          'margarine',
#                          'sauces-gravy-pkle',
#                          'spices',
#                          'vegetables'}),
#               1),
#              (frozenset({"'baking needs'",
#                          "'party snack foods'",
#                          "'soft drinks'",
#                          "'tissues-paper prd'",
#                          'biscuits',
#                          'confectionary',
#                          'kitchen',
#                          'potatoes',
#                          'stationary'}),
#               1),
#              (frozenset({"'bread and cake'",
#                          "'variety misc'",
#                          'kitchen',
#                          'milk-cream'}),
#               1),
#              (frozenset({"'baking needs'",
#                          "'bread and cake'",
#                          "'breakfast food'",
#                          "'dried vegetables'",
#                          "'frozen foods'",
#                          "'fuels-garden aids'",
#                          "'party snack foods'",
#                          'biscuits',
#                          'cheese',
#                          'confectionary',
#                          'cough-cold-pain',
#                          'fruit',
#                          'juice-sat-cord-ms',
#                          'lotions-creams',
#                          'medicines',
#                          'milk-cream',
#                          'spices',
#                          'wrapping'}),
#               1),
#              (frozenset({"'baking needs'",
#                          "'dairy foods'",
#                          "'port and sherry'",
#                          "'tissues-paper prd'",
#                          'biscuits',
#                          'cheese',
#                          'condiments',
#                          'electrical',
#                          'fruit',
#                          'margarine',
#                          'milk-cream',
#                          'poultry',
#                          'sauces-gravy-pkle',
#                          'stationary'}),
#               1),
#              (frozenset({"'baking needs'",
#                          "'breakfast food'",
#                          "'cooking oils'",
#                          "'sanitary pads'",
#                          "'variety misc'",
#                          'cheese',
#                          'fruit',
#                          'juice-sat-cord-ms',
#                          'kitchen',
#                          'spices',
#                          'wrapping'}),
#               1),
#              (frozenset({"'baby needs'",
#                          "'breakfast food'",
#                          "'canned fish-meat'",
#                          "'canned fruit'",
#                          "'canned vegetables'",
#                          "'dairy foods'",
#                          "'frozen foods'",
#                          "'laundry needs'",
#                          "'mens toiletries'",
#                          "'party snack foods'",
#                          "'pet foods'",
#                          "'razor blades'",
#                          "'tissues-paper prd'",
#                          'beef',
#                          'biscuits',
#                          'cheese',
#                          'confectionary',
#                          'jams-spreads',
#                          'juice-sat-cord-ms',
#                          'margarine',
#                          'pork',
#                          'potatoes',
#                          'sauces-gravy-pkle',
#                          'tea'}),
#               1),
#              (frozenset({"'cigs-tobacco pkts'",
#                          "'grocery misc'",
#                          "'party snack foods'",
#                          'pork',
#                          'poultry',
#                          'stationary'}),
#               1),
#              (frozenset({"'baking needs'",
#                          "'breakfast food'",
#                          "'canned fruit'",
#                          "'canned vegetables'",
#                          "'dental needs'",
#                          "'frozen foods'",
#                          "'health food other'",
#                          "'laundry needs'",
#                          "'pet food'",
#                          "'tissues-paper prd'",
#                          'biscuits',
#                          'cheese',
#                          'cleaners-polishers',
#                          'confectionary',
#                          'cough-cold-pain',
#                          'deodorants-soap',
#                          'dishcloths-scour',
#                          'jams-spreads',
#                          'potatoes',
#                          'sauces-gravy-pkle',
#                          'tea',
#                          'vegetables'}),
#               1),
#              (frozenset({"'baking needs'",
#                          "'bread and cake'",
#                          "'canned fish-meat'",
#                          "'dairy foods'",
#                          "'frozen foods'",
#                          "'laundry needs'",
#                          "'party snack foods'",
#                          "'tissues-paper prd'",
#                          'biscuits',
#                          'cheese',
#                          'coffee',
#                          'fruit',
#                          'haberdashery',
#                          'juice-sat-cord-ms',
#                          'milk-cream',
#                          'puddings-deserts',
#                          'sauces-gravy-pkle',
#                          'stationary',
#                          'tea'}),
#               1),
#              (frozenset({"'bake off products'",
#                          "'bread and cake'",
#                          "'cigs-tobacco pkts'",
#                          "'laundry needs'",
#                          "'party snack foods'",
#                          "'pet food'",
#                          "'tissues-paper prd'",
#                          'biscuits',
#                          'fruit',
#                          'insecticides',
#                          'vegetables'}),
#               1),
#              (frozenset({"'baby needs'",
#                          "'baking needs'",
#                          "'bread and cake'",
#                          "'canned fish-meat'",
#                          "'canned vegetables'",
#                          "'cooking oils'",
#                          "'laundry needs'",
#                          "'party snack foods'",
#                          "'pet foods'",
#                          "'small goods'",
#                          'coffee',
#                          'fruit',
#                          'juice-sat-cord-ms',
#                          'lamb',
#                          'margarine',
#                          'milk-cream',
#                          'plasticware',
#                          'poultry',
#                          'stationary',
#                          'vegetables'}),
#               1),
#              (frozenset({"'baking needs'",
#                          "'bread and cake'",
#                          "'canned fish-meat'",
#                          "'canned vegetables'",
#                          "'cooking oils'",
#                          'beef',
#                          'biscuits',
#                          'cheese',
#                          'haircare',
#                          'juice-sat-cord-ms',
#                          'milk-cream',
#                          'potatoes',
#                          'puddings-deserts',
#                          'vegetables',
#                          'wrapping'}),
#               1),
#              (frozenset({"'baby needs'",
#                          "'baking needs'",
#                          "'bread and cake'",
#                          "'breakfast food'",
#                          "'canned fruit'",
#                          "'dairy foods'",
#                          "'dental needs'",
#                          "'frozen foods'",
#                          "'laundry needs'",
#                          "'party snack foods'",
#                          "'sanitary pads'",
#                          "'small goods2'",
#                          "'tissues-paper prd'",
#                          "'trim pork'",
#                          'beef',
#                          'cheese',
#                          'cleaners-polishers',
#                          'cold-meats',
#                          'deodorants-soap',
#                          'fruit',
#                          'jams-spreads',
#                          'juice-sat-cord-ms',
#                          'lamb',
#                          'margarine',
#                          'milk-cream',
#                          'potatoes',
#                          'puddings-deserts',
#                          'vegetables',
#                          'wrapping'}),
#               1),
#              (frozenset({"'beverages hot'",
#                          "'bread and cake'",
#                          "'dairy foods'",
#                          "'frozen foods'",
#                          "'health food other'",
#                          "'pkt-canned soup'",
#                          "'tissues-paper prd'",
#                          'cleaners-polishers',
#                          'margarine',
#                          'milk-cream',
#                          'sauces-gravy-pkle',
#                          'spices'}),
#               1),
#              (frozenset({"'baking needs'",
#                          "'bread and cake'",
#                          "'canned fruit'",
#                          "'cigarette cartons'",
#                          "'frozen foods'",
#                          "'fuels-garden aids'",
#                          "'tissues-paper prd'",
#                          'biscuits',
#                          'cleaners-polishers',
#                          'fruit',
#                          'jams-spreads',
#                          'tea',
#                          'vegetables'}),
#               1),
#              (frozenset({"'baby needs'",
#                          "'baking needs'",
#                          "'bread and cake'",
#                          "'canned vegetables'",
#                          "'cigs-tobacco pkts'",
#                          "'grocery misc'",
#                          "'party snack foods'",
#                          "'prepared meals'",
#                          "'soft drinks'",
#                          'beef',
#                          'biscuits',
#                          'cheese',
#                          'deodorants-soap',
#                          'fruit'}),
#               1),
#              (frozenset({"'bread and cake'",
#                          "'breakfast food'",
#                          "'pet foods'",
#                          "'tissues-paper prd'",
#                          'biscuits',
#                          'cleaners-polishers',
#                          'deod-disinfectant',
#                          'deodorants-soap',
#                          'haircare',
#                          'milk-cream',
#                          'poultry',
#                          'vegetables'}),
#               1),
#              (frozenset({"'baking needs'",
#                          "'canned fish-meat'",
#                          "'canned vegetables'",
#                          "'frozen foods'",
#                          "'imported cheese'",
#                          "'pkt-canned soup'",
#                          "'small goods'",
#                          "'tissues-paper prd'",
#                          "'variety misc'",
#                          'beef',
#                          'biscuits',
#                          'cheese',
#                          'fruit',
#                          'jams-spreads',
#                          'margarine',
#                          'spices',
#                          'vegetables'}),
#               1),
#              (frozenset({"'breakfast food'",
#                          "'dairy foods'",
#                          "'dental needs'",
#                          "'frozen foods'",
#                          "'laundry needs'",
#                          "'party snack foods'",
#                          "'produce misc'",
#                          "'tissues-paper prd'",
#                          'beef',
#                          'cheese',
#                          'cleaners-polishers',
#                          'confectionary',
#                          'fruit',
#                          'juice-sat-cord-ms',
#                          'lamb',
#                          'medicines',
#                          'vegetables'}),
#               1),
#              (frozenset({"'bake off products'",
#                          "'baking needs'",
#                          "'beverages hot'",
#                          "'bread and cake'",
#                          "'breakfast food'",
#                          "'canned fish-meat'",
#                          "'canned fruit'",
#                          "'frozen foods'",
#                          "'laundry needs'",
#                          "'meat misc'",
#                          "'pet foods'",
#                          "'tissues-paper prd'",
#                          'cheese',
#                          'deod-disinfectant',
#                          'fruit',
#                          'margarine',
#                          'sauces-gravy-pkle',
#                          'stationary',
#                          'vegetables',
#                          'wrapping'}),
#               1),
#              (frozenset({"'bake off products'",
#                          "'baking needs'",
#                          "'beverages hot'",
#                          "'bread and cake'",
#                          "'cigs-tobacco pkts'",
#                          "'frozen foods'",
#                          "'grocery misc'",
#                          "'pet foods'",
#                          "'small goods'",
#                          "'soft drinks'",
#                          'biscuits',
#                          'coffee',
#                          'confectionary',
#                          'fruit',
#                          'jams-spreads',
#                          'margarine',
#                          'milk-cream',
#                          'plants',
#                          'stationary',
#                          'tea',
#                          'wrapping'}),
#               1),
#              (frozenset({"'bake off products'",
#                          "'baking needs'",
# ...
#               1),
#              (frozenset({"'baby needs'",
#                          "'baking needs'",
#                          "'bread and cake'",
#                          "'breakfast food'",
#                          "'frozen foods'",
#                          "'laundry needs'",
#                          "'party snack foods'",
#                          "'pet foods'",
#                          "'sanitary pads'",
#                          "'small goods'",
#                          "'soft drinks'",
#                          "'tissues-paper prd'",
#                          'biscuits',
#                          'brushware',
#                          'cleaners-polishers',
#                          'deodorants-soap',
#                          'kitchen',
#                          'margarine',
#                          'milk-cream',
#                          'sauces-gravy-pkle',
#                          'spices',
#                          'tea',
#                          'wrapping'}),
#               1),
#              (frozenset({"'bake off products'",
#                          "'baking needs'",
#                          "'bread and cake'",
#                          "'breakfast food'",
#                          "'canned fruit'",
#                          "'dairy foods'",
#                          "'deli gourmet'",
#                          "'delicatessen misc'",
#                          "'dental needs'",
#                          "'frozen foods'",
#                          "'imported cheese'",
#                          "'laundry needs'",
#                          "'party snack foods'",
#                          "'pet foods'",
#                          "'small goods'",
#                          "'small goods2'",
#                          "'soft drinks'",
#                          "'tissues-paper prd'",
#                          'beef',
#                          'biscuits',
#                          'cheese',
#                          'cleaners-polishers',
#                          'deodorants-soap',
#                          'fruit',
#                          'haircare',
#                          'jams-spreads',
#                          'juice-sat-cord-ms',
#                          'margarine',
#                          'milk-cream',
#                          'potatoes',
#                          'poultry',
#                          'sauces-gravy-pkle',
#                          'stationary',
#                          'vegetables'}),
#               1),
#              (frozenset({"'bake off products'",
#                          "'baking needs'",
#                          "'bread and cake'",
#                          "'canned vegetables'",
#                          "'cigs-tobacco pkts'",
#                          "'cooking oils'",
#                          "'dairy foods'",
#                          "'dental needs'",
#                          "'frozen foods'",
#                          "'party snack foods'",
#                          "'pet foods'",
#                          "'prepared meals'",
#                          "'small goods'",
#                          "'soft drinks'",
#                          "'tissues-paper prd'",
#                          'biscuits',
#                          'cheese',
#                          'coffee',
#                          'confectionary',
#                          'deod-disinfectant',
#                          'deodorants-soap',
#                          'fruit',
#                          'juice-sat-cord-ms',
#                          'margarine',
#                          'milk-cream',
#                          'vegetables',
#                          'wrapping'}),
#               1),
#              (frozenset({"'baking needs'",
#                          "'bread and cake'",
#                          "'breakfast food'",
#                          "'dairy foods'",
#                          "'small goods'",
#                          'fruit',
#                          'haircare',
#                          'kitchen',
#                          'lotions-creams',
#                          'margarine',
#                          'vegetables'}),
#               1),
#              (frozenset({"'cigs-tobacco pkts'",
#                          "'frozen foods'",
#                          "'party snack foods'",
#                          "'small goods2'",
#                          "'soft drinks'",
#                          'beef',
#                          'milk-cream',
#                          'poultry',
#                          'stationary'}),
#               1),
#              (frozenset({"'bread and cake'",
#                          "'breakfast food'",
#                          'biscuits',
#                          'cold-meats',
#                          'condiments',
#                          'milk-cream',
#                          'stationary',
#                          'vegetables'}),
#               1),
#              (frozenset({"'bake off products'",
#                          "'dental needs'",
#                          "'party snack foods'",
#                          "'prepared meals'",
#                          "'sanitary pads'",
#                          'biscuits',
#                          'confectionary',
#                          'deodorants-soap',
#                          'electrical',
#                          'fruit',
#                          'haircare',
#                          'kitchen'}),
#               1),
#              (frozenset({"'bread and cake'",
#                          "'breakfast food'",
#                          "'small goods2'",
#                          "'trim pork'",
#                          'beef',
#                          'biscuits',
#                          'fruit',
#                          'insecticides',
#                          'jams-spreads',
#                          'lotions-creams',
#                          'manchester',
#                          'milk-cream',
#                          'potatoes',
#                          'poultry',
#                          'vegetables'}),
#               1),
#              (frozenset({"'baking needs'",
#                          "'bread and cake'",
#                          "'frozen foods'",
#                          "'party snack foods'",
#                          "'small goods'",
#                          'biscuits',
#                          'confectionary',
#                          'sauces-gravy-pkle',
#                          'vegetables',
#                          'wrapping'}),
#               1),
#              (frozenset({"'baking needs'",
#                          "'breakfast food'",
#                          "'canned fruit'",
#                          "'frozen foods'",
#                          "'small goods'",
#                          'beef',
#                          'confectionary',
#                          'margarine',
#                          'milk-cream',
#                          'potatoes',
#                          'stationary',
#                          'vegetables'}),
#               1),
#              (frozenset({"'baking needs'",
#                          "'bread and cake'",
#                          "'canned fruit'",
#                          "'canned vegetables'",
#                          "'dairy foods'",
#                          "'frozen foods'",
#                          "'laundry needs'",
#                          "'party snack foods'",
#                          "'pet foods'",
#                          "'soft drinks'",
#                          'beef',
#                          'biscuits',
#                          'confectionary',
#                          'dishcloths-scour',
#                          'fruit',
#                          'juice-sat-cord-ms',
#                          'milk-cream',
#                          'puddings-deserts',
#                          'sauces-gravy-pkle',
#                          'vegetables'}),
#               1),
#              (frozenset({"'750ml red imp'",
#                          "'bread and cake'",
#                          "'casks red wine'",
#                          "'dairy foods'",
#                          "'delicatessen misc'",
#                          "'frozen foods'",
#                          "'pet food'",
#                          "'pet foods'",
#                          "'soft drinks'",
#                          'biscuits',
#                          'cheese',
#                          'cold-meats',
#                          'jams-spreads',
#                          'kitchen',
#                          'milk-cream',
#                          'sauces-gravy-pkle',
#                          'stationary',
#                          'vegetables'}),
#               1),
#              (frozenset({"'baking needs'",
#                          "'bread and cake'",
#                          "'canned fruit'",
#                          "'canned vegetables'",
#                          "'dairy foods'",
#                          "'delicatessen misc'",
#                          "'frozen foods'",
#                          "'party snack foods'",
#                          'biscuits',
#                          'cold-meats',
#                          'fruit',
#                          'juice-sat-cord-ms',
#                          'potatoes',
#                          'vegetables'}),
#               1),
#              (frozenset({"'bread and cake'",
#                          "'canned fruit'",
#                          "'dairy foods'",
#                          "'dental needs'",
#                          "'laundry needs'",
#                          "'tissues-paper prd'",
#                          'beef',
#                          'lotions-creams',
#                          'margarine',
#                          'puddings-deserts',
#                          'vegetables'}),
#               1),
#              (frozenset({"'baking needs'",
#                          "'cigs-tobacco pkts'",
#                          "'frozen foods'",
#                          "'grocery misc'",
#                          "'party snack foods'",
#                          "'pet food'",
#                          "'pet foods'",
#                          "'sanitary pads'",
#                          "'soft drinks'",
#                          'biscuits',
#                          'confectionary',
#                          'milk-cream',
#                          'sauces-gravy-pkle',
#                          'stationary'}),
#               1),
#              (frozenset({"'casks red wine'",
#                          "'cigs-tobacco pkts'",
#                          "'frozen foods'",
#                          "'soft drinks'",
#                          'beef',
#                          'confectionary',
#                          'kitchen',
#                          'milk-cream',
#                          'vegetables'}),
#               1),
#              (frozenset({"'baking needs'",
#                          "'bread and cake'",
#                          "'dairy foods'",
#                          "'deli gourmet'",
#                          "'imported cheese'",
#                          'cheese',
#                          'cough-cold-pain',
#                          'haircare',
#                          'insecticides',
#                          'jams-spreads',
#                          'margarine',
#                          'tea'}),
#               1),
#              (frozenset({"'bread and cake'",
#                          "'canned fish-meat'",
#                          "'canned vegetables'",
#                          "'cigs-tobacco pkts'",
#                          "'dairy foods'",
#                          "'laundry needs'",
#                          "'pet foods'",
#                          "'small goods'",
#                          "'soft drinks'",
#                          "'tissues-paper prd'",
#                          'cleaners-polishers',
#                          'fruit',
#                          'insecticides',
#                          'manchester',
#                          'milk-cream',
#                          'potatoes'}),
#               1),
#              (frozenset({"'baking needs'",
#                          "'bread and cake'",
#                          "'breakfast food'",
#                          "'canned vegetables'",
#                          "'cigs-tobacco pkts'",
#                          "'dental needs'",
#                          "'party snack foods'",
#                          "'prepared meals'",
#                          "'soft drinks'",
#                          'coffee',
#                          'juice-sat-cord-ms',
#                          'margarine',
#                          'milk-cream',
#                          'vegetables',
#                          'wrapping'}),
#               1),
#              (frozenset({"'bread and cake'",
#                          "'dairy foods'",
#                          "'deli gourmet'",
#                          "'fuels-garden aids'",
#                          "'party snack foods'",
#                          "'small goods2'",
#                          'biscuits',
#                          'fruit',
#                          'juice-sat-cord-ms',
#                          'kitchen',
#                          'milk-cream',
#                          'plants',
#                          'vegetables'}),
#               1),
#              (frozenset({"'dairy foods'",
#                          "'frozen foods'",
#                          "'party snack foods'",
#                          "'small goods2'",
#                          "'tissues-paper prd'",
#                          'cheese',
#                          'cleaners-polishers',
#                          'cold-meats',
#                          'fruit',
#                          'insecticides',
#                          'juice-sat-cord-ms',
#                          'kitchen',
#                          'milk-cream',
#                          'pork',
#                          'sauces-gravy-pkle',
#                          'wrapping'}),
#               1),
#              (frozenset({"'750ml red imp'",
#                          "'baking needs'",
#                          "'imported cheese'",
#                          "'soft drinks'",
#                          'cheese',
#                          'confectionary',
#                          'juice-sat-cord-ms',
#                          'milk-cream',
#                          'puddings-deserts',
#                          'sauces-gravy-pkle',
#                          'spices',
#                          'vegetables'}),
#               1),
#              (frozenset({"'baking needs'",
#                          "'breakfast food'",
#                          "'canned fish-meat'",
#                          "'dairy foods'",
#                          "'party snack foods'",
#                          "'produce misc'",
#                          'biscuits',
#                          'cheese',
#                          'fruit',
#                          'milk-cream',
#                          'vegetables'}),
#               1),
#              (frozenset({"'baby needs'",
#                          "'baking needs'",
#                          "'breakfast food'",
#                          "'canned vegetables'",
#                          "'dairy foods'",
#                          "'frozen foods'",
#                          "'laundry needs'",
#                          'cheese',
#                          'coffee',
#                          'fruit',
#                          'jams-spreads',
#                          'juice-sat-cord-ms',
#                          'margarine',
#                          'milk-cream',
#                          'stationary',
#                          'vegetables',
#                          'wrapping'}),
#               1),
#              (frozenset({"'baking needs'",
#                          "'bread and cake'",
#                          "'canned fruit'",
#                          "'canned vegetables'",
#                          "'frozen foods'",
#                          "'health food other'",
#                          "'party snack foods'",
#                          "'pet food'",
#                          "'pet foods'",
#                          "'soft drinks'",
#                          "'variety misc'",
#                          'juice-sat-cord-ms',
#                          'milk-cream'}),
#               1),
#              ...])

# %%
minSup = 0.15
FPtree, HeaderTab = createTree(supermarket_data_set_list, minSup)
FPtree.disp()
# Out:
#    Null Set   1
#      'bread and cake'   3329
#        fruit   2324
#          vegetables   1790
#            milk-cream   1311
#              'baking needs'   939
#                'frozen foods'   690
#                  biscuits   539
#                    juice-sat-cord-ms   365
#                      'party snack foods'   270
#                        margarine   198
#                          'tissues-paper prd'   157
#                            sauces-gravy-pkle   122
#                              cheese   40
#                                confectionary   1
#                                  'canned vegetables'   1
#                                    wrapping   1
#                                      cleaners-polishers   1
#                                        'small goods'   1
#                                          coffee   1
#                                'pet foods'   24
#                                  'breakfast food'   19
#                                    beef   16
#                                      confectionary   8
#                                        'dairy foods'   7
#                                          'canned vegetables'   7
#                                            'laundry needs'   6
#                                              stationary   4
#                                                wrapping   3
#                                                  jams-spreads   1
#                                                    'prepared meals'   1
#                                                      'small goods'   1
#                                                        deodorants-soap   1
#                                                          'dental needs'   1
#                                                            'small goods2'   1
#                                                              tea   1
#                                                                puddings-deserts   1
#                                                                  potatoes   1
#                                                  'canned fruit'   2
#                                                    jams-spreads   1
#                                                      'prepared meals'   1
#                                                        cleaners-polishers   1
#                                                          tea   1
#                                                            haircare   1
#                                                              poultry   1
#                                                    'prepared meals'   1
#                                                      'small goods'   1
#                                                        deodorants-soap   1
#                                                          'dental needs'   1
#                                                            'small goods2'   1
#                                                              'canned fish-meat'   1
#                                                                puddings-deserts   1
#                                                                  poultry   1
#                                                'canned fruit'   1
#                                                  'prepared meals'   1
#                                                    'small goods'   1
#                                                      'dental needs'   1
#                                                        'small goods2'   1
#                                              wrapping   2
#                                                'canned fruit'   2
#                                                  'prepared meals'   1
#                                                    cleaners-polishers   1
#                                                      'small goods'   1
#                                                        'small goods2'   1
#                                                          tea   1
#                                                            puddings-deserts   1
#                                                              potatoes   1
#                                                                'cigs-tobacco pkts'   1
#                                                  jams-spreads   1
#                                                    'prepared meals'   1
#                                                      cleaners-polishers   1
#                                                        'small goods'   1
#                                                          deodorants-soap   1
#                                                            'dental needs'   1
#                                                              'small goods2'   1
#                                                                puddings-deserts   1
#                                            jams-spreads   1
#                                              'prepared meals'   1
#                                                'cigs-tobacco pkts'   1
#                                        'laundry needs'   1
#                                          stationary   1
#                                            'canned fruit'   1
#                                              jams-spreads   1
#                                                cleaners-polishers   1
#                                                  haircare   1
#                                      'dairy foods'   7
#                                        'canned vegetables'   5
#                                          'laundry needs'   1
#                                            wrapping   1
#                                              'canned fruit'   1
#                                                jams-spreads   1
#                                                  'small goods'   1
#                                                    deodorants-soap   1
#                                                      'small goods2'   1
#                                                        'canned fish-meat'   1
#                                                          tea   1
#                                                            haircare   1
#                                                              puddings-deserts   1
#                                                                poultry   1
#                                                                  potatoes   1
#                                          stationary   3
#                                            'canned fruit'   1
#                                              jams-spreads   1
#                                                cleaners-polishers   1
#                                                  'small goods'   1
#                                                    deodorants-soap   1
#                                                      'dental needs'   1
#                                                        'small goods2'   1
#                                                          'canned fish-meat'   1
#                                                            puddings-deserts   1
#                                            wrapping   2
#                                              jams-spreads   1
#                                                'dental needs'   1
#                                                  'canned fish-meat'   1
#                                                    tea   1
#                                              'canned fruit'   1
#                                                jams-spreads   1
#                                                  'prepared meals'   1
#                                                    cleaners-polishers   1
#                                                      'small goods'   1
#                                                        'canned fish-meat'   1
#                                                          tea   1
#                                          wrapping   1
#                                            'canned fruit'   1
#                                              jams-spreads   1
#                                                'prepared meals'   1
#                                                  'small goods'   1
#                                                    'dental needs'   1
#                                        'laundry needs'   2
#                                          wrapping   1
#                                            'canned fruit'   1
#                                              jams-spreads   1
#                                                'prepared meals'   1
#                                                  coffee   1
#                                                    'dental needs'   1
#                                                      'small goods2'   1
#                                                        potatoes   1
#                                          stationary   1
#                                            jams-spreads   1
#                                              'prepared meals'   1
#                                                cleaners-polishers   1
#                                                  coffee   1
#                                                    'small goods2'   1
#                                      'canned vegetables'   1
#                                        'laundry needs'   1
#                                          wrapping   1
#                                            'canned fruit'   1
#                                              jams-spreads   1
#                                                'prepared meals'   1
#                                                  cleaners-polishers   1
#                                                    'small goods'   1
#                                                      deodorants-soap   1
#                                                        'dental needs'   1
#                                                          'canned fish-meat'   1
#                                                            haircare   1
#                                                              puddings-deserts   1
#                                    confectionary   2
#                                      'canned vegetables'   1
#                                        'laundry needs'   1
#                                          wrapping   1
#                                            'prepared meals'   1
#                                              coffee   1
#                                                deodorants-soap   1
#                                                  'dental needs'   1
#                                                    'small goods2'   1
#                                                      tea   1
#                                                        haircare   1
#                                      'dairy foods'   1
#                                        'laundry needs'   1
#                                          wrapping   1
#                                            jams-spreads   1
#                                              cleaners-polishers   1
#                                                'small goods'   1
#                                                  coffee   1
#                                                    'dental needs'   1
#                                                      'canned fish-meat'   1
#                                                        haircare   1
#                                    'canned vegetables'   1
#                                      'laundry needs'   1
#                                        wrapping   1
#                                          'canned fruit'   1
#                                            jams-spreads   1
#                                              'prepared meals'   1
#                                                cleaners-polishers   1
#                                                  'small goods'   1
#                                                    coffee   1
#                                                      'dental needs'   1
#                                                        tea   1
#                                                          puddings-deserts   1
#                                  beef   3
#                                    'dairy foods'   2
#                                      'laundry needs'   1
#                                        wrapping   1
#                                          'canned fruit'   1
#                                            jams-spreads   1
#                                              cleaners-polishers   1
#                                                'small goods'   1
#                                                  'small goods2'   1
#                                                    'canned fish-meat'   1
#                                                      tea   1
#                                      'canned vegetables'   1
#                                        'laundry needs'   1
#                                          stationary   1
#                                            wrapping   1
#                                              'canned fruit'   1
#                                                'prepared meals'   1
#                                                  cleaners-polishers   1
#                                                    'small goods2'   1
#                                                      tea   1
#                                                        poultry   1
#                                    'canned vegetables'   1
#                                      stationary   1
#                                        'canned fruit'   1
#                                          'small goods'   1
#                                            coffee   1
#                                              deodorants-soap   1
#                                                'small goods2'   1
#                                                  'cigs-tobacco pkts'   1
#                                  'dairy foods'   1
#                                    'canned vegetables'   1
#                                      stationary   1
#                                        'canned fruit'   1
#                                          'prepared meals'   1
#                                            cleaners-polishers   1
#                                              'small goods'   1
#                                                deodorants-soap   1
#                                                  haircare   1
#                                  confectionary   1
#                                    'dairy foods'   1
#                                      stationary   1
#                                        wrapping   1
#                                          jams-spreads   1
#                                            cleaners-polishers   1
#                                              'small goods'   1
#                                                deodorants-soap   1
#                                                  'small goods2'   1
#                                                    tea   1
#                                                      haircare   1
#                                                        potatoes   1
#                                'breakfast food'   9
#                                  beef   4
#                                    'dairy foods'   2
#                                      'canned vegetables'   2
#                                        'laundry needs'   1
#                                          wrapping   1
#                                            'canned fruit'   1
#                                              'prepared meals'   1
#                                                coffee   1
#                                                  deodorants-soap   1
#                                                    'dental needs'   1
#                                                      'small goods2'   1
#                                                        haircare   1
#                                                          poultry   1
#                                                            'cigs-tobacco pkts'   1
#                                        wrapping   1
#                                          'canned fruit'   1
#                                            jams-spreads   1
#                                              'prepared meals'   1
#                                                'small goods'   1
#                                                  coffee   1
#                                                    'canned fish-meat'   1
#                                                      tea   1
#                                                        poultry   1
#                                    confectionary   2
#                                      'canned vegetables'   1
#                                        'laundry needs'   1
#                                          stationary   1
#                                            wrapping   1
#                                              'canned fruit'   1
#                                                jams-spreads   1
#                                                  cleaners-polishers   1
#                                                    'dental needs'   1
#                                                      'small goods2'   1
#                                                        haircare   1
#                                      'dairy foods'   1
#                                        'canned vegetables'   1
#                                          'laundry needs'   1
#                                            wrapping   1
#                                              'canned fruit'   1
#                                                jams-spreads   1
#                                                  'prepared meals'   1
#                                                    cleaners-polishers   1
#                                                      'dental needs'   1
#                                                        'small goods2'   1
#                                                          'canned fish-meat'   1
#                                                            puddings-deserts   1
#                                                              poultry   1
#                                                                potatoes   1
#                                  'dairy foods'   1
#                                    'laundry needs'   1
#                                      stationary   1
#                                        wrapping   1
#                                          jams-spreads   1
#                                            'prepared meals'   1
#                                              coffee   1
#                                                deodorants-soap   1
#                                                  'dental needs'   1
#                                                    'small goods2'   1
#                                                      tea   1
#                                                        haircare   1
#                                  confectionary   3
#                                    'canned vegetables'   2
#                                      'laundry needs'   2
#                                        stationary   1
#                                          wrapping   1
#                                            'canned fruit'   1
#                                              jams-spreads   1
#                                                'prepared meals'   1
#                                                  cleaners-polishers   1
#                                                    'small goods'   1
#                                                      coffee   1
#                                                        'small goods2'   1
#                                                          tea   1
#                                                            haircare   1
#                                        'canned fruit'   1
#                                          jams-spreads   1
#                                            tea   1
#                                    'dairy foods'   1
#                                      'canned vegetables'   1
#                                        'laundry needs'   1
#                                          stationary   1
#                                            'canned fruit'   1
#                                              jams-spreads   1
#                                                cleaners-polishers   1
#                                                  coffee   1
#                                                    puddings-deserts   1
#                                  'canned vegetables'   1
#                                    wrapping   1
#                                      'canned fruit'   1
#                                        'prepared meals'   1
#                                          'small goods'   1
#                                            'dental needs'   1
#                                              puddings-deserts   1
#                                                poultry   1
#                                                  potatoes   1
#                                beef   5
#                                  'laundry needs'   1
#                                  confectionary   2
#                                    'canned vegetables'   1
#                                      'laundry needs'   1
#                                        wrapping   1
#                                          'prepared meals'   1
#                                            cleaners-polishers   1
#                                              'dental needs'   1
#                                                'small goods2'   1
#                                                  tea   1
#                                                    puddings-deserts   1
#                                    'dairy foods'   1
#                                      'canned vegetables'   1
#                                        wrapping   1
#                                          'canned fruit'   1
#                                            jams-spreads   1
#                                              'prepared meals'   1
#                                                cleaners-polishers   1
#                                                  'small goods'   1
#                                                    coffee   1
#                                                      'dental needs'   1
#                                                        'small goods2'   1
#                                                          tea   1
#                                                            puddings-deserts   1
#                                                              potatoes   1
#                                  'dairy foods'   2
#                                    'laundry needs'   1
#                                      stationary   1
#                                        'canned fruit'   1
#                                          'prepared meals'   1
#                                            'small goods'   1
#                                              coffee   1
#                                                'small goods2'   1
#                                                  haircare   1
#                                                    puddings-deserts   1
#                                                      potatoes   1
#                                                        'cigs-tobacco pkts'   1
#                                    'canned vegetables'   1
#                                      'laundry needs'   1
#                                        'canned fruit'   1
#                                          jams-spreads   1
#                                            'prepared meals'   1
#                                              cleaners-polishers   1
#                                                'small goods2'   1
#                                                  puddings-deserts   1
#                                                    poultry   1
#                                'dairy foods'   1
#                                  'canned vegetables'   1
#                                    'laundry needs'   1
#                                      'canned fruit'   1
#                                        jams-spreads   1
#                                          'prepared meals'   1
#                                            'small goods'   1
#                                              deodorants-soap   1
#                                                haircare   1
#                              'soft drinks'   70
#                                cheese   54
#                                  'pet foods'   43
#                                    'breakfast food'   30
#                                      beef   18
#                                        confectionary   13
#                                          'dairy foods'   8
#                                            'laundry needs'   2
#                                              stationary   1
#                                                wrapping   1
#                                                  jams-spreads   1
#                                                    coffee   1
#                                                      deodorants-soap   1
#                                                        'canned fish-meat'   1
#                                                          haircare   1
#                                                            poultry   1
#                                                              'cigs-tobacco pkts'   1
#                                              wrapping   1
#                                                coffee   1
#                                                  'small goods2'   1
#                                                    potatoes   1
#                                            'canned vegetables'   5
#                                              'laundry needs'   4
#                                                wrapping   2
#                                                  'canned fruit'   2
#                                                    jams-spreads   2
#                                                      coffee   1
#                                                        deodorants-soap   1
#                                                          'dental needs'   1
#                                                            haircare   1
#                                                              puddings-deserts   1
#                                                      'prepared meals'   1
#                                                        cleaners-polishers   1
#                                                          'small goods'   1
#                                                            coffee   1
#                                                              deodorants-soap   1
#                                                                'dental needs'   1
#                                                                  'small goods2'   1
#                                                                    'canned fish-meat'   1
#                                                                      tea   1
#                                                                        haircare   1
#                                                                          puddings-deserts   1
#                                                                            potatoes   1
#                                                stationary   2
#                                                  wrapping   2
#                                                    'canned fruit'   2
#                                                      'small goods'   1
#                                                        deodorants-soap   1
#                                                          'dental needs'   1
#                                                            'canned fish-meat'   1
#                                                              haircare   1
#                                                                poultry   1
#                                                      'prepared meals'   1
#                                                        cleaners-polishers   1
#                                                          'small goods'   1
#                                                            'small goods2'   1
#                                                              tea   1
#                                                                haircare   1
#                                                                  puddings-deserts   1
#                                                                    potatoes   1
#                                              stationary   1
#                                                wrapping   1
#                                                  'canned fruit'   1
#                                                    jams-spreads   1
#                                                      'prepared meals'   1
#                                                        'small goods'   1
#                                                          coffee   1
#                                                            deodorants-soap   1
#                                                              'small goods2'   1
#                                                                'canned fish-meat'   1
#                                                                  puddings-deserts   1
#                                                                    poultry   1
#                                                                      potatoes   1
#                                            wrapping   1
#                                              'canned fruit'   1
#                                                cleaners-polishers   1
#                                                  deodorants-soap   1
#                                                    'small goods2'   1
#                                                      tea   1
#                                                        poultry   1
#                                                          'cigs-tobacco pkts'   1
#                                          'canned vegetables'   5
#                                            wrapping   2
#                                              'canned fruit'   1
#                                                jams-spreads   1
#                                                  'prepared meals'   1
#                                                    cleaners-polishers   1
#                                                      coffee   1
#                                                        deodorants-soap   1
#                                                          'dental needs'   1
#                                                            'small goods2'   1
#                                                              'canned fish-meat'   1
#                                                                tea   1
#                                                                  puddings-deserts   1
#                                              jams-spreads   1
#                                                'prepared meals'   1
#                                                  cleaners-polishers   1
#                                                    coffee   1
#                                                      'dental needs'   1
#                                                        'small goods2'   1
#                                                          'canned fish-meat'   1
#                                                            tea   1
#                                                              potatoes   1
#                                                                'cigs-tobacco pkts'   1
#                                            'laundry needs'   2
#                                              wrapping   1
#                                                cleaners-polishers   1
#                                                  'small goods'   1
#                                                    deodorants-soap   1
#                                                      potatoes   1
#                                              stationary   1
#                                                jams-spreads   1
#                                                  'prepared meals'   1
#                                                    cleaners-polishers   1
#                                                      'small goods'   1
#                                                        coffee   1
#                                                          deodorants-soap   1
#                                                            'dental needs'   1
#                                                              'canned fish-meat'   1
#                                                                puddings-deserts   1
#                                                                  poultry   1
#                                                                    'cigs-tobacco pkts'   1
#                                            'canned fruit'   1
#                                              'prepared meals'   1
#                                                'small goods'   1
#                                                  'canned fish-meat'   1
#                                                    haircare   1
#                                                      'cigs-tobacco pkts'   1
#                                        'dairy foods'   4
#                                          'canned fruit'   1
#                                            cleaners-polishers   1
#                                              'small goods'   1
#                                                tea   1
#                                                  poultry   1
#                                                    potatoes   1
#                                          'laundry needs'   2
#                                            stationary   1
#                                              'canned fruit'   1
#                                                jams-spreads   1
#                                                  cleaners-polishers   1
#                                                    'small goods'   1
#                                                      deodorants-soap   1
#                                                        'dental needs'   1
#                                                          'small goods2'   1
#                                                            haircare   1
#                                                              poultry   1
#                                                                potatoes   1
#                                            wrapping   1
#                                              'prepared meals'   1
#                                                coffee   1
#                                                  'dental needs'   1
#                                                    puddings-deserts   1
#                                                      poultry   1
#                                                        'cigs-tobacco pkts'   1
#                                          'canned vegetables'   1
#                                            'laundry needs'   1
#                                              wrapping   1
#                                                jams-spreads   1
#                                                  'prepared meals'   1
#                                                    'small goods'   1
#                                                      'dental needs'   1
#                                                        haircare   1
#                                                          puddings-deserts   1
#                                        'laundry needs'   1
#                                          stationary   1
#                                            'canned fruit'   1
#                                              jams-spreads   1
#                                                deodorants-soap   1
#                                                  tea   1
#                                                    puddings-deserts   1
#                                                      potatoes   1
#                                      confectionary   9
#                                        'canned vegetables'   3
#                                          'laundry needs'   3
#                                            wrapping   1
#                                              'canned fruit'   1
#                                                jams-spreads   1
#                                                  'prepared meals'   1
#                                                    deodorants-soap   1
#                                                      'dental needs'   1
#                                                        puddings-deserts   1
#                                                          poultry   1
#                                            stationary   2
#                                              jams-spreads   1
#                                                'prepared meals'   1
#                                                  cleaners-polishers   1
#                                                    'small goods'   1
#                                                      deodorants-soap   1
#                                                        'canned fish-meat'   1
#                                                          tea   1
#                                              'prepared meals'   1
#                                                'small goods'   1
#                                                  deodorants-soap   1
#                                                    haircare   1
#                                        'dairy foods'   6
#                                          'canned vegetables'   5
#                                            'laundry needs'   5
#                                              wrapping   1
#                                                jams-spreads   1
#                                                  cleaners-polishers   1
#                                                    'small goods'   1
#                                                      'dental needs'   1
#                                              stationary   4
#                                                'canned fruit'   2
#                                                  'small goods'   1
#                                                    'dental needs'   1
#                                                      tea   1
#                                                        haircare   1
#                                                          'cigs-tobacco pkts'   1
#                                                  'prepared meals'   1
#                                                    cleaners-polishers   1
#                                                      'small goods'   1
#                                                        coffee   1
#                                                          'dental needs'   1
#                                                            'small goods2'   1
#                                                              'canned fish-meat'   1
#                                                                tea   1
#                                                                  puddings-deserts   1
#                                                                    poultry   1
#                                                wrapping   1
#                                                  'canned fruit'   1
#                                                    cleaners-polishers   1
#                                                      'small goods'   1
#                                                        coffee   1
#                                                          deodorants-soap   1
#                                                            'dental needs'   1
#                                                              'cigs-tobacco pkts'   1
#                                                cleaners-polishers   1
#                                                  tea   1
#                                                    puddings-deserts   1
#                                          'laundry needs'   1
#                                            wrapping   1
#                                              'canned fruit'   1
#                                                cleaners-polishers   1
#                                                  'dental needs'   1
#                                                    'canned fish-meat'   1
#                                                      potatoes   1
#                                      'canned vegetables'   2
#                                        'laundry needs'   2
#                                          stationary   1
#                                            wrapping   1
#                                              'canned fruit'   1
#                                                jams-spreads   1
#                                                  'prepared meals'   1
#                                                    cleaners-polishers   1
#                                                      'small goods'   1
#                                                        deodorants-soap   1
#                                                          'dental needs'   1
#                                                            haircare   1
#                                                              puddings-deserts   1
#                                          'canned fruit'   1
#                                            jams-spreads   1
#                                              'prepared meals'   1
#                                                coffee   1
#                                                  'dental needs'   1
#                                      'dairy foods'   1
#                                        'canned vegetables'   1
#                                          stationary   1
#                                            wrapping   1
#                                              'canned fruit'   1
#                                                jams-spreads   1
#                                                  cleaners-polishers   1
#                                                    deodorants-soap   1
#                                                      haircare   1
#                                                        puddings-deserts   1
#                                    beef   9
#                                      confectionary   8
#                                        'canned vegetables'   1
#                                          'canned fruit'   1
#                                            cleaners-polishers   1
#                                              'small goods'   1
#                                                coffee   1
#                                                  deodorants-soap   1
#                                                    'small goods2'   1
#                                                      'canned fish-meat'   1
#                                                        puddings-deserts   1
#                                                          potatoes   1
#                                        'dairy foods'   6
#                                          'canned vegetables'   5
#                                            'laundry needs'   5
#                                              stationary   4
#                                                wrapping   3
#                                                  jams-spreads   2
#                                                    coffee   1
#                                                      deodorants-soap   1
#                                                        'dental needs'   1
#                                                          'small goods2'   1
#                                                            haircare   1
#                                                              potatoes   1
#                                                    'prepared meals'   1
#                                                      cleaners-polishers   1
#                                                        coffee   1
#                                                          'dental needs'   1
#                                                            haircare   1
#                                                              poultry   1
#                                                  'canned fruit'   1
#                                                    jams-spreads   1
#                                                      cleaners-polishers   1
#                                                        'small goods'   1
#                                                          coffee   1
#                                                            deodorants-soap   1
#                                                              'dental needs'   1
#                                                                poultry   1
#                                                                  potatoes   1
#                                                'small goods'   1
#                                                  'dental needs'   1
#                                                    tea   1
#                                                      poultry   1
#                                              'canned fruit'   1
#                                                jams-spreads   1
#                                                  'prepared meals'   1
#                                                    'small goods'   1
#                                                      'dental needs'   1
#                                                        haircare   1
#                                                          puddings-deserts   1
#                                                            poultry   1
#                                          'laundry needs'   1
#                                            stationary   1
#                                              'prepared meals'   1
#                                                cleaners-polishers   1
#                                                  'small goods'   1
#                                                    'dental needs'   1
#                                                      haircare   1
#                                                        potatoes   1
#                                        'laundry needs'   1
#                                          stationary   1
#                                            wrapping   1
#                                              'canned fruit'   1
#                                                jams-spreads   1
#                                                  'small goods'   1
#                                                    coffee   1
#                                                      'small goods2'   1
#                                      'canned vegetables'   1
#                                        wrapping   1
#                                          'canned fruit'   1
#                                            jams-spreads   1
#                                              'prepared meals'   1
#                                                'dental needs'   1
#                                                  'small goods2'   1
#                                                    'canned fish-meat'   1
# ...
#              jams-spreads   1
#                tea   1
#                  haircare   1
#                    potatoes   1
#            'soft drinks'   1
#              'pet foods'   1
#                'cigs-tobacco pkts'   1
#            margarine   1
#              'tissues-paper prd'   1
#                'soft drinks'   1
#                  'pet foods'   1
#                    'laundry needs'   1
#                      'canned fruit'   1
#                        cleaners-polishers   1
#                          coffee   1
#                            deodorants-soap   1
#                              'dental needs'   1
#                                'canned fish-meat'   1
#                                  tea   1
#                                    poultry   1
#                                      'cigs-tobacco pkts'   1
#          'canned vegetables'   1
#            'canned fish-meat'   1
#              'cigs-tobacco pkts'   1
#          margarine   2
#            'soft drinks'   1
#              'dairy foods'   1
#                'small goods2'   1
#                  poultry   1
#            beef   1
#              'canned vegetables'   1
#                stationary   1
#                  'canned fruit'   1
#                    jams-spreads   1
#                      cleaners-polishers   1
#                        'canned fish-meat'   1
#                          tea   1
#                            puddings-deserts   1
#          cheese   1
#            'breakfast food'   1
#              stationary   1
#                'dental needs'   1
#          sauces-gravy-pkle   1
#            'canned vegetables'   1
#              'laundry needs'   1
#                stationary   1
#                  'canned fruit'   1
#                    jams-spreads   1
#                      cleaners-polishers   1
#                        coffee   1
#                          poultry   1
#        biscuits   17
#          margarine   2
#            beef   1
#              'laundry needs'   1
#                stationary   1
#                  cleaners-polishers   1
#                    'cigs-tobacco pkts'   1
#            'tissues-paper prd'   1
#              sauces-gravy-pkle   1
#                'pet foods'   1
#                  'dairy foods'   1
#                    'canned vegetables'   1
#                      deodorants-soap   1
#          sauces-gravy-pkle   1
#            cheese   1
#              'breakfast food'   1
#                confectionary   1
#          juice-sat-cord-ms   6
#            'party snack foods'   2
#              'tissues-paper prd'   2
#                'soft drinks'   1
#                  'pet foods'   1
#                    'breakfast food'   1
#                      beef   1
#                        'dairy foods'   1
#                          stationary   1
#                            'small goods'   1
#                              poultry   1
#                'pet foods'   1
#                  'breakfast food'   1
#                    confectionary   1
#                      'laundry needs'   1
#                        stationary   1
#                          cleaners-polishers   1
#            cheese   1
#              'dairy foods'   1
#                cleaners-polishers   1
#                  coffee   1
#                    'small goods2'   1
#            margarine   1
#              cheese   1
#                'pet foods'   1
#                  'breakfast food'   1
#                    confectionary   1
#                      'dental needs'   1
#                        'canned fish-meat'   1
#            'tissues-paper prd'   1
#              sauces-gravy-pkle   1
#                'soft drinks'   1
#                  cleaners-polishers   1
#                    'small goods2'   1
#            'soft drinks'   1
#              confectionary   1
#                'dairy foods'   1
#                  stationary   1
#                    deodorants-soap   1
#          'party snack foods'   4
#            margarine   2
#              'soft drinks'   1
#                cheese   1
#                  beef   1
#                    coffee   1
#                      'small goods2'   1
#                        tea   1
#                          'cigs-tobacco pkts'   1
#              'tissues-paper prd'   1
#                'soft drinks'   1
#                  'pet foods'   1
#                    beef   1
#                      'canned vegetables'   1
#                        coffee   1
#                          'canned fish-meat'   1
#                            haircare   1
#            'soft drinks'   1
#              stationary   1
#            sauces-gravy-pkle   1
#              'soft drinks'   1
#                cheese   1
#                  'pet foods'   1
#                    'breakfast food'   1
#                      'canned vegetables'   1
#                        'laundry needs'   1
#                          stationary   1
#                            jams-spreads   1
#                              cleaners-polishers   1
#                                coffee   1
#                                  'dental needs'   1
#                                    'small goods2'   1
#                                      'canned fish-meat'   1
#                                        haircare   1
#                                          puddings-deserts   1
#          'soft drinks'   2
#            confectionary   2
#              'canned fruit'   1
#                jams-spreads   1
#                  'small goods'   1
#                    coffee   1
#                      'small goods2'   1
#                        poultry   1
#              'cigs-tobacco pkts'   1
#          'breakfast food'   2
#            wrapping   1
#              deodorants-soap   1
#                poultry   1
#        'tissues-paper prd'   4
#          'breakfast food'   1
#            'dairy foods'   1
#              puddings-deserts   1
#                'cigs-tobacco pkts'   1
#          sauces-gravy-pkle   1
#            'soft drinks'   1
#              beef   1
#                'dental needs'   1
#                  'small goods2'   1
#          confectionary   2
#            'dairy foods'   1
#              cleaners-polishers   1
#            'canned vegetables'   1
#              stationary   1
#                wrapping   1
#                  'prepared meals'   1
#        confectionary   2
#          'cigs-tobacco pkts'   1
#          'prepared meals'   1
#            'cigs-tobacco pkts'   1
#        margarine   2
#          deodorants-soap   1
#            'cigs-tobacco pkts'   1
#          sauces-gravy-pkle   1
#            'pet foods'   1
#              'breakfast food'   1
#                beef   1
#                  confectionary   1
#                    'laundry needs'   1
#                      'canned fruit'   1
#                        'canned fish-meat'   1
#                          tea   1
#                            'cigs-tobacco pkts'   1
#        cheese   1
#          beef   1
#            'small goods'   1
#        'cigs-tobacco pkts'   1
#      'tissues-paper prd'   10
#        'pet foods'   3
#          'laundry needs'   2
#            stationary   1
#              wrapping   1
#                cleaners-polishers   1
#                  deodorants-soap   1
#                    'dental needs'   1
#                      haircare   1
#            wrapping   1
#              cleaners-polishers   1
#                coffee   1
#                  deodorants-soap   1
#          'cigs-tobacco pkts'   1
#        'breakfast food'   2
#          beef   1
#            'laundry needs'   1
#              wrapping   1
#                'cigs-tobacco pkts'   1
#        sauces-gravy-pkle   2
#          'pet foods'   2
#            'small goods'   1
#              'cigs-tobacco pkts'   1
#            'breakfast food'   1
#              'canned vegetables'   1
#                stationary   1
#                  'canned fruit'   1
#        beef   1
#          'laundry needs'   1
#        'laundry needs'   1
#          wrapping   1
#            cleaners-polishers   1
#              deodorants-soap   1
#                'dental needs'   1
#                  haircare   1
#                    'cigs-tobacco pkts'   1
#        stationary   1
#          haircare   1
#            'cigs-tobacco pkts'   1
#      stationary   6
#        coffee   1
#          'cigs-tobacco pkts'   1
#        'cigs-tobacco pkts'   1
#        wrapping   1
#          cleaners-polishers   1
#            'dental needs'   1
#      biscuits   24
#        juice-sat-cord-ms   11
#          'party snack foods'   7
#            margarine   3
#              cheese   1
#                'breakfast food'   1
#                  beef   1
#                    wrapping   1
#                      jams-spreads   1
#                        'prepared meals'   1
#                          'small goods'   1
#                            coffee   1
#                              'small goods2'   1
#              sauces-gravy-pkle   2
#                'soft drinks'   2
#                  confectionary   1
#                    'canned vegetables'   1
#                      cleaners-polishers   1
#                        coffee   1
#                          'canned fish-meat'   1
#                  'breakfast food'   1
#                    beef   1
#                      'dairy foods'   1
#                        'canned vegetables'   1
#                          coffee   1
#            cheese   1
#              'pet foods'   1
#                confectionary   1
#                  stationary   1
#                    wrapping   1
#                      coffee   1
#                        deodorants-soap   1
#                          poultry   1
#            'soft drinks'   1
#              wrapping   1
#                cleaners-polishers   1
#            'tissues-paper prd'   1
#              'soft drinks'   1
#                'pet foods'   1
#                  confectionary   1
#                    stationary   1
#                      wrapping   1
#                        'small goods'   1
#                          coffee   1
#            sauces-gravy-pkle   1
#              cheese   1
#                'breakfast food'   1
#                  'dairy foods'   1
#                    'canned vegetables'   1
#                      'laundry needs'   1
#                        deodorants-soap   1
#                          'dental needs'   1
#          margarine   1
#            'tissues-paper prd'   1
#              sauces-gravy-pkle   1
#                confectionary   1
#                  'canned vegetables'   1
#                    cleaners-polishers   1
#                      tea   1
#          'soft drinks'   1
#            'breakfast food'   1
#              confectionary   1
#                stationary   1
#                  wrapping   1
#                    'canned fruit'   1
#                      cleaners-polishers   1
#          confectionary   1
#            stationary   1
#          'breakfast food'   1
#            confectionary   1
#              'laundry needs'   1
#                jams-spreads   1
#                  cleaners-polishers   1
#                    deodorants-soap   1
#                      haircare   1
#        confectionary   2
#          cleaners-polishers   1
#            coffee   1
#              tea   1
#        cleaners-polishers   1
#          coffee   1
#            tea   1
#        'party snack foods'   6
#          'tissues-paper prd'   2
#            sauces-gravy-pkle   1
#              'soft drinks'   1
#                'pet foods'   1
#                  'breakfast food'   1
#                    beef   1
#                      'dairy foods'   1
#                        'canned vegetables'   1
#                          stationary   1
#                            deodorants-soap   1
#                              poultry   1
#            cheese   1
#              'prepared meals'   1
#                deodorants-soap   1
#                  'small goods2'   1
#                    'cigs-tobacco pkts'   1
#          'soft drinks'   2
#            beef   1
#              'small goods'   1
#                'small goods2'   1
#            confectionary   1
#              'cigs-tobacco pkts'   1
#          sauces-gravy-pkle   1
#            cheese   1
#              'laundry needs'   1
#                'canned fruit'   1
#                  'small goods2'   1
#                    tea   1
#          margarine   1
#            sauces-gravy-pkle   1
#              cheese   1
#                'breakfast food'   1
#                  beef   1
#                    'canned vegetables'   1
#                      'laundry needs'   1
#                        'canned fruit'   1
#                          'prepared meals'   1
#                            'small goods'   1
#                              coffee   1
#                                deodorants-soap   1
#                                  'dental needs'   1
#                                    'small goods2'   1
#                                      'canned fish-meat'   1
#                                        haircare   1
#                                          puddings-deserts   1
#        margarine   2
#          beef   1
#          'pet foods'   1
#            confectionary   1
#              'canned vegetables'   1
#                'canned fruit'   1
#                  jams-spreads   1
#                    'prepared meals'   1
#        'soft drinks'   2
#          beef   1
#            'laundry needs'   1
#              cleaners-polishers   1
#                poultry   1
#          confectionary   1
#            'cigs-tobacco pkts'   1
#      juice-sat-cord-ms   21
#        'party snack foods'   8
#          'dairy foods'   1
#            cleaners-polishers   1
#              'small goods'   1
#                haircare   1
#          sauces-gravy-pkle   2
#            'soft drinks'   2
#              'pet foods'   1
#                confectionary   1
#                  'dairy foods'   1
#          'tissues-paper prd'   2
#            'soft drinks'   1
#              stationary   1
#                'small goods'   1
#          confectionary   1
#            'dairy foods'   1
#          'soft drinks'   1
#            beef   1
#              confectionary   1
#                'canned vegetables'   1
#                  'small goods'   1
#                    'canned fish-meat'   1
#                      poultry   1
#          margarine   1
#            'soft drinks'   1
#              'pet foods'   1
#                'dairy foods'   1
#                  'laundry needs'   1
#        'tissues-paper prd'   2
#          'breakfast food'   1
#            beef   1
#              wrapping   1
#                jams-spreads   1
#                  cleaners-polishers   1
#                    poultry   1
#          sauces-gravy-pkle   1
#            'soft drinks'   1
#              beef   1
#                wrapping   1
#                  cleaners-polishers   1
#        confectionary   2
#          'canned vegetables'   1
#            'prepared meals'   1
#          'cigs-tobacco pkts'   1
#        'pet foods'   2
#          wrapping   1
#          'cigs-tobacco pkts'   1
#        cheese   1
#          cleaners-polishers   1
#        'soft drinks'   3
#          beef   1
#            'dairy foods'   1
#          haircare   1
#        margarine   1
#          sauces-gravy-pkle   1
#            cheese   1
#              'breakfast food'   1
#                beef   1
#                  'small goods'   1
#                    'small goods2'   1
#                      poultry   1
#      'soft drinks'   4
#        beef   1
#          'small goods'   1
#            haircare   1
#        confectionary   2
#          'dental needs'   1
#            'cigs-tobacco pkts'   1
#          'dairy foods'   1
#            coffee   1
#              'cigs-tobacco pkts'   1
#      'breakfast food'   3
#        beef   1
#          jams-spreads   1
#        stationary   1
#          'dental needs'   1
#      beef   3
#        poultry   1
#        'small goods2'   2
#      haircare   2
#        'cigs-tobacco pkts'   2
#      margarine   1
#        'breakfast food'   1
#          confectionary   1
#            'dairy foods'   1
#              'laundry needs'   1
#                'dental needs'   1
#      cleaners-polishers   2
#        coffee   1
#        haircare   1
#          'cigs-tobacco pkts'   1
#      confectionary   3
#        haircare   1
#        stationary   1
#          'cigs-tobacco pkts'   1
#        'dental needs'   1
#      'pet foods'   2
#        'dairy foods'   1
#      coffee   1
#      'laundry needs'   1
#      'dental needs'   1
#        'cigs-tobacco pkts'   1
#      'prepared meals'   1
#      sauces-gravy-pkle   2
#        wrapping   1
#          'canned fruit'   1
#            'cigs-tobacco pkts'   1
#      'dairy foods'   1

# %%
freqItems = []
mineTree(FPtree, HeaderTab, minSup, set([]), freqItems)

#特征数过多，递归算法占用内存过大，内存不足，运行失败
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\Code\数据挖掘\李典202006140455\Work2\FP_tree_supermarket.ipynb Cell 18 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/d%3A/Code/%E6%95%B0%E6%8D%AE%E6%8C%96%E6%8E%98/%E6%9D%8E%E5%85%B8202006140455/Work2/FP_tree_supermarket.ipynb#X23sZmlsZQ%3D%3D?line=0'>1</a> freqItems = []
# ----> <a href='vscode-notebook-cell:/d%3A/Code/%E6%95%B0%E6%8D%AE%E6%8C%96%E6%8E%98/%E6%9D%8E%E5%85%B8202006140455/Work2/FP_tree_supermarket.ipynb#X23sZmlsZQ%3D%3D?line=1'>2</a> mineTree(FPtree, HeaderTab, minSup, set([]), freqItems)
#
# d:\Code\数据挖掘\李典202006140455\Work2\FP_tree_supermarket.ipynb Cell 18 in mineTree(inTree, headerTable, minSup, preFix, freqItemList)
#      <a href='vscode-notebook-cell:/d%3A/Code/%E6%95%B0%E6%8D%AE%E6%8C%96%E6%8E%98/%E6%9D%8E%E5%85%B8202006140455/Work2/FP_tree_supermarket.ipynb#X23sZmlsZQ%3D%3D?line=27'>28</a> # 挖掘条件 FP-tree, 如果myHead不为空，表示满足minSup {所有的元素+(value, treeNode)}
#      <a href='vscode-notebook-cell:/d%3A/Code/%E6%95%B0%E6%8D%AE%E6%8C%96%E6%8E%98/%E6%9D%8E%E5%85%B8202006140455/Work2/FP_tree_supermarket.ipynb#X23sZmlsZQ%3D%3D?line=28'>29</a> if myHead != None:
#      <a href='vscode-notebook-cell:/d%3A/Code/%E6%95%B0%E6%8D%AE%E6%8C%96%E6%8E%98/%E6%9D%8E%E5%85%B8202006140455/Work2/FP_tree_supermarket.ipynb#X23sZmlsZQ%3D%3D?line=29'>30</a>     # print('conditional tree for:', newFreqSet)
#      <a href='vscode-notebook-cell:/d%3A/Code/%E6%95%B0%E6%8D%AE%E6%8C%96%E6%8E%98/%E6%9D%8E%E5%85%B8202006140455/Work2/FP_tree_supermarket.ipynb#X23sZmlsZQ%3D%3D?line=30'>31</a>     # myCondTree.disp(1)
#      <a href='vscode-notebook-cell:/d%3A/Code/%E6%95%B0%E6%8D%AE%E6%8C%96%E6%8E%98/%E6%9D%8E%E5%85%B8202006140455/Work2/FP_tree_supermarket.ipynb#X23sZmlsZQ%3D%3D?line=31'>32</a>     # 递归 myHead 找出频繁项集
# ---> <a href='vscode-notebook-cell:/d%3A/Code/%E6%95%B0%E6%8D%AE%E6%8C%96%E6%8E%98/%E6%9D%8E%E5%85%B8202006140455/Work2/FP_tree_supermarket.ipynb#X23sZmlsZQ%3D%3D?line=32'>33</a>     mineTree(myCondTree, myHead, minSup, newFreqSet, freqItemList)
#
# d:\Code\数据挖掘\李典202006140455\Work2\FP_tree_supermarket.ipynb Cell 18 in mineTree(inTree, headerTable, minSup, preFix, freqItemList)
#      <a href='vscode-notebook-cell:/d%3A/Code/%E6%95%B0%E6%8D%AE%E6%8C%96%E6%8E%98/%E6%9D%8E%E5%85%B8202006140455/Work2/FP_tree_supermarket.ipynb#X23sZmlsZQ%3D%3D?line=27'>28</a> # 挖掘条件 FP-tree, 如果myHead不为空，表示满足minSup {所有的元素+(value, treeNode)}
#      <a href='vscode-notebook-cell:/d%3A/Code/%E6%95%B0%E6%8D%AE%E6%8C%96%E6%8E%98/%E6%9D%8E%E5%85%B8202006140455/Work2/FP_tree_supermarket.ipynb#X23sZmlsZQ%3D%3D?line=28'>29</a> if myHead != None:
#      <a href='vscode-notebook-cell:/d%3A/Code/%E6%95%B0%E6%8D%AE%E6%8C%96%E6%8E%98/%E6%9D%8E%E5%85%B8202006140455/Work2/FP_tree_supermarket.ipynb#X23sZmlsZQ%3D%3D?line=29'>30</a>     # print('conditional tree for:', newFreqSet)
#      <a href='vscode-notebook-cell:/d%3A/Code/%E6%95%B0%E6%8D%AE%E6%8C%96%E6%8E%98/%E6%9D%8E%E5%85%B8202006140455/Work2/FP_tree_supermarket.ipynb#X23sZmlsZQ%3D%3D?line=30'>31</a>     # myCondTree.disp(1)
#      <a href='vscode-notebook-cell:/d%3A/Code/%E6%95%B0%E6%8D%AE%E6%8C%96%E6%8E%98/%E6%9D%8E%E5%85%B8202006140455/Work2/FP_tree_supermarket.ipynb#X23sZmlsZQ%3D%3D?line=31'>32</a>     # 递归 myHead 找出频繁项集
# ---> <a href='vscode-notebook-cell:/d%3A/Code/%E6%95%B0%E6%8D%AE%E6%8C%96%E6%8E%98/%E6%9D%8E%E5%85%B8202006140455/Work2/FP_tree_supermarket.ipynb#X23sZmlsZQ%3D%3D?line=32'>33</a>     mineTree(myCondTree, myHead, minSup, newFreqSet, freqItemList)
#
#     [... skipping similar frames: mineTree at line 33 (14 times)]
#
# d:\Code\数据挖掘\李典202006140455\Work2\FP_tree_supermarket.ipynb Cell 18 in mineTree(inTree, headerTable, minSup, preFix, freqItemList)
#      <a href='vscode-notebook-cell:/d%3A/Code/%E6%95%B0%E6%8D%AE%E6%8C%96%E6%8E%98/%E6%9D%8E%E5%85%B8202006140455/Work2/FP_tree_supermarket.ipynb#X23sZmlsZQ%3D%3D?line=27'>28</a> # 挖掘条件 FP-tree, 如果myHead不为空，表示满足minSup {所有的元素+(value, treeNode)}
#      <a href='vscode-notebook-cell:/d%3A/Code/%E6%95%B0%E6%8D%AE%E6%8C%96%E6%8E%98/%E6%9D%8E%E5%85%B8202006140455/Work2/FP_tree_supermarket.ipynb#X23sZmlsZQ%3D%3D?line=28'>29</a> if myHead != None:
#      <a href='vscode-notebook-cell:/d%3A/Code/%E6%95%B0%E6%8D%AE%E6%8C%96%E6%8E%98/%E6%9D%8E%E5%85%B8202006140455/Work2/FP_tree_supermarket.ipynb#X23sZmlsZQ%3D%3D?line=29'>30</a>     # print('conditional tree for:', newFreqSet)
#      <a href='vscode-notebook-cell:/d%3A/Code/%E6%95%B0%E6%8D%AE%E6%8C%96%E6%8E%98/%E6%9D%8E%E5%85%B8202006140455/Work2/FP_tree_supermarket.ipynb#X23sZmlsZQ%3D%3D?line=30'>31</a>     # myCondTree.disp(1)
#      <a href='vscode-notebook-cell:/d%3A/Code/%E6%95%B0%E6%8D%AE%E6%8C%96%E6%8E%98/%E6%9D%8E%E5%85%B8202006140455/Work2/FP_tree_supermarket.ipynb#X23sZmlsZQ%3D%3D?line=31'>32</a>     # 递归 myHead 找出频繁项集
# ---> <a href='vscode-notebook-cell:/d%3A/Code/%E6%95%B0%E6%8D%AE%E6%8C%96%E6%8E%98/%E6%9D%8E%E5%85%B8202006140455/Work2/FP_tree_supermarket.ipynb#X23sZmlsZQ%3D%3D?line=32'>33</a>     mineTree(myCondTree, myHead, minSup, newFreqSet, freqItemList)
#
# d:\Code\数据挖掘\李典202006140455\Work2\FP_tree_supermarket.ipynb Cell 18 in mineTree(inTree, headerTable, minSup, preFix, freqItemList)
#      <a href='vscode-notebook-cell:/d%3A/Code/%E6%95%B0%E6%8D%AE%E6%8C%96%E6%8E%98/%E6%9D%8E%E5%85%B8202006140455/Work2/FP_tree_supermarket.ipynb#X23sZmlsZQ%3D%3D?line=16'>17</a> # 循环遍历 最频繁项集的key，从小到大的递归寻找对应的频繁项集
#      <a href='vscode-notebook-cell:/d%3A/Code/%E6%95%B0%E6%8D%AE%E6%8C%96%E6%8E%98/%E6%9D%8E%E5%85%B8202006140455/Work2/FP_tree_supermarket.ipynb#X23sZmlsZQ%3D%3D?line=17'>18</a> for basePat in bigL:
# ---> <a href='vscode-notebook-cell:/d%3A/Code/%E6%95%B0%E6%8D%AE%E6%8C%96%E6%8E%98/%E6%9D%8E%E5%85%B8202006140455/Work2/FP_tree_supermarket.ipynb#X23sZmlsZQ%3D%3D?line=18'>19</a>     newFreqSet = preFix.copy() # preFix为newFreqSet上一次的存储记录，一旦没有myHead，就不会更新
#      <a href='vscode-notebook-cell:/d%3A/Code/%E6%95%B0%E6%8D%AE%E6%8C%96%E6%8E%98/%E6%9D%8E%E5%85%B8202006140455/Work2/FP_tree_supermarket.ipynb#X23sZmlsZQ%3D%3D?line=19'>20</a>     newFreqSet.add(basePat)
#      <a href='vscode-notebook-cell:/d%3A/Code/%E6%95%B0%E6%8D%AE%E6%8C%96%E6%8E%98/%E6%9D%8E%E5%85%B8202006140455/Work2/FP_tree_supermarket.ipynb#X23sZmlsZQ%3D%3D?line=20'>21</a>     # print ('finalFrequent Item: ',newFreqSet)    #添加的频繁项列表
#
# KeyboardInterrupt:
